# %%
#libraries 
import numpy as np
import pandas as pd
import re
import os


#preprocessing
import string
from time import time  
from nltk.corpus import stopwords #remove stop words
chachedWords = stopwords.words('english')

#cosine similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
import math
from collections import Counter

# %% [markdown]
# Base: https://medium.com/@adriensieg/text-similarities-da019229c894

# %% [markdown]
# REF:
#
# https://arxiv.org/pdf/1301.3781.pdf
#
# https://www.aclweb.org/anthology/N19-1181.pdf
#
# http://proceedings.mlr.press/v37/kusnerb15.pdf
#
# https://static.googleusercontent.com/media/research.google.com/en//pubs/archive/37842.pdf
#
# https://arxiv.org/pdf/1609.08144.pdf

# %%
#df = pd.read_csv(r"C:\Users\hirom\OneDrive - NOVAIMS\NOVA IMS\OneDrive_1_25-02-2021\Text Mining\Project\corpus\de-en\scores.csv")
df = pd.read_csv(r"C:\Users\hirom\Documents\GitHub\textmining_project\test\de-en\scores.csv")
df
# Out:
#                                                   source  \
# 0      Das Publikum ist fast gleichmäßig zwischen Sch...
# 1      Du kannst ihre Energie durch den Bildschirm sp...
# 2      Da die Adresse unbekannt ist, wird die Mithilf...
# 3      Arsenal-Manager Arsene Wenger, dessen Verein i...
# 4      Landwirtschaftsminister im Interview - Wie sch...
# ...                                                  ...
# 28399  Insgesamt gebe es jedoch seit rund 30 Jahren e...
# 28400  Wir können froh sein, dass wir diese Zeit läng...
# 28401  Der unheilbare Zustand, der in den USA rund 1,...
# 28402  "Komfort Check-in" nennt die Bahn die Fahrkart...
# 28403  Anleger erreichen Renditen, wenn ihre Portfoli...
#
#                                                reference  \
# 0      The audience is almost evenly split between bl...
# 1       You can feel their energy through the screen. ""
# 2      As the address is unknown, the help of the pop...
# 3      Arsenal manager Arsene Wenger, whose club is o...
# 4      Agriculture Minister in the interview - How do...
# ...                                                  ...
# 28399  Total, however, there were approximately 30 ye...
# 28400  We can be glad we have overcome these time alr...
# 28401  The condition of unheilbare, which affects the...
# 28402  "Check-in amenities," the rail operator descri...
# 28403  Investors reach valuations if their Portfolio-...
#
#                                              translation
# 0      The audience is almost evenly split between bl...
# 1           You can feel her energy through the screen."
# 2      As the address is unknown, the assistance of t...
# 3      Arsenal manager Arsene Wenger, whose club is o...
# 4      Minister of Agriculture in interview – How do ...
# ...                                                  ...
# 28399  Nevertheless, altogether, there have been a se...
# 28400  We can be glad that we have long overcome this...
# 28401  The incurable condition, which affects around ...
# 28402  The railway is calling this conductorless tick...
# 28403  Investors achieve returns when their portfolio...
#
# [28404 rows x 3 columns]

# %% [markdown]
# ## Preprocessing

# %%
def preprocessing2(sentence):
    return " ".join(re.sub(r'[^a-zA-Z]',' ',w).lower() for w in sentence.split() if re.sub(r'[^a-zA-Z]',' ',w).lower() not in chachedWords)

# %%
df['p_reference'] = df.apply(lambda x:preprocessing2(x['reference']),axis=1)

# %%
df['p_translation'] = df.apply(lambda x:preprocessing2(x['translation']),axis=1)

# %%
def delete_sw(sentence):
    stop_words = stopwords.words('english')
    processed = sentence.split()
    clean = [w for w in processed if w not in chachedWords]
    return clean

# %%
df_cp = df.copy()

# %%
df_cp['w_reference'] = df_cp.apply(lambda x:delete_sw(x['p_reference']),axis=1)

# %%
df_cp['w_translation'] = df_cp.apply(lambda x:delete_sw(x['p_translation']),axis=1)

# %% [markdown]
# ## Embedding
#
# https://www.analyticsvidhya.com/blog/2020/08/top-4-sentence-embedding-techniques-using-python/
#
# Doc2Vec

# %%
# import
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(df_cp['w_translation'])]
tagged_data
# Out:
# C:\Users\hirom\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# [TaggedDocument(words=['audience', 'almost', 'evenly', 'split', 'black', 'white'], tags=[0]),
#  TaggedDocument(words=['feel', 'energy', 'screen'], tags=[1]),
#  TaggedDocument(words=['address', 'unknown', 'assistance', 'population', 'requested', 'hoped'], tags=[2]),
#  TaggedDocument(words=['arsenal', 'manager', 'arsene', 'wenger', 'whose', 'club', 'owned', 'american', 'sports', 'tycoon', 'shares', 'la', 'liga', 'reservations', 'state', 'funding', 'club'], tags=[3]),
#  TaggedDocument(words=['minister', 'agriculture', 'interview', 'protect', 'poisoned', 'eggs', 'mr', 'schmidt'], tags=[4]),
#  TaggedDocument(words=['audi', 'modify', 'diesel', 'vehicles', 'carmakers', 'face', 'backlash'], tags=[5]),
#  TaggedDocument(words=['galerie', 'suit', 'bitburg'], tags=[6]),
#  TaggedDocument(words=['blue', 'business', 'survey', 'filled', 'business', 'premises', 'operate', 'building'], tags=[7]),
#  TaggedDocument(words=['earlier', 'year', 'french', 'journalists', 'franck', 'escudie', 'basille', 'longchamp', 'deported', 'papua', 'lack', 'coordination', 'related', 'institutions', 'despite', 'granted', 'rare', 'permission', 'film'], tags=[8]),
#  TaggedDocument(words=['directly', 'linking', 'kitchen', 'staff', 'team', 'makes', 'sense'], tags=[9]),
#  TaggedDocument(words=['hundred', 'yards', 'back', 'group', 'four', 'dozen', 'spectators', 'wipe', 'sweat', 'tears', 'away', 'eyes'], tags=[10]),
#  TaggedDocument(words=['ten', 'pieces', 'nota', 'cost', 'indonesian', 'rupiah', 'cents'], tags=[11]),
#  TaggedDocument(words=['one', 'hopes', 'afforestation', 'area', 'could', 'drawn', 'long'], tags=[12]),
#  TaggedDocument(words=['latter', 'said', 'thursday', 'regarded', 'new', 'rules', 'unnecessary', 'acceptable', 'would', 'involve', 'significant', 'change', 'impediment', 'rescue', 'operations'], tags=[13]),
#  TaggedDocument(words=['epa', 'reversal', 'following', 'lawsuits', 'important', 'win', 'health', 'safety', 'million', 'new', 'yorkers', 'million', 'americans', 'directly', 'impacted', 'smog', 'pouring', 'communities', 'schneiderman', 'said'], tags=[14]),
#  TaggedDocument(words=['trump', 'great', 'feat'], tags=[15]),
#  TaggedDocument(words=['high', 'proportion', 'cases', 'judged', 'necessarily', 'mean', 'asylum', 'seeker', 'lied', 'age'], tags=[16]),
#  TaggedDocument(words=['continuity', 'important', 'good', 'working', 'atmosphere', 'also', 'future', 'design', 'city'], tags=[17]),
#  TaggedDocument(words=['old', 'rules', 'others', 'say', 'longer', 'apply', 'sinaloa', 'tamaulipas', 'veracruz', 'guerrero', 'states', 'home', 'toxic', 'mix', 'lucrative', 'smuggling', 'routes', 'weak', 'institutions', 'corrupt', 'government', 'officials'], tags=[18]),
#  TaggedDocument(words=['second', 'day', 'went', 'bad', 'rkheim', 'salt', 'works', 'wurstmarkt', 'festival'], tags=[19]),
#  TaggedDocument(words=['tc', 'blau', 'weiss', 'neuss', 'competing', 'tomorrow', 'kiel', 'third', 'table', 'suchsdorfer', 'sv'], tags=[20]),
#  TaggedDocument(words=['protecting', 'shareholders', 'employment', 'litigation'], tags=[21]),
#  TaggedDocument(words=['defence', 'minister', 'von', 'der', 'leyen', 'described', 'killed', 'soldiers', 'highly', 'decorated', 'experienced', 'missions'], tags=[22]),
#  TaggedDocument(words=['gave', 'rise', 'speculations', 'whether', 'trump', 'wanted', 'dismiss', 'mueller'], tags=[23]),
#  TaggedDocument(words=['addition', 'munich', 'team', 'missing', 'manuel', 'neuer', 'james', 'thiago', 'jerome', 'boateng', 'arjen', 'robben', 'juan', 'bernat'], tags=[24]),
#  TaggedDocument(words=['highly', 'unjust', 'make', 'media', 'scapegoat', 'man', 'prominent', 'even', 'prominent', 'brother'], tags=[25]),
#  TaggedDocument(words=['iteration', 'story', 'simultaneously', 'nostalgic', 'characters', 'glory', 'days', 'grunge', 'era', 'around', 'masterminds', 'david', 'wain', 'michael', 'showalter', 'made', 'sketch', 'comedy', 'state', 'mtv', 'stars', 'like', 'elizabeth', 'banks', 'amy', 'poehler', 'paul', 'rudd', 'went', 'bigger', 'things'], tags=[26]),
#  TaggedDocument(words=['rascona', 'asked'], tags=[27]),
#  TaggedDocument(words=['players', 'enrolled', 'summer', 'classes', 'head', 'back', 'dorms', 'three', 'hour', 'practice', 'study', 'final', 'exams', 'returning', 'wasserman', 'football', 'center', 'meetings', 'following', 'morning'], tags=[28]),
#  TaggedDocument(words=['however', 'important', 'always', 'advertising', 'effect', 'chocolate', 'producer', 'prestigious', 'contract'], tags=[29]),
#  TaggedDocument(words=['really', 'special', 'time', 'one', 'always', 'cherish'], tags=[30]),
#  TaggedDocument(words=['leader', 'mob', 'middle', 'aged', 'man', 'pinstriped', 'suit', 'took', 'long', 'drag', 'cigar', 'peered', 'windshield'], tags=[31]),
#  TaggedDocument(words=['stories', 'rooted', 'firmly', 'history', 'castle', 'priest', 'tells', 'tale', 'jesuit', 'priest', 'darrell', 'family', 'hid', 'seven', 'years', 'english', 'reformation'], tags=[32]),
#  TaggedDocument(words=['psg', 'warn', 'barcelona', 'move', 'neymar', 'three', 'years', 'ago'], tags=[33]),
#  TaggedDocument(words=['precisely', 'reason', 'crucially', 'important', 'occurrences', 'thoroughly', 'cleared', 'passed', 'public', 'prosecutors', 'cases', 'crimes', 'could', 'committed'], tags=[34]),
#  TaggedDocument(words=['played', 'part', 'head', 'klansman', 'years', 'said', 'role', 'never', 'gets', 'easier'], tags=[35]),
#  TaggedDocument(words=['real', 'football', 'deal', 'particular', 'year', 'olds', 'young', 'people', 'still', 'go', 'stadium', 'future', 'says', 'year', 'old'], tags=[36]),
#  TaggedDocument(words=['police', 'idea', 'whereabouts', 'efforts', 'locate', 'intensifying', 'guglielmi', 'said'], tags=[37]),
#  TaggedDocument(words=['travellers', 'negotiate', 'trench', 'return', 'millionaire', 'row'], tags=[38]),
#  TaggedDocument(words=['interview', 'domspatzen', 'report', 'exonerates', 'pope', 'brother', 'georg', 'ratzinger'], tags=[39]),
#  TaggedDocument(words=['west', 'antarctic', 'gigantic', 'iceberg', 'almost', 'seven', 'times', 'size', 'berlin', 'detached', 'ice', 'shelf'], tags=[40]),
#  TaggedDocument(words=['steg', 'represented', 'wednesday', 'evening', 'martin', 'keller', 'gaby', 'pietzschmann', 'sarah', 'gotzel'], tags=[41]),
#  TaggedDocument(words=['head', 'iaaf', 'task', 'force', 'rune', 'andersen', 'said', 'monday', 'russia', 'yet', 'meet', 'several', 'criteria', 'reinstatement'], tags=[42]),
#  TaggedDocument(words=['red', 'meat', 'dairy', 'chocolate', 'could', 'help', 'relieve', 'ibd'], tags=[43]),
#  TaggedDocument(words=['order', 'use', 'however', 'conditions', 'must', 'met', 'need', 'smartphone', 'tablet'], tags=[44]),
#  TaggedDocument(words=['city', 'operates', 'nurseries', 'district', 'krefeld', 'children', 'get', 'warm', 'meal', 'midday'], tags=[45]),
#  TaggedDocument(words=['assume', 'task', 'falls', 'journalist', 'either', 'play', 'dumb'], tags=[46]),
#  TaggedDocument(words=['afd', 'event', 'lasts', 'little', 'hour', 'guests', 'forecourt', 'long', 'wind', 'even', 'time', 'clear', 'shortly', 'pm'], tags=[47]),
#  TaggedDocument(words=['jose', 'mourinho', 'thinks', 'manchester', 'united', 'signed', 'genius', 'nemanja', 'matic'], tags=[48]),
#  TaggedDocument(words=['married', 'father', 'one', 'technology', 'fitted', 'home', 'bmw', 'z', 'starts', 'hand', 'wheel'], tags=[49]),
#  TaggedDocument(words=['youngest', 'husband', 'four', 'wives', 'assigned', 'fields', 'tend'], tags=[50]),
#  TaggedDocument(words=['years', 'st', 'hilarius', 'church', 'mark', 'anniversary', 'mountain', 'church', 'invitations', 'issued', 'serenade', 'old', 'cemetery', 'grounds', 'tumlingen', 'sunday', 'th', 'july', 'pm'], tags=[51]),
#  TaggedDocument(words=['making', 'city', 'liveable'], tags=[52]),
#  TaggedDocument(words=['want', 'carry', 'living', 'said', 'time', 'cpj', 'award'], tags=[53]),
#  TaggedDocument(words=['people', 'therefore', 'also', 'lived'], tags=[54]),
#  TaggedDocument(words=['michael', 'hesemann', 'indeed', 'big', 'problem', 'coverage', 'everything', 'mixed', 'confounded', 'huge', 'melange', 'sexual', 'abuse', 'acts', 'extreme', 'violence', 'somewhere', 'middle', 'georg', 'ratzinger'], tags=[55]),
#  TaggedDocument(words=['football', 'also', 'tactics', 'strategy', 'personality', 'motivation'], tags=[56]),
#  TaggedDocument(words=['designed', 'make', 'age', 'assessment', 'asylum', 'process', 'accurate', 'swedish', 'migration', 'agency', 'migrationsverket', 'criticized', 'failings', 'assessing', 'correct', 'age', 'refugees', 'claiming', 'underage'], tags=[57]),
#  TaggedDocument(words=['construction', 'common', 'room', 'would', 'eligible', 'financial', 'support', 'reports', 'tjaden', 'per', 'cent', 'per', 'cent'], tags=[58]),
#  TaggedDocument(words=['else', 'could'], tags=[59]),
#  TaggedDocument(words=['anyone', 'wishes', 'take', 'roland', 'wacker', 'according', 'city', 'haslach', 'able', 'demonstrate', 'completed', 'studies', 'graduate', 'engineer', 'bachelors', 'degree', 'specialisation', 'architecture', 'good', 'specialist', 'knowledge', 'fields', 'building', 'regulations', 'planning', 'laws'], tags=[60]),
#  TaggedDocument(words=['later', 'audience', 'sits', 'dinner', 'actors'], tags=[61]),
#  TaggedDocument(words=['wants', 'jokowi', 'know', 'paniai', 'people', 'aside', 'living', 'looming', 'threat', 'rapacious', 'military', 'wallow', 'destitution', 'paltry', 'education', 'health', 'services'], tags=[62]),
#  TaggedDocument(words=['nothing', 'routine', 'turkish', 'armed', 'forces', 'one', 'year', 'coup', 'attempt'], tags=[63]),
#  TaggedDocument(words=['burying', 'bodies', 'military', 'came', 'looking', 'says'], tags=[64]),
#  TaggedDocument(words=['record', 'riot', 'happening', 'castle', 'book', 'called', 'knightly', 'families', 'kent', 'sussex', 'says', 'rhodes'], tags=[65]),
#  TaggedDocument(words=['hilarius', 'cemetery', 'tumlingen', 'served', 'last', 'place', 'rest', 'h', 'rschweiler', 'dead'], tags=[66]),
#  TaggedDocument(words=['last', 'summer', 'raft', 'travelled', 'isar', 'already', 'year', 'campaigns', 'measures', 'bring', 'thoughtful', 'environmentally', 'aware', 'behaviour'], tags=[67]),
#  TaggedDocument(words=['panicked', 'afraid', 'revenge', 'year', 'old', 'dominggu', 'badii', 'lives', 'near', 'hospital', 'witnessed', 'injured', 'hurried', 'tells', 'time'], tags=[68]),
#  TaggedDocument(words=['clearly', 'murders', 'chilling', 'effect'], tags=[69]),
#  TaggedDocument(words=['first', 'glance', 'looks', 'like', 'statue', 'albeit', 'terrifying', 'one'], tags=[70]),
#  TaggedDocument(words=['months', 'since', 'reporters', 'gone', 'mountainous', 'countryside', 'drug', 'gangs', 'de', 'facto', 'control'], tags=[71]),
#  TaggedDocument(words=['space', 'left', 'covered', 'market', 'thanks', 'crazily', 'large', 'number', 'see', 'pointless', 'construction', 'projects', 'bitburg'], tags=[72]),
#  TaggedDocument(words=['prime', 'minister', 'weil', 'wants', 'snap', 'new', 'election'], tags=[73]),
#  TaggedDocument(words=['small', 'number', 'trial', 'customers', 'use', 'new', 'service', 'yet'], tags=[74]),
#  TaggedDocument(words=['past', 'months', 'part', 'pilot', 'operation', 'tests', 'see', 'whether', 'line', 'gets', 'used', 'large', 'enough', 'number', 'people', 'continue', 'commissioned', 'normal', 'future'], tags=[75]),
#  TaggedDocument(words=['zones', 'said', 'prevent', 'asparagusisation', 'landscape'], tags=[76]),
#  TaggedDocument(words=['special', 'adviser', 'ty', 'cobb', 'explained', 'statement', 'knew', 'nothing', 'convening', 'grand', 'jury'], tags=[77]),
#  TaggedDocument(words=['sold', 'million'], tags=[78]),
#  TaggedDocument(words=['eye', 'bigger', 'picture', 'many', 'others', 'busied'], tags=[79]),
#  TaggedDocument(words=['according', 'department', 'defense', 'hourly', 'rates', 'fiscal', 'year', 'dod', 'reimbursement', 'rate', 'vh', 'per', 'flight', 'hour'], tags=[80]),
#  TaggedDocument(words=['joining', 'trio', 'field', 'former', 'masters', 'winner', 'ian', 'woosnam', 'senior', 'major', 'champions', 'paul', 'broadhurst', 'roger', 'chapman', 'mark', 'james', 'mark', 'mcnulty'], tags=[81]),
#  TaggedDocument(words=['roxxxy', 'gold', 'sex', 'robots', 'developed', 'true', 'companion', 'come', 'pre', 'programmed', 'personalities', 'including', 'frigid', 'farrah', 'gives', 'impression', 'shyness', 'wild', 'wendy', 'adventurous', 'personality'], tags=[82]),
#  TaggedDocument(words=['however', 'district', 'lacking', 'additional', 'personnel', 'needs', 'overcome', 'growing', 'demands', 'duties'], tags=[83]),
#  TaggedDocument(words=['respect', 'clubs'], tags=[84]),
#  TaggedDocument(words=['get', 'car'], tags=[85]),
#  TaggedDocument(words=['recent', 'months', 'constant', 'arguments', 'future', 'rennsteig', 'shuttle', 'said', 'moving', 'quickly'], tags=[86]),
#  TaggedDocument(words=['type', 'murder', 'become', 'used', 'call', 'typical'], tags=[87]),
#  TaggedDocument(words=['politely', 'commented', 'disappointed', 'lack', 'response', 'hate', 'crimes', 'recent', 'news', 'items', 'wrote', 'comment', 'section', 'post', 'news', 'story'], tags=[88]),
#  TaggedDocument(words=['fire', 'ripped', 'one', 'world', 'tallest', 'residential', 'towers', 'dubai', 'friday', 'forcing', 'hundreds', 'occupants', 'flee', 'metre', 'tall', 'storey', 'structure'], tags=[89]),
#  TaggedDocument(words=['modern', 'sex', 'dolls', 'evolved', 'robots', 'silicon', 'skin'], tags=[90]),
#  TaggedDocument(words=['among', 'hesse', 'prime', 'minister', 'volker', 'bouffier', 'cdu', 'inspector', 'general', 'german', 'army', 'volker', 'wieker'], tags=[91]),
#  TaggedDocument(words=['one', 'soldiers', 'took', 'umbrage', 'tone', 'later', 'returned', 'four', 'soldiers', 'according', 'local', 'pastor', 'yavedt', 'tebai'], tags=[92]),
#  TaggedDocument(words=['one', 'day', 'getting', 'sued', 'states', 'environmental', 'protection', 'agency', 'chief', 'scott', 'pruitt', 'reversed', 'earlier', 'decision', 'delay', 'implementation', 'obama', 'era', 'rules', 'reducing', 'emissions', 'smog', 'causing', 'air', 'pollutants'], tags=[93]),
#  TaggedDocument(words=['compared', 'rest', 'europe', 'germany', 'lagging', 'behind', 'declares', 'vfb', 'board', 'member', 'r', 'ttgermann'], tags=[94]),
#  TaggedDocument(words=['mild', 'moderate', 'injuries', 'said', 'police', 'spokesperson'], tags=[95]),
#  TaggedDocument(words=['time', 'alberta', 'warm', 'south', 'florida', 'today', 'rivers', 'oceans', 'likely', 'spread', 'far', 'inland'], tags=[96]),
#  TaggedDocument(words=['fact', 'paniai', 'suffered', 'nadir', 'two', 'months', 'jokowi', 'october', 'inauguration'], tags=[97]),
#  TaggedDocument(words=['often', 'case', 'one', 'fellow', 'passengers', 'documentation', 'one', 'needs', 'validate', 'online', 'ticket'], tags=[98]),
#  TaggedDocument(words=['farmers', 'thus', 'left', 'euros', 'invest', 'kilometre', 'pasture', 'fence'], tags=[99]),
#  TaggedDocument(words=['pair', 'posed', 'photos', 'lomachenko', 'manager', 'egis', 'klimas', 'noted', 'potential', 'showdown', 'fighters', 'would', 'perfect', 'sizing'], tags=[100]),
#  TaggedDocument(words=['report', 'comes', 'quite', 'clear', 'conclusion', 'affected', 'pupils', 'around', 'confided', 'beforehand', 'could', 'confirmed', 'within', 'scope', 'investigation'], tags=[101]),
#  TaggedDocument(words=['making', 'mitt', 'romney', 'seem', 'epitome', 'common', 'sense'], tags=[102]),
#  TaggedDocument(words=['ministry', 'foreign', 'affairs', 'reported', 'btv', 'bulgarians', 'later', 'released'], tags=[103]),
#  TaggedDocument(words=['think', 'get', 'saturday', 'time', 'really', 'great'], tags=[104]),
#  TaggedDocument(words=['silence', 'critics'], tags=[105]),
#  TaggedDocument(words=['anyone', 'needs', 'lift', 'kaiseringen', 'frohnstetten', 'meeting', 'point', 'kaiseringen', 'school'], tags=[106]),
#  TaggedDocument(words=['computer', 'keyboard', 'headphones', 'lay', 'next', 'severed', 'head'], tags=[107]),
#  TaggedDocument(words=['especially', 'one', 'compares', 'current', 'online', 'maps'], tags=[108]),
#  TaggedDocument(words=['ignorance', 'car', 'drivers', 'around', 'red', 'lights', 'barriers', 'really', 'huge', 'reports', 'heinze'], tags=[109]),
#  TaggedDocument(words=['care', 'care'], tags=[110]),
#  TaggedDocument(words=['metre', 'wide', 'bridge', 'parapet', 'put', 'place', 'south', 'part', 'bridge', 'friday'], tags=[111]),
#  TaggedDocument(words=['frenchman', 'currently', 'still', 'active', 'challenger', 'tournament', 'italian', 'biella', 'make', 'bundesliga', 'match', 'zdenek', 'kolar', 'czech', 'playing', 'tournament', 'liberec', 'czech', 'republic', 'called', 'action', 'first', 'time', 'season'], tags=[112]),
#  TaggedDocument(words=['checks', 'continue', 'throughout', 'season'], tags=[113]),
#  TaggedDocument(words=['roster', 'famous', 'voice', 'actors', 'among', 'jenny', 'slate', 'nick', 'offerman', 'mahershala', 'ali', 'chlo', 'sevigny', 'makes', 'decent', 'game', 'spot', 'voice'], tags=[114]),
#  TaggedDocument(words=['taking', 'place', 'legal', 'grey', 'zone', 'every', 'one', 'us', 'well', 'knows'], tags=[115]),
#  TaggedDocument(words=['eggs', 'proven', 'contain', 'fipronil', 'stacked', 'onto', 'shelves'], tags=[116]),
#  TaggedDocument(words=['mid', 'colin', 'wrote', 'one', 'court', 'filing', 'tried', 'accommodate', 'brother', 'requests'], tags=[117]),
#  TaggedDocument(words=['prep', 'targeted', 'properly', 'need', 'risk', 'offers', 'possibility', 'transforming', 'english', 'hiv', 'epidemic'], tags=[118]),
#  TaggedDocument(words=['wild', 'ferrell', 'thought'], tags=[119]),
#  TaggedDocument(words=['within', 'large', 'overview', 'map', 'worked', 'detailed', 'maps', 'towns', 'municipalities', 'called', 'original', 'lay', 'land', 'sheets'], tags=[120]),
#  TaggedDocument(words=['way', 'much', 'closely', 'involved', 'easier', 'nursery', 'head', 'put', 'educational', 'concepts', 'place'], tags=[121]),
#  TaggedDocument(words=['first', 'however', 'stocktaking', 'carried', 'september', 'year', 'part', 'stake', 'regeneration', 'area', 'receive', 'survey', 'fill'], tags=[122]),
#  TaggedDocument(words=['addition', 'wissing', 'said', 'sympathetic', 'ear', 'people', 'want', 'found', 'company', 'ihk', 'applauded'], tags=[123]),
#  TaggedDocument(words=['regularly', 'hear', 'many', 'former', 'domspatzen', 'still', 'today', 'keep', 'regular', 'contact', 'years', 'retirement', 'visit', 'read', 'almost', 'blind', 'treat', 'like', 'member', 'family'], tags=[124]),
#  TaggedDocument(words=['even', 'back', 'washington', 'anonymous', 'trolls'], tags=[125]),
#  TaggedDocument(words=['well', 'preserved', 'even', 'able', 'determine', 'colour', 'scaly', 'skin', 'reddish', 'brown', 'say', 'something', 'troubled', 'past'], tags=[126]),
#  TaggedDocument(words=['according', 'fbi', 'files', 'obtained', 'nbc', 'news', 'men', 'monroe', 'surrounding', 'counties', 'suspected', 'lynching'], tags=[127]),
#  TaggedDocument(words=['government', 'said', 'working', 'providing', 'shelter', 'affected'], tags=[128]),
#  TaggedDocument(words=['point', 'even', 'capacity', 'longer', 'enough', 'reason', 'district', 'mental', 'asylum', 'haar', 'constructed'], tags=[129]),
#  TaggedDocument(words=['prep', 'trial', 'drug', 'procured', 'well', 'way', 'protecting', 'people', 'risk', 'hiv'], tags=[130]),
#  TaggedDocument(words=['disturbing', 'much', 'pressure', 'took', 'get', 'commonsense', 'step', 'guy', 'charge', 'protecting', 'air', 'breathe', 'said', 'lori', 'ann', 'burd', 'center', 'biological', 'diversity'], tags=[131]),
#  TaggedDocument(words=['michael', 'hesemann', 'quite', 'clearly'], tags=[132]),
#  TaggedDocument(words=['help', 'ready', 'sooner', 'rather', 'later'], tags=[133]),
#  TaggedDocument(words=['end', 'august', 'climax', 'campaign', 'festival', 'island', 'grafenwerth'], tags=[134]),
#  TaggedDocument(words=['consciously', 'decided', 'give', 'statement', 'parliamentary', 'group'], tags=[135]),
#  TaggedDocument(words=['difficult', 'count', 'number', 'victims', 'incidents', 'happen', 'every', 'week', 'says', 'andreas', 'harsono', 'indonesia', 'researcher', 'human', 'rights', 'watch'], tags=[136]),
#  TaggedDocument(words=['nostalgia', 'goes', 'niche', 'wet', 'hot', 'american', 'summer', 'comrade', 'detective'], tags=[137]),
#  TaggedDocument(words=['title', 'defender', 'missing', 'seven', 'pros', 'super', 'cup', 'cup', 'winners'], tags=[138]),
#  TaggedDocument(words=['since', 'guzman', 'arrest', 'last', 'year', 'extradition', 'united', 'states', 'january', 'sinaloa', 'one', 'country', 'bloodiest', 'battlegrounds', 'rival', 'factions', 'fight', 'fill', 'vacuum'], tags=[139]),
#  TaggedDocument(words=['ford', 'mercury', 'passed', 'group', 'onlookers', 'rural', 'monroe', 'georgia', 'rumbled', 'toward', 'small', 'moore', 'ford', 'bridge'], tags=[140]),
#  TaggedDocument(words=['order', 'ensure', 'stability', 'road', 'safety', 'three', 'structures', 'thoroughly', 'renovated'], tags=[141]),
#  TaggedDocument(words=['confused', 'noticing', 'one', 'else', 'feed', 'posted', 'information', 'closed', 'facebook', 'opened', 'twitter'], tags=[142]),
#  TaggedDocument(words=['victor', 'ken', 'marino', 'still', 'lost', 'virginity'], tags=[143]),
#  TaggedDocument(words=['long', 'tail', 'antarctica', 'stretches', 'towards', 'south', 'america'], tags=[144]),
#  TaggedDocument(words=['spectators', 'game', 'sold', 'shared', 'german', 'football', 'league', 'dfl', 'friday'], tags=[145]),
#  TaggedDocument(words=['helps', 'passes', 'committee', 'unanimously'], tags=[146]),
#  TaggedDocument(words=['stephen', 'milling', 'sings', 'part', 'superbly', 'nasty', 'hagen', 'aura', 'heavy', 'weight', 'boxer'], tags=[147]),
#  TaggedDocument(words=['postcards', 'sought', 'criminals', 'eu', 'countries', 'assembled'], tags=[148]),
#  TaggedDocument(words=['sirens', 'wailed', 'nearby', 'another', 'shootout', 'area'], tags=[149]),
#  TaggedDocument(words=['results', 'presented', 'international', 'olympic', 'committee', 'ioc', 'wada', 'near', 'future', 'added'], tags=[150]),
#  TaggedDocument(words=['agreement', 'late', 'father', 'colin', 'described', 'paul', 'major', 'driving', 'force', 'dominant', 'personality', 'de', 'lutis', 'family', 'owns', 'two', 'thirds', 'company', 'assets', 'paul', 'one', 'third'], tags=[151]),
#  TaggedDocument(words=['mr', 'roy', 'sister', 'camdyn', 'roy', 'testified', 'haunted', 'realisation', 'would', 'never', 'attend', 'brother', 'wedding', 'aunt', 'children'], tags=[152]),
#  TaggedDocument(words=['wednesday', 'morning', 'black', 'forest', 'baar', 'district', 'numerous', 'properties', 'searched', 'rottweil', 'konstanz', 'esslingen', 'stuttgart', 'said', 'konstanz', 'public', 'prosecutor', 'office', 'friday'], tags=[153]),
#  TaggedDocument(words=['led', 'four', 'powerful', 'godfathers', 'operate', 'like', 'fortune', 'company', 'government', 'bribes', 'violent', 'actions'], tags=[154]),
#  TaggedDocument(words=['fight', 'could', 'pay', 'per', 'view', 'fans', 'asking', 'garcia', 'said', 'later', 'expressing', 'openness', 'fighting', 'whatever', 'network', 'offers', 'best', 'financial', 'package'], tags=[155]),
#  TaggedDocument(words=['earth', 'thus', 'shrinks', 'ball', 'diameter', 'millimetres', 'sun', 'standing', 'exactly', 'metres', 'away', 'measures', 'centimetres'], tags=[156]),
#  TaggedDocument(words=['common', 'items', 'whisked', 'past', 'tsa', 'agents', 'purpose', 'food', 'liquids'], tags=[157]),
#  TaggedDocument(words=['wonderful', 'place', 'play', 'golf'], tags=[158]),
#  TaggedDocument(words=['president', 'international', 'tennis', 'federation', 'failed', 'big', 'davis', 'cup', 'coup', 'general', 'assembly'], tags=[159]),
#  TaggedDocument(words=['representatives', 'fischerbach', 'local', 'cdu', 'group', 'met', 'mayor', 'thomas', 'schneider', 'two', 'representatives', 'rechtgrabenhof', 'farm', 'belonging', 'schwendemann', 'family'], tags=[160]),
#  TaggedDocument(words=['would', 'already', 'known', 'happened', 'said', 'villarreal', 'nicknamed', 'el', 'flaco', 'slender', 'build'], tags=[161]),
#  TaggedDocument(words=['far', 'possible', 'arrest', 'sought', 'online', 'least', 'due', 'tips', 'following', 'publication', 'internet', 'site'], tags=[162]),
#  TaggedDocument(words=['already', 'day', 'coup', 'erdogan', 'described', 'attempt', 'overthrow', 'gift', 'god', 'since', 'gives', 'opportunity', 'completely', 'cleanse', 'armed', 'forces'], tags=[163]),
#  TaggedDocument(words=['going', 'worry', 'much'], tags=[164]),
#  TaggedDocument(words=['rhodes', 'arrived', 'decade', 'later', 'staff', 'starting', 'tackle', 'archive', 'describes', 'hundreds', 'years', 'aristocrats', 'going', 'oh', 'stick', 'loft'], tags=[165]),
#  TaggedDocument(words=['rapturous', 'reception', 'foster', 'milling', 'vinke', 'conductor', 'janowski', 'effaces', 'bows', 'hands', 'forming', 'merkel', 'diamond'], tags=[166]),
#  TaggedDocument(words=['support', 'coordination', 'count', 'years', 'old', 'colleagues', 'markus', 'neumaier', 'building', 'construction', 'ten', 'years', 'manfred', 'sch', 'ner', 'civil', 'engineering', 'already', 'years'], tags=[167]),
#  TaggedDocument(words=['warren', 'senior', 'treasury', 'assistant', 'oxford', 'university'], tags=[168]),
#  TaggedDocument(words=['meanwhile', 'back', 'ferguson', 'news', 'cameras', 'long', 'gone', 'fraught', 'racial', 'ties', 'community', 'police', 'persist'], tags=[169]),
#  TaggedDocument(words=['work', 'fun'], tags=[170]),
#  TaggedDocument(words=['connections', 'ice', 'dortmund', 'stuttgart', 'ice', 'stuttgart', 'essen'], tags=[171]),
#  TaggedDocument(words=['materials', 'things', 'touch', 'therefore', 'help', 'create', 'emotional', 'bond', 'home', 'says', 'erfan'], tags=[172]),
#  TaggedDocument(words=['sports', 'stars', 'future', 'sit', 'front', 'computer', 'consoles', 'instead', 'battling', 'sweatily', 'come', 'wind', 'rain', 'stadium', 'turf'], tags=[173]),
#  TaggedDocument(words=['court', 'filing', 'says', 'translates', 'colin', 'owning', 'property', 'worth', 'million', 'paul', 'million'], tags=[174]),
#  TaggedDocument(words=['consumers', 'right', 'get', 'safe', 'food', 'approved', 'market'], tags=[175]),
#  TaggedDocument(words=['construction', 'works', 'bridge', 'east', 'entrance', 'town', 'lauterbach', 'road', 'area', 'bridge', 'tannenhof', 'sieben', 'linden', 'hotels', 'fully', 'closed'], tags=[176]),
#  TaggedDocument(words=['surest', 'mark', 'regime', 'change', 'start', 'attacking', 'statues'], tags=[177]),
#  TaggedDocument(words=['little', 'million', 'euros', 'reckons'], tags=[178]),
#  TaggedDocument(words=['clear', 'case', 'financial', 'doping', 'club', 'state', 'la', 'liga', 'president', 'javier', 'tebas', 'told', 'spanish', 'newspaper', 'referring', 'qatar', 'ultimate', 'ownership', 'psg'], tags=[179]),
#  TaggedDocument(words=['really', 'enjoyed', 'playing', 'played', 'solid', 'golf'], tags=[180]),
#  TaggedDocument(words=['haste', 'pass', 'legislation', 'congress', 'packed', 'unconstitutional', 'provisions', 'griped'], tags=[181]),
#  TaggedDocument(words=['memories', 'last', 'year', 'coming', 'back', 'special', 'wife', 'sharon', 'win', 'last', 'year'], tags=[182]),
#  TaggedDocument(words=['garcia', 'victory', 'unanimous', 'decision', 'former', 'four', 'division', 'world', 'champion', 'adrien', 'broner', 'saturday', 'showtime', 'fighters', 'members', 'top', 'five', 'pound', 'pound', 'list'], tags=[183]),
#  TaggedDocument(words=['year', 'old', 'estefan', 'stressed', 'would', 'use', 'conversation', 'trump', 'make', 'point', 'view', 'clear'], tags=[184]),
#  TaggedDocument(words=['survived', 'long', 'friends', 'colleagues', 'assumed', 'always'], tags=[185]),
#  TaggedDocument(words=['duel', 'two', 'german', 'football', 'heavyweights', 'captivating', 'fans'], tags=[186]),
#  TaggedDocument(words=['likes', 'country', 'worked', 'last', 'years'], tags=[187]),
#  TaggedDocument(words=['actually', 'official', 'controls', 'exposed', 'going'], tags=[188]),
#  TaggedDocument(words=['deutsche', 'bahn', 'currently', 'trialling', 'conductorless', 'ticket', 'inspection'], tags=[189]),
#  TaggedDocument(words=['thought', 'get', 'weirder', 'along', 'comes', 'new', 'report', 'technological', 'developments', 'sex', 'robot', 'sector'], tags=[190]),
#  TaggedDocument(words=['trial', 'designed', 'assess', 'full', 'potential', 'prep', 'gathering', 'clinical', 'evidence', 'targeted', 'taken', 'implemented', 'large', 'scale'], tags=[191]),
#  TaggedDocument(words=['contemporary', 'resonance', 'lazarus', 'startling', 'words', 'ones', 'state', 'appeared', 'invite', 'old', 'immigrants', 'poorest', 'poor', 'tired', 'poor', 'huddled', 'masses', 'yearning', 'breathe', 'free', 'wretched', 'refuse', 'teeming', 'shore'], tags=[192]),
#  TaggedDocument(words=['researchers', 'studied', 'named', 'beast', 'borealopelta', 'markmitchelli', 'museum', 'technician', 'mark', 'mitchell', 'one', 'team', 'spent', 'hours', 'painstakingly', 'uncovering'], tags=[193]),
#  TaggedDocument(words=['photos', 'police', 'tape', 'people', 'yelling', 'guy', 'claiming', 'brown', 'father', 'holding', 'sign', 'read', 'ferguson', 'police', 'killed', 'unarmed', 'son'], tags=[194]),
#  TaggedDocument(words=['according', 'johan', 'g', 'ransson', 'forensic', 'medicine', 'agency', 'results', 'consistent', 'previous', 'months'], tags=[195]),
#  TaggedDocument(words=['correspondents', 'say', 'suicide', 'bombings', 'kabul', 'recent', 'weeks', 'also', 'created', 'crisis', 'public', 'confidence', 'government', 'policies', 'particular', 'reputation', 'president', 'ashraf', 'ghani'], tags=[196]),
#  TaggedDocument(words=['follow', 'employees', 'wonder', 'really', 'hear'], tags=[197]),
#  TaggedDocument(words=['completed', 'two', 'week', 'stint', 'finnish', 'wilderness', 'graphic', 'novel', 'el', 'nm', 'ki', 'site', 'early', 'th', 'century', 'sanatorium', 'since', 'reclaimed', 'nature'], tags=[198]),
#  TaggedDocument(words=['trump', 'new', 'chief', 'staff', 'plans', 'restrict', 'president', 'media', 'diet'], tags=[199]),
#  TaggedDocument(words=['chief', 'staff', 'hulusi', 'akar', 'remains', 'office', 'commanders', 'army', 'air', 'force', 'marines', 'removed'], tags=[200]),
#  TaggedDocument(words=['followed', 'viewing', 'spots', 'towers', 'one', 'could', 'look', 'far', 'wide', 'palatinate', 'forest', 'upstream', 'plains'], tags=[201]),
#  TaggedDocument(words=['understood', 'work', 'humanizing', 'black', 'folks', 'level', 'vulnerability'], tags=[202]),
#  TaggedDocument(words=['commissioner', 'napoleon'], tags=[203]),
#  TaggedDocument(words=['sometimes', 'hunted', 'apparently', 'photographer', 'ruben', 'espinosa', 'murdered', 'along', 'four', 'women', 'mexico', 'city', 'apartment', 'three', 'months', 'fleeing', 'veracruz'], tags=[204]),
#  TaggedDocument(words=['according', 'broadcaster', 'cnn', 'subpoenas', 'already', 'issued', 'relation', 'meeting', 'donald', 'trump', 'jr', 'russian', 'lawyer'], tags=[205]),
#  TaggedDocument(words=['nato', 'statement', 'said', 'thursday', 'evening', 'blast', 'happened', 'joint', 'patrol', 'afghan', 'army', 'attacked', 'personnel', 'borne', 'improvised', 'explosive', 'device'], tags=[206]),
#  TaggedDocument(words=['piece', 'may', 'angered', 'sons', 'suspected', 'gang', 'members', 'bought', 'every', 'copy', 'edition', 'soon', 'delivered', 'newsstands'], tags=[207]),
#  TaggedDocument(words=['efforts', 'triggered', 'pushback', 'democratics', 'conservation', 'groups', 'concerned', 'impact', 'greater', 'emissions', 'public', 'health'], tags=[208]),
#  TaggedDocument(words=['another', 'battily', 'villainous', 'plot', 'involving', 'ronald', 'reagan', 'also', 'mr', 'showalter', 'abetted', 'george', 'h', 'w', 'bush', 'well', 'inhabited', 'impression', 'michael', 'ian', 'black'], tags=[209]),
#  TaggedDocument(words=['see', 'positive', 'results'], tags=[210]),
#  TaggedDocument(words=['music', 'sorts', 'food', 'including', 'typical', 'german', 'potato', 'salad', 'even', 'afd', 'would', 'problem', 'eating', 'said', 'woman', 'brought'], tags=[211]),
#  TaggedDocument(words=['total', 'members', 'regensburger', 'domspatzen', 'highly', 'likely', 'victims', 'assaults', 'early', 'domspatzen', 'sexually', 'abused'], tags=[212]),
#  TaggedDocument(words=['walk', 'starts', 'sunday', 'th', 'july', 'pm', 'frohnstetten', 'water', 'reservoir', 'amerikastra', 'e'], tags=[213]),
#  TaggedDocument(words=['public', 'health', 'advocates', 'environmentalists', 'cheered', 'pruitt', 'surprising', 'change', 'course'], tags=[214]),
#  TaggedDocument(words=['put', 'phone', 'return', 'later', 'evening', 'tweets', 'people', 'gathering', 'canfield', 'drive'], tags=[215]),
#  TaggedDocument(words=['nation', 'first', 'astral', 'path', 'come', 'life', 'harz'], tags=[216]),
#  TaggedDocument(words=['happy', 'work', 'garcia', 'said'], tags=[217]),
#  TaggedDocument(words=['chilling', 'aspect', 'tv', 'series', 'handmaid', 'tale', 'graphic', 'imagery', 'noosed', 'bodies', 'gouged', 'eyes', 'realistic', 'vision', 'feels'], tags=[218]),
#  TaggedDocument(words=['everyone', 'least', 'black', 'actors', 'bursts', 'laughter'], tags=[219]),
#  TaggedDocument(words=['sad', 'brother', 'paul', 'chosen', 'sue', 'drag', 'family', 'name', 'courts', 'wrote'], tags=[220]),
#  TaggedDocument(words=['manufacturers', 'announced', 'swift', 'implementation', 'coming', 'months', 'specified', 'precise', 'deadline', 'yet'], tags=[221]),
#  TaggedDocument(words=['meeting', 'ho', 'chi', 'minh', 'city', 'sport', 'revolutionary', 'suggestion', 'play', 'davis', 'cup', 'singles', 'best', 'three', 'sets', 'received', 'shy', 'whisker', 'necessary', 'two', 'thirds', 'majority', 'support'], tags=[222]),
#  TaggedDocument(words=['allows', 'passengers', 'personalise', 'journey', 'time', 'train', 'says', 'michael', 'peterson', 'director', 'marketing', 'db', 'fernverkehr'], tags=[223]),
#  TaggedDocument(words=['must', 'love', 'support'], tags=[224]),
#  TaggedDocument(words=['polish', 'title', 'defender', 'piotr', 'malachowski', 'also', 'qualified', 'final', 'showdown', 'first', 'attempt', 'throwing', 'metres'], tags=[225]),
#  TaggedDocument(words=['school', 'headteacher', 'angelika', 'sitte', 'greeted', 'parents', 'public', 'representatives', 'biesental', 'community', 'centre', 'epfenhofen', 'tuesday', 'evening'], tags=[226]),
#  TaggedDocument(words=['brings', 'maryland', 'gov', 'larry', 'hogan', 'needs', 'work', 'like', 'washington'], tags=[227]),
#  TaggedDocument(words=['afghan', 'provincial', 'council', 'presidential', 'elections', 'take', 'place', 'april'], tags=[228]),
#  TaggedDocument(words=['roll', 'back', 'time', 'city', 'employs', 'kitchen', 'assistants'], tags=[229]),
#  TaggedDocument(words=['originally', 'town', 'picnic', 'planned', 'brunnenplatz', 'square', 'motto', 'everyone', 'one', 'table', 'taking', 'place', 'carpark', 'beneath', 'shopping', 'plaza', 'therefore', 'directly', 'sight', 'coming', 'afd', 'event', 'town', 'hall'], tags=[230]),
#  TaggedDocument(words=['beginning', 'information', 'session', 'schindler', 'cast', 'glimpse', 'back', 'case', 'far'], tags=[231]),
#  TaggedDocument(words=['evidence', 'shows', 'transformative', 'drug', 'part', 'approach', 'hiv', 'prevention', 'ending', 'transmission', 'life', 'changing', 'infection'], tags=[232]),
#  TaggedDocument(words=['university', 'town', 'initiative', 'g', 'ttingen', 'planetarium', 'friends', 'association', 'something', 'similar', 'astral', 'path', 'since', 'planetary', 'trail'], tags=[233]),
#  TaggedDocument(words=['exactly'], tags=[234]),
#  TaggedDocument(words=['sounds', 'like', 'locked', 'deputy', 'commandant', 'replied'], tags=[235]),
#  TaggedDocument(words=['lord', 'built', 'furnished', 'church', 'staffed', 'priest', 'still', 'remained', 'owner', 'church', 'also', 'able', 'bequeath', 'proprietary', 'church', 'right'], tags=[236]),
#  TaggedDocument(words=['feel', 'really', 'special', 'said', 'southport', 'based', 'player'], tags=[237]),
#  TaggedDocument(words=['trek', 'nearest', 'fixed', 'star', 'would', 'take', 'another', 'half', 'year', 'though'], tags=[238]),
#  TaggedDocument(words=['daimler', 'advised', 'affected', 'write'], tags=[239]),
#  TaggedDocument(words=['even', 'facing', 'risk', 'negative', 'press', 'releases', 'recommended', 'urgent', 'intervention'], tags=[240]),
#  TaggedDocument(words=['biggest', 'asset', 'people', 'work', 'agriculture', 'give', 'thought', 'bring', 'businesses', 'forward', 'stressed', 'mayor'], tags=[241]),
#  TaggedDocument(words=['many', 'people', 'weird', 'offensive', 'free', 'market', 'gives', 'permission'], tags=[242]),
#  TaggedDocument(words=['ibarra', 'wanted', 'poet', 'admits', 'covering', 'drug', 'trade', 'scares'], tags=[243]),
#  TaggedDocument(words=['worked', 'quite', 'well', 'though'], tags=[244]),
#  TaggedDocument(words=['many', 'locals', 'lost', 'sight', 'town', 'centre', 'shopping'], tags=[245]),
#  TaggedDocument(words=['duo', 'fled', 'without', 'loot'], tags=[246]),
#  TaggedDocument(words=['americans', 'loved', 'george', 'washington', 'take', 'long', 'newspapers', 'start', 'slamming', 'everything', 'domestic', 'policy', 'political', 'principles'], tags=[247]),
#  TaggedDocument(words=['management', 'team', 'grand', 'plaza', 'released', 'statement', 'residents', 'saying', 'police', 'currently', 'working', 'timeline', 'background', 'victim', 'exploring', 'variety', 'motives', 'including', 'possible', 'domestic', 'incident'], tags=[248]),
#  TaggedDocument(words=['happier', 'get', 'four', 'four', 'great', 'effort'], tags=[249]),
#  TaggedDocument(words=['current', 'state', 'affairs', 'city', 'council', 'passed', 'resolution', 'wind', 'concentration', 'zone', 'boisheimer', 'nette', 'summer', 'break', 'approval', 'regional', 'government', 'still', 'pending'], tags=[250]),
#  TaggedDocument(words=['option', 'separation', 'cleaning', 'kitchen', 'service', 'improves', 'quality', 'kitchen', 'output', 'also', 'appeal', 'turned', 'economical', 'option', 'city', 'comparing', 'costs', 'house', 'outsourcing', 'said', 'press', 'office'], tags=[251]),
#  TaggedDocument(words=['pistorius', 'claimed', 'mistook', 'girlfriend', 'nighttime', 'intruder', 'hiding', 'cubicle'], tags=[252]),
#  TaggedDocument(words=['signal', 'investor', 'one', 'wants', 'put', 'spoke', 'wheel', 'proposed', 'resolution', 'makes', 'allowances', 'determination', 'saddled', 'roof', 'based', 'surrounding', 'buildings', 'mono', 'pitch', 'roof', 'reduces', 'height', 'eaves', 'makes', 'building', 'economical', 'would', 'possible'], tags=[253]),
#  TaggedDocument(words=['schulz', 'got', 'since', 'beginning', 'year', 'even', 'begin', 'describe', 'opposing', 'wind'], tags=[254]),
#  TaggedDocument(words=['point', 'committed', 'addressing', 'violations', 'processes', 'go', 'said'], tags=[255]),
#  TaggedDocument(words=['erkens', 'grant', 'approval', 'construction', 'wind', 'turbines', 'site', 'therefore', 'precluded', 'planning', 'law'], tags=[256]),
#  TaggedDocument(words=['yellow', 'survey', 'building', 'property', 'survey', 'among', 'things', 'structural', 'condition', 'intentions', 'refurbishment'], tags=[257]),
#  TaggedDocument(words=['group', 'mostly', 'democratic', 'states', 'along', 'district', 'columbia', 'filed', 'suit', 'tuesday', 'saying', 'effort', 'illegal'], tags=[258]),
#  TaggedDocument(words=['left', 'invigorated', 'trump', 'warping', 'effect', 'presidency', 'power', 'push', 'us', 'rightwards'], tags=[259]),
#  TaggedDocument(words=['incident', 'may', 'revive', 'questions', 'safety', 'materials', 'used', 'exteriors', 'tall', 'buildings', 'across', 'world'], tags=[260]),
#  TaggedDocument(words=['psg', 'made', 'clear', 'would', 'allow', 'italy', 'international', 'leave', 'circumstances', 'barcelona', 'could', 'well', 'feeling', 'repercussions', 'interest', 'losing', 'one', 'prize', 'assets', 'neymar'], tags=[261]),
#  TaggedDocument(words=['national', 'association', 'advancement', 'colored', 'people', 'put', 'alert', 'people', 'color', 'traveling', 'missouri', 'state', 'discriminatory', 'policies', 'racist', 'attacks'], tags=[262]),
#  TaggedDocument(words=['big', 'markets', 'asia', 'usa', 'ex', 'basketball', 'player', 'shaquille', 'neal', 'baseball', 'star', 'alex', 'rodriguez', 'involved', 'us', 'team', 'nrg', 'esports'], tags=[263]),
#  TaggedDocument(words=['two', 'groups', 'republican', 'democratic', 'senators', 'proposed', 'draft', 'legislation', 'thursday', 'would', 'make', 'longer', 'easy', 'special', 'counsel', 'dismissed'], tags=[264]),
#  TaggedDocument(words=['surprise', 'largest', 'amount', 'stuff', 'seized', 'tsa', 'happens', 'forbidden', 'liquids'], tags=[265]),
#  TaggedDocument(words=['train', 'numbers', 'line', 'yet', 'enabled'], tags=[266]),
#  TaggedDocument(words=['run', 'works', 'residents', 'informed', 'project', 'via', 'leaflet'], tags=[267]),
#  TaggedDocument(words=['ran', 'examined', 'body', 'make', 'sure', 'yohanes', 'like', 'many', 'indonesians', 'goes', 'one', 'name', 'told', 'time', 'somberly'], tags=[268]),
#  TaggedDocument(words=['kinzig', 'bridge', 'bollenbach', 'steinach', 'renovated', 'refurbishment', 'stadium', 'still', 'topic'], tags=[269]),
#  TaggedDocument(words=['means', 'justification', 'office', 'writes', 'intake', 'capacity', 'families', 'children', 'minors', 'significantly', 'increased', 'italy'], tags=[270]),
#  TaggedDocument(words=['lower', 'saxony', 'prime', 'minister', 'stephan', 'weil', 'spd', 'wants', 'state', 'parliament', 'snap', 'new', 'election', 'loss', 'red', 'green', 'governing', 'majority', 'want', 'step'], tags=[271]),
#  TaggedDocument(words=['however', 'described', 'two', 'pilots', 'killed', 'experts', 'field'], tags=[272]),
#  TaggedDocument(words=['gilberto', 'rodriguez', 'orejuela', 'damian', 'alcazar', 'cartel', 'leader', 'miguel', 'rodriguez', 'orejuela', 'francisco', 'denis', 'brains', 'pacho', 'herrera', 'alberto', 'ammann', 'running', 'mexican', 'connection', 'chepe', 'santacruz', 'londono', 'pepe', 'rapazote', 'based', 'new', 'york'], tags=[273]),
#  TaggedDocument(words=['eligible', 'treatment', 'include', 'gay', 'bisexual', 'men', 'transgender', 'people', 'hiv', 'positive', 'partners', 'successfully', 'receiving', 'treatment'], tags=[274]),
#  TaggedDocument(words=['rare', 'glimpse', 'daily', 'life', 'highlands', 'papua', 'former', 'dutch', 'colony', 'absorbed', 'indonesia', 'following', 'controversial', 'referendum', 'elders', 'forced', 'vote', 'public', 'show', 'hands', 'occupying', 'troops'], tags=[275]),
#  TaggedDocument(words=['right', 'back', 'position', 'white', 'armband', 'cast', 'habitual', 'spell'], tags=[276]),
#  TaggedDocument(words=['even', 'china', 'mordillo', 'found', 'many', 'fans'], tags=[277]),
#  TaggedDocument(words=['purely', 'precautionary', 'measure', 'beyond', 'adverse', 'effects', 'health', 'assumed', 'said', 'announcement'], tags=[278]),
#  TaggedDocument(words=['probably', 'never', 'know', 'tweets', 'trump', 'send'], tags=[279]),
#  TaggedDocument(words=['car', 'tractor', 'crash', 'together', 'woman', 'dies', 'terrible', 'accident'], tags=[280]),
#  TaggedDocument(words=['rally', 'erupted', 'cheers'], tags=[281]),
#  TaggedDocument(words=['number', 'newspapers', 'quadrupled', 'anonymous', 'letter', 'writers', 'hammered', 'leadership'], tags=[282]),
#  TaggedDocument(words=['landing', 'p', 'picked', 'year', 'old', 'daughter', 'dad', 'house', 'decided', 'two', 'would', 'head', 'ferguson', 'next', 'morning'], tags=[283]),
#  TaggedDocument(words=['sweet', 'hearted', 'coop', 'mr', 'showalter', 'novelist', 'still', 'gotten', 'katie', 'marguerite', 'moreau'], tags=[284]),
#  TaggedDocument(words=['brooks', 'said', 'town', 'rumor', 'hester', 'sleeping', 'malcom', 'wife', 'dorothy', 'baby', 'carrying', 'husband'], tags=[285]),
#  TaggedDocument(words=['move', 'announced', 'thursday', 'hailed', 'major', 'new', 'intervention', 'nhs', 'england', 'chief', 'executive', 'simon', 'stevens', 'national', 'aids', 'trust', 'nat', 'described', 'pivotal', 'moment'], tags=[286]),
#  TaggedDocument(words=['campaign', 'launched', 'year', 'old', 'lady', 'chapel', 'rh', 'ndorf', 'encased'], tags=[287]),
#  TaggedDocument(words=['truth', 'report', 'exonerates', 'georg', 'ratzinger', 'every', 'way'], tags=[288]),
#  TaggedDocument(words=['statement', 'issued', 'wednesday', 'evening', 'pruitt', 'suggested', 'face', 'ozone', 'standards', 'simply', 'reinforced', 'epa', 'commitment', 'working', 'states', 'complex', 'process', 'meeting', 'new', 'standards', 'time'], tags=[289]),
#  TaggedDocument(words=['go', 'hard'], tags=[290]),
#  TaggedDocument(words=['since', 'henrik', 'get', 'title', 'function', 'wanted', 'denmark', 'see', 'equal', 'wife', 'death', 'either', 'explains', 'lene', 'balleby', 'chief', 'spokeswoman', 'danish', 'royal', 'family'], tags=[291]),
#  TaggedDocument(words=['pose', 'danger', 'men'], tags=[292]),
#  TaggedDocument(words=['unconfirmed', 'local', 'reports', 'say', 'three', 'civilians', 'also', 'died', 'incident', 'city', 'qarabagh', 'district'], tags=[293]),
#  TaggedDocument(words=['last', 'published', 'accounts', 'show', 'psg', 'made', 'profit', 'million', 'euros', 'turnover', 'million', 'euros'], tags=[294]),
#  TaggedDocument(words=['massachusetts', 'woman', 'sentenced', 'two', 'half', 'years', 'encouraging', 'boyfriend', 'commit', 'suicide', 'texts', 'phone', 'calls'], tags=[295]),
#  TaggedDocument(words=['great', 'advantage', 'longevity', 'fences', 'explained', 'schwendemann'], tags=[296]),
#  TaggedDocument(words=['seemed', 'happy', 'position', 'ashamed'], tags=[297]),
#  TaggedDocument(words=['yet', 'klaus', 'dieter', 'v', 'lker', 'parliamentary', 'group', 'leader', 'cdu', 'party', 'going', 'even', 'beyond', 'joint', 'request'], tags=[298]),
#  TaggedDocument(words=['gmb', 'concern', 'investment', 'mcvitie', 'glasgow', 'factory'], tags=[299]),
#  TaggedDocument(words=['president', 'lot', 'pressure', 'investigation'], tags=[300]),
#  TaggedDocument(words=['hours', 'nearly', 'much', 'impact', 'around', 'people', 'education', 'sector', 'says', 'sonja', 'pommeranz'], tags=[301]),
#  TaggedDocument(words=['midst', 'new', 'revelations', 'president', 'took', 'advantage', 'speech', 'west', 'virginia', 'thursday', 'evening', 'order', 'portray', 'russia', 'affair', 'campaign', 'political', 'opponents'], tags=[302]),
#  TaggedDocument(words=['vasyl', 'lomachenko', 'mikey', 'garcia', 'collision', 'course', 'stage', 'compelling', 'boxing', 'match', 'pounds', 'near', 'future', 'met', 'first', 'time', 'thursday'], tags=[303]),
#  TaggedDocument(words=['calendars', 'puzzles', 'books', 'young', 'old', 'shirts', 'soft', 'toys', 'clocks', 'whimsical', 'figures', 'still', 'disseminated', 'widely', 'around', 'world'], tags=[304]),
#  TaggedDocument(words=['touran', 'driver', 'grazed', 'crash', 'barrier'], tags=[305]),
#  TaggedDocument(words=['miller', 'factually', 'correct', 'put', 'really', 'history'], tags=[306]),
#  TaggedDocument(words=['addition', 'working', 'six', 'years', 'animated', 'film', 'tv', 'series', 'figures'], tags=[307]),
#  TaggedDocument(words=['ultimately', 'competition', 'municipalities'], tags=[308]),
#  TaggedDocument(words=['first', 'honours', 'ceremony', 'president', 'trump', 'promises', 'get', 'political'], tags=[309]),
#  TaggedDocument(words=['maintained', 'forecast', 'growth'], tags=[310]),
#  TaggedDocument(words=['wife', 'margrethe', 'accession', 'throne', 'would', 'liked', 'become', 'king'], tags=[311]),
#  TaggedDocument(words=['audience', 'made', 'kind', 'peace', 'castorf', 'top', 'understanding', 'point', 'view', 'grown'], tags=[312]),
#  TaggedDocument(words=['floors', 'ripped', 'ceilings', 'partly', 'dismantled', 'old', 'bath', 'tubs', 'taken', 'rooms'], tags=[313]),
#  TaggedDocument(words=['cases', 'cancellation', 'tesla', 'pays', 'euro', 'usa', 'us', 'dollar', 'great', 'britain', 'pound', 'reservation', 'deposit', 'back', 'entirety'], tags=[314]),
#  TaggedDocument(words=['large', 'information', 'banner', 'seen', 'raft'], tags=[315]),
#  TaggedDocument(words=['husband', 'danish', 'queen', 'margrethe', 'prinz', 'henrik', 'want', 'buried', 'next', 'wife', 'death'], tags=[316]),
#  TaggedDocument(words=['important', 'trial', 'rolled', 'quickly', 'possible', 'across', 'country', 'protect', 'individuals', 'exposed', 'hiv', 'help', 'take', 'us', 'one', 'step', 'closer', 'ending', 'spread', 'hiv', 'society'], tags=[317]),
#  TaggedDocument(words=['conducting', 'interview', 'chelsea', 'manning', 'prison', 'wanted', 'kind', 'portrait', 'accompany', 'article', 'dewey', 'hagborg', 'explained', 'press', 'preview', 'new', 'exhibition'], tags=[318]),
# ...
#  TaggedDocument(words=['line', 'run', 'places'], tags=[901]),
#  TaggedDocument(words=['due', 'sacking', 'accusations', 'raised', 'wanted', 'obstruct', 'course', 'justice'], tags=[902]),
#  TaggedDocument(words=['princess', 'gloria', 'thurn', 'taxis', 'also', 'said', 'interview', 'bavarian', 'radio', 'people', 'love', 'let', 'loose', 'church', 'easy', 'target'], tags=[903]),
#  TaggedDocument(words=['world', 'largest', 'profitable', 'gold', 'mine', 'grasberg', 'owned', 'phoenix', 'based', 'freeport', 'mcmoran', 'lies', 'miles', 'paniai', 'highland', 'province', 'around', 'size', 'new', 'jersey', 'home', 'people'], tags=[904]),
#  TaggedDocument(words=['however', 'judge', 'lawrence', 'moniz', 'said', 'find', 'age', 'level', 'maturity', 'even', 'mental', 'illness', 'significant', 'impact', 'actions'], tags=[905]),
#  TaggedDocument(words=['serenade', 'rounded', 'drinks', 'front', 'cemetery'], tags=[906]),
#  TaggedDocument(words=['green', 'white', 'sikorsky', 'vh', 'known', 'marine', 'one', 'president', 'aboard', 'centerpiece', 'july', 'event', 'white', 'house', 'showcasing', 'american', 'construction', 'programs'], tags=[907]),
#  TaggedDocument(words=['suggests', 'dinosaur', 'hunted', 'enough', 'pressure', 'meat', 'eating', 'dinosaurs', 'evolution', 'favoured', 'concealment', 'confrontation', 'means', 'survival'], tags=[908]),
#  TaggedDocument(words=['prior', 'bank', 'latest', 'rates', 'verdict', 'growing', 'clamour', 'rate', 'rise', 'inflation', 'ramped', 'pressure', 'hard', 'pressed', 'households', 'three', 'policymakers', 'calling', 'increase', 'july'], tags=[909]),
#  TaggedDocument(words=['bradshaw', 'hugs', 'marbaugh', 'man', 'suit', 'played', 'head', 'klansman'], tags=[910]),
#  TaggedDocument(words=['precious', 'little', 'changed', 'papua', 'today', 'local', 'people', 'feel', 'betrayed'], tags=[911]),
#  TaggedDocument(words=['soldiers', 'removed', 'ranks', 'army', 'mostly', 'due', 'alleged', 'connections', 'movement', 'exiled', 'preacher', 'fethullah', 'g', 'len', 'erdogan', 'sees', 'mastermind', 'behind', 'coup', 'attempt'], tags=[912]),
#  TaggedDocument(words=['antarctic', 'peninsula', 'warmed', 'around', 'three', 'degrees', 'last', 'years', 'amongst', 'areas', 'temperatures', 'rising', 'quickly'], tags=[913]),
#  TaggedDocument(words=['drug', 'traffickers', 'politicians', 'businesspeople', 'journalists', 'suspected', 'payroll', 'government', 'cartels', 'catalog', 'villains', 'make', 'job', 'covering', 'mexico', 'chaos', 'perilous'], tags=[914]),
#  TaggedDocument(words=['guiding', 'principle', 'always', 'wanted', 'separate', 'clean', 'athletes', 'tainted', 'system', 'added'], tags=[915]),
#  TaggedDocument(words=['children', 'cared', 'hours', 'week', 'eat', 'kita', 'lunchtime', 'explains', 'pommeranz'], tags=[916]),
#  TaggedDocument(words=['according', 'initial', 'reports', 'driver', 'opel', 'zaifra', 'lost', 'control', 'vehicle', 'around', 'pm', 'shortly', 'marktbreit', 'junction', 'burst', 'tyre'], tags=[917]),
#  TaggedDocument(words=['yvonne', 'staiger', 'declares', 'unequivocally', 'favour', 'common', 'room', 'absolutely', 'investment', 'municipality'], tags=[918]),
#  TaggedDocument(words=['admittedly', 'still', 'plot', 'belonged', 'church', 'parish', 'comes', 'possession', 'municipality', 'nevertheless', 'longer', 'planning', 'obstacles', 'project', 'materialised', 'private', 'investor'], tags=[919]),
#  TaggedDocument(words=['successfully', 'abandoned', 'shall', 'say', 'civil', 'engineering', 'course', 'studies'], tags=[920]),
#  TaggedDocument(words=['area', 'gives', 'one', 'lot'], tags=[921]),
#  TaggedDocument(words=['contract', 'basis', 'shuttle', 'commissioned', 'state', 'future', 'well', 'currently', 'finalised', 'explained', 'hl'], tags=[922]),
#  TaggedDocument(words=['georg', 'ratzinger', 'systematically', 'close', 'ears', 'conditions'], tags=[923]),
#  TaggedDocument(words=['lot', 'cleaner', 'old', 'days', 'would', 'required', 'sending', 'staff', 'collect', 'burn', 'newspapers', 'critical', 'editorials', 'arresting', 'silencing', 'protesters'], tags=[924]),
#  TaggedDocument(words=['according', 'information', 'fire', 'department', 'one', 'injured', 'person', 'still', 'critical', 'condition', 'wednesday', 'local', 'time'], tags=[925]),
#  TaggedDocument(words=['sleeping', 'woke', 'fire', 'alarm', 'people', 'screaming'], tags=[926]),
#  TaggedDocument(words=['maybe', 'campaign', 'officials', 'know', 'something', 'rest', 'us', 'trump', 'tweets', 'would', 'even', 'inflammatory', 'interventions'], tags=[927]),
#  TaggedDocument(words=['first', 'publication', 'february', 'interview', 'damaso', 'lopez', 'leader', 'one', 'rival', 'cartel', 'factions', 'war', 'guzman', 'sons'], tags=[928]),
#  TaggedDocument(words=['although', 'special', 'federal', 'prosecutor', 'office', 'established', 'handle', 'journalists', 'cases', 'prosecuted', 'two', 'according', 'committee', 'protect', 'journalists'], tags=[929]),
#  TaggedDocument(words=['tempers', 'grew', 'heated', 'order', 'sent', 'soldiers', 'internal', 'radio', 'masses', 'offer', 'resistance', 'three', 'times', 'shoot', 'dead', 'said', 'according', 'official', 'document', 'seen', 'time', 'released', 'local', 'media'], tags=[930]),
#  TaggedDocument(words=['much', 'idea'], tags=[931]),
#  TaggedDocument(words=['last', 'admission', 'pm'], tags=[932]),
#  TaggedDocument(words=['however', 'various', 'senators', 'parties', 'want', 'avoid', 'move'], tags=[933]),
#  TaggedDocument(words=['already', 'thomas', 'bockstadt', 'susanne', 'reichle', 'sandra', 'sch', 'ck', 'thomas', 'reichle', 'meta', 'umbeer', 'numbered', 'amongst', 'repeat', 'donors', 'honoured', 'made', 'donations'], tags=[934]),
#  TaggedDocument(words=['princess', 'quite', 'right'], tags=[935]),
#  TaggedDocument(words=['says', 'beaten', 'military', 'helping', 'bury', 'four', 'victims'], tags=[936]),
#  TaggedDocument(words=['products', 'would', 'reviewed', 'undergo', 'quality', 'control', 'every', 'two', 'three', 'years'], tags=[937]),
#  TaggedDocument(words=['foreign', 'manufacturers', 'would', 'apparently', 'follow', 'suit', 'said', 'smetanin'], tags=[938]),
#  TaggedDocument(words=['moreover', 'within', 'statistics', 'people', 'obliged', 'leave', 'country', 'recorded', 'eu', 'citizens', 'leave'], tags=[939]),
#  TaggedDocument(words=['reason', 'presume', 'anything', 'changed', 'statement', 'continued'], tags=[940]),
#  TaggedDocument(words=['screws', 'tightened', 'papua', 'resources', 'bring', 'influx', 'settlers', 'elsewhere', 'indonesia'], tags=[941]),
#  TaggedDocument(words=['one', 'single', 'blood', 'donation', 'helps', 'multiple', 'people', 'explained', 'district', 'head', 'call', 'service', 'german', 'red', 'cross', 'drk', 'holger', 'maisenbacher', 'reserves', 'broken', 'components'], tags=[942]),
#  TaggedDocument(words=['incensed', 'villagers', 'protested', 'front', 'company', 'site', 'office'], tags=[943]),
#  TaggedDocument(words=['always', 'emergencies', 'inspectors'], tags=[944]),
#  TaggedDocument(words=['emergence', 'increasing', 'sophistication', 'points', 'something', 'darker', 'deeper', 'within', 'culture', 'retreat', 'ideal', 'gender', 'equality', 'toward', 'desire', 'sex', 'subjugation', 'optional', 'add'], tags=[945]),
#  TaggedDocument(words=['travel', 'warnings', 'usually', 'issued', 'state', 'department', 'countries', 'lately', 'advocacy', 'groups', 'resorted', 'measure', 'response', 'certain', 'laws', 'trends', 'inside', 'us'], tags=[946]),
#  TaggedDocument(words=['shape', 'dreamliner', 'could', 'seen', 'radar', 'screens'], tags=[947]),
#  TaggedDocument(words=['lose', 'everything', 'report', 'archdiocese', 'brisbane', 'contains', 'testimony', 'atrocities', 'committed', 'previous', 'year', 'extrajudicial', 'executions', 'torture', 'rape', 'electrocution', 'especially', 'popular', 'according', 'another', 'report', 'brutal', 'crushing', 'peaceful', 'demonstrations'], tags=[948]),
#  TaggedDocument(words=['could', 'rated', 'carousel', 'would', 'given', 'full', 'marks', 'thankfully', 'nobody', 'asked'], tags=[949]),
#  TaggedDocument(words=['second', 'mistake', 'forcing', 'valdez', 'leave', 'country', 'safety', 'seizure', 'another', 'newspaper', 'carried', 'story'], tags=[950]),
#  TaggedDocument(words=['young', 'men', 'later', 'arrested', 'police'], tags=[951]),
#  TaggedDocument(words=['something', 'different', 'place', 'dressing', 'room', 'joshua', 'kimmich', 'noticed', 'immediately', 'even', 'extra', 'piece', 'kit', 'small'], tags=[952]),
#  TaggedDocument(words=['great', 'confidence', 'team', 'exhibits', 'qualities'], tags=[953]),
#  TaggedDocument(words=['watched', 'live', 'feed', 'police', 'officer', 'stood', 'front', 'group', 'protesters', 'barking', 'dog'], tags=[954]),
#  TaggedDocument(words=['former', 'hotel', 'birkenhof', 'turned', 'waldhotel', 'luise'], tags=[955]),
#  TaggedDocument(words=['one', 'cannot', 'say', 'always', 'turned', 'blind', 'eye'], tags=[956]),
#  TaggedDocument(words=['third', 'party', 'analytics', 'tools', 'promise', 'increase', 'employee', 'commitment', 'engagement', 'wonder', 'finding', 'backing'], tags=[957]),
#  TaggedDocument(words=['hard', 'hear', 'horrible', 'awful', 'words', 'deeds', 'come', 'people', 'look', 'like', 'look', 'like', 'said'], tags=[958]),
#  TaggedDocument(words=['together', 'mother', 'anna', 'brothers', 'properties', 'worth', 'half', 'billion', 'dollars', 'amassed', 'since', 'family', 'bought', 'smith', 'street', 'collingwood', 'shop'], tags=[959]),
#  TaggedDocument(words=['message', 'indicated', 'helicopter', 'would', 'arrive', 'south', 'lawn', 'approximately', 'july', 'p', 'event', 'remain', 'lawn', 'cleared', 'p', 'p', 'evening'], tags=[960]),
#  TaggedDocument(words=['records', 'indicate', 'hmx', 'inquired', 'whether', 'event', 'might', 'violate', 'provision'], tags=[961]),
#  TaggedDocument(words=['especially', 'fun', 'see', 'forever', 'young', 'mr', 'rudd', 'sporting', 'matt', 'dillon', 'soul', 'patch', 'singles', 'whose', 'former', 'big', 'man', 'camp', 'andy', 'feels', 'like', 'geezer'], tags=[962]),
#  TaggedDocument(words=['code', 'conduct', 'boats', 'like', 'iuventa', 'would', 'notably', 'italian', 'police', 'officer', 'board', 'monitoring', 'activities'], tags=[963]),
#  TaggedDocument(words=['cdu', 'parliamentary', 'group', 'expected', 'decide', 'tuesday', 'proceed'], tags=[964]),
#  TaggedDocument(words=['night', 'friday', 'saturday', 'unknown', 'perpetrator', 'deliberately', 'knocked', 'scooter', 'parked', 'k', 'nigsfelder', 'stra', 'e', 'outside', 'residence', 'number', 'thus', 'causing', 'material', 'damage', 'euros', 'fairing', 'vehicle'], tags=[965]),
#  TaggedDocument(words=['freedom', 'speech', 'dissent', 'discourse', 'lie', 'foundation', 'nation'], tags=[966]),
#  TaggedDocument(words=['performance', 'could', 'means', 'okay', 'said', 'hoffmann'], tags=[967]),
#  TaggedDocument(words=['fall', 'love', 'electrical', 'feeds', 'walls'], tags=[968]),
#  TaggedDocument(words=['like', 'glint', 'convercent', 'lets', 'companies', 'send', 'customized', 'pulse', 'surveys', 'gather', 'confidential', 'responses', 'real', 'time', 'view', 'heat', 'maps', 'problem', 'areas'], tags=[969]),
#  TaggedDocument(words=['wanted', 'make', 'sure', 'aware', 'unusual', 'high', 'visibility', 'event', 'commander', 'hmx', 'emailed', 'superior', 'marine', 'deputy', 'commandant', 'aviation', 'day', 'event'], tags=[970]),
#  TaggedDocument(words=['parents', 'brought', 'loop'], tags=[971]),
#  TaggedDocument(words=['reports', 'varied', 'also', 'demanding', 'tasks', 'await', 'successors'], tags=[972]),
#  TaggedDocument(words=['console', 'instead', 'turf', 'bundesliga', 'getting', 'ready', 'e', 'sport'], tags=[973]),
#  TaggedDocument(words=['uneccessary', 'addition', 'thinks', 'wilfried', 'sohmer'], tags=[974]),
#  TaggedDocument(words=['law', 'reduce', 'poverty', 'raise', 'wages', 'save', 'billions', 'dollars', 'taxpayers', 'changing', 'way', 'us', 'issues', 'green', 'cards', 'citizens', 'countries'], tags=[975]),
#  TaggedDocument(words=['giving', 'perception', 'glamorous', 'space', 'beauty', 'living', 'room', 'able', 'close', 'kitchen', 'use'], tags=[976]),
#  TaggedDocument(words=['true', 'sighed', 'spd', 'campaigner', 'bad', 'news', 'reached', 'party', 'headquarters', 'friday', 'afternoon'], tags=[977]),
#  TaggedDocument(words=['digital', 'bayernatlas', 'patchwork', 'quilt', 'one', 'quite', 'recognise', 'first'], tags=[978]),
#  TaggedDocument(words=['would', 'great', 'service', 'reputation', 'catholic', 'church', 'ller', 'ratzinger', 'express', 'deep', 'regret', 'failures', 'false', 'assessments', 'events', 'back'], tags=[979]),
#  TaggedDocument(words=['wiranto', 'backtracked', 'speaking', 'time', 'jakarta', 'june', 'saying', 'plans', 'establish', 'grievance', 'mechanism', 'papua'], tags=[980]),
#  TaggedDocument(words=['reach', 'satisfactory', 'solution', 'short', 'term', 'district', 'administration', 'strive', 'unions', 'perhaps', 'also', 'collaboration', 'district', 'towns', 'secure', 'house', 'wage', 'agreement', 'said', 'v', 'lker'], tags=[981]),
#  TaggedDocument(words=['misery', 'began', 'unexpectedly', 'decisive', 'defeat', 'saarland', 'election', 'march'], tags=[982]),
#  TaggedDocument(words=['farmer', 'arnold', 'found', 'curious', 'egg'], tags=[983]),
#  TaggedDocument(words=['professor', 'colonna', 'said', 'established', 'link', 'one', 'bacterial', 'species', 'lactobacillus', 'reuteri', 'normal', 'part', 'gut', 'microbiome', 'development', 'population', 'cells', 'promote', 'tolerance'], tags=[984]),
#  TaggedDocument(words=['squint', 'eyes', 'bit', 'could', 'almost', 'believe', 'sleeping', 'said', 'lead', 'author', 'caleb', 'brown', 'scientist', 'royal', 'tyrrell', 'museum', 'creature', 'display'], tags=[985]),
#  TaggedDocument(words=['migrants', 'started', 'sell', 'chicken', 'vegetables', 'traditional', 'market', 'cheaper', 'local', 'papuans', 'explains', 'abeth', 'year', 'old', 'paniai', 'native', 'moved', 'provincial', 'capital', 'jayapura', 'work'], tags=[986]),
#  TaggedDocument(words=['squad', 'concerns', 'fc', 'bayern', 'travelling', 'dortmund', 'first', 'competitive', 'match', 'new', 'season'], tags=[987]),
#  TaggedDocument(words=['therefore', 'also', 'reason', 'bring', 'good', 'name', 'association', 'despicable', 'crime', 'unfortunately', 'happened', 'cases'], tags=[988]),
#  TaggedDocument(words=['edited', 'tighter', 'length', 'comrade', 'detective', 'might', 'deliver', 'better', 'agitprop', 'satire', 'gregor', 'iosef', 'repeatedly', 'visit', 'american', 'embassy', 'whose', 'lobby', 'always', 'occupied', 'two', 'fat', 'men', 'wolfing', 'pile', 'hamburgers'], tags=[989]),
#  TaggedDocument(words=['elector', 'max', 'iv', 'joseph', 'propelled', 'project', 'forward', 'founding', 'topographical', 'bureau', 'bavarian', 'surveying', 'mapping', 'authority'], tags=[990]),
#  TaggedDocument(words=['pietzschmann', 'explained', 'every', 'community', 'must', 'carry', 'aforementioned', 'preliminary', 'studies'], tags=[991]),
#  TaggedDocument(words=['two', 'bulgarians', 'detained', 'illegal', 'camping', 'greece'], tags=[992]),
#  TaggedDocument(words=['russia', 'affair', 'us', 'special', 'counsel', 'convenes', 'grand', 'jury'], tags=[993]),
#  TaggedDocument(words=['donald', 'trump', 'exactly', 'look', 'happy', 'wednesday', 'evening', 'placed', 'signature', 'bill', 'would', 'see', 'sanctions', 'russia', 'strengthened'], tags=[994]),
#  TaggedDocument(words=['paul', 'wanted', 'family', 'business', 'since', 'acrimonious', 'argument', 'playing', 'supreme', 'court', 'break'], tags=[995]),
#  TaggedDocument(words=['simply', 'slide', 'back', 'nostalgia', 'romanticise', 'old', 'days', 'longer', 'enough', 'days'], tags=[996]),
#  TaggedDocument(words=['bank', 'england', 'expected', 'announce', 'later', 'interest', 'rates', 'remain', 'unchanged', 'lacklustre', 'economic', 'growth', 'easing', 'inflation', 'dampened', 'speculation', 'hike'], tags=[997]),
#  TaggedDocument(words=['names', 'generate', 'kind', 'attention'], tags=[998]),
#  TaggedDocument(words=['back', 'washington', 'said', 'freedom', 'speech', 'may', 'taken', 'away', 'dumb', 'silent', 'may', 'led', 'like', 'sheep', 'slaughter'], tags=[999]),
#  ...]

# %%
## Train doc2vec model
model_Doc2Vec = Doc2Vec(tagged_data, vector_size = 1024, window = 3, min_count = 1.5, epochs = 100)

# %%
def Doc2Vec(sentece):
    x = model_Doc2Vec.infer_vector(sentece)    
    return x

# %%
#embedding = df_cp.apply(lambda x:Doc2Vec(x['w_reference']), axis=1)

# %%
#pd.DataFrame(embedding).to_csv('embedding.csv')

# %% [markdown]
# ## Similarity

# %% [markdown]
# ## Doc2Vec + Cosine Similarity

# %%
from scipy import spatial
def cosinesimilarity(ref,trans):
    t = model_Doc2Vec.infer_vector(trans)
    r = model_Doc2Vec.infer_vector(ref)
    result = 1 - spatial.distance.cosine(t,r)
    return result

# %% [markdown]
# REF: https://www.machinelearningplus.com/nlp/cosine-similarity/
#
# The cosine similarity is advantageous because even if the two similar documents are far apart by the Euclidean distance (due to the size of the document), chances are they may still be oriented closer together. The smaller the angle, higher the cosine similarity.

# %% [markdown]
# **Interpretation** : A cosine value of 0 means that the two vectors are at 90 degrees to each other (orthogonal) and have no match. The closer the cosine value to 1, the smaller the angle and the greater the match between vectors.

# %%
df_cp['metric'] = df_cp.apply(lambda x:cosinesimilarity(x['w_reference'],x['w_translation']), axis=1)

# %%
df_cp
# Out:
#                                                   source  \
# 0      Das Publikum ist fast gleichmäßig zwischen Sch...
# 1      Du kannst ihre Energie durch den Bildschirm sp...
# 2      Da die Adresse unbekannt ist, wird die Mithilf...
# 3      Arsenal-Manager Arsene Wenger, dessen Verein i...
# 4      Landwirtschaftsminister im Interview - Wie sch...
# ...                                                  ...
# 28399  Insgesamt gebe es jedoch seit rund 30 Jahren e...
# 28400  Wir können froh sein, dass wir diese Zeit läng...
# 28401  Der unheilbare Zustand, der in den USA rund 1,...
# 28402  "Komfort Check-in" nennt die Bahn die Fahrkart...
# 28403  Anleger erreichen Renditen, wenn ihre Portfoli...
#
#                                                reference  \
# 0      The audience is almost evenly split between bl...
# 1       You can feel their energy through the screen. ""
# 2      As the address is unknown, the help of the pop...
# 3      Arsenal manager Arsene Wenger, whose club is o...
# 4      Agriculture Minister in the interview - How do...
# ...                                                  ...
# 28399  Total, however, there were approximately 30 ye...
# 28400  We can be glad we have overcome these time alr...
# 28401  The condition of unheilbare, which affects the...
# 28402  "Check-in amenities," the rail operator descri...
# 28403  Investors reach valuations if their Portfolio-...
#
#                                              translation  \
# 0      The audience is almost evenly split between bl...
# 1           You can feel her energy through the screen."
# 2      As the address is unknown, the assistance of t...
# 3      Arsenal manager Arsene Wenger, whose club is o...
# 4      Minister of Agriculture in interview – How do ...
# ...                                                  ...
# 28399  Nevertheless, altogether, there have been a se...
# 28400  We can be glad that we have long overcome this...
# 28401  The incurable condition, which affects around ...
# 28402  The railway is calling this conductorless tick...
# 28403  Investors achieve returns when their portfolio...
#
#                                              p_reference  \
# 0              audience almost evenly split black white
# 1                                 feel energy screen
# 2      address unknown  help population requested hop...
# 3      arsenal manager arsene wenger  whose club owne...
# 4      agriculture minister interview   protect poiso...
# ...                                                  ...
# 28399  total  however  approximately    years since s...
# 28400                        glad overcome time already
# 28401  condition unheilbare  affects u s  approximate...
# 28402   check in amenities   rail operator describes ...
# 28403  investors reach valuations portfolio  running ...
#
#                                            p_translation  \
# 0              audience almost evenly split black white
# 1                                   feel energy screen
# 2      address unknown  assistance population request...
# 3      arsenal manager arsene wenger  whose club owne...
# 4      minister agriculture interview   protect poiso...
# ...                                                  ...
# 28399  nevertheless  altogether  series unusual colla...
# 28400                           glad long overcome time
# 28401  incurable condition  affects around     millio...
# 28402  railway calling conductorless ticket validatio...
# 28403  investors achieve returns portfolio companies ...
#
#                                              w_reference  \
# 0        [audience, almost, evenly, split, black, white]
# 1                                 [feel, energy, screen]
# 2      [address, unknown, help, population, requested...
# 3      [arsenal, manager, arsene, wenger, whose, club...
# 4      [agriculture, minister, interview, protect, po...
# ...                                                  ...
# 28399  [total, however, approximately, years, since, ...
# 28400                    [glad, overcome, time, already]
# 28401  [condition, unheilbare, affects, u, approximat...
# 28402  [check, amenities, rail, operator, describes, ...
# 28403  [investors, reach, valuations, portfolio, runn...
#
#                                            w_translation    metric
# 0        [audience, almost, evenly, split, black, white]  0.911390
# 1                                 [feel, energy, screen]  0.902081
# 2      [address, unknown, assistance, population, req... -0.274379
# 3      [arsenal, manager, arsene, wenger, whose, club...  0.906433
# 4      [minister, agriculture, interview, protect, po... -0.528896
# ...                                                  ...       ...
# 28399  [nevertheless, altogether, series, unusual, co... -0.102730
# 28400                       [glad, long, overcome, time]  0.339870
# 28401  [incurable, condition, affects, around, millio...  0.057377
# 28402  [railway, calling, conductorless, ticket, vali... -0.362051
# 28403  [investors, achieve, returns, portfolio, compa...  0.428049
#
# [28404 rows x 8 columns]

# %%
df_final = df_cp.drop(columns=['p_reference', 'p_translation','w_reference','w_translation'])

# %%
df_final
# Out:
#                                                   source  \
# 0      Das Publikum ist fast gleichmäßig zwischen Sch...
# 1      Du kannst ihre Energie durch den Bildschirm sp...
# 2      Da die Adresse unbekannt ist, wird die Mithilf...
# 3      Arsenal-Manager Arsene Wenger, dessen Verein i...
# 4      Landwirtschaftsminister im Interview - Wie sch...
# ...                                                  ...
# 28399  Insgesamt gebe es jedoch seit rund 30 Jahren e...
# 28400  Wir können froh sein, dass wir diese Zeit läng...
# 28401  Der unheilbare Zustand, der in den USA rund 1,...
# 28402  "Komfort Check-in" nennt die Bahn die Fahrkart...
# 28403  Anleger erreichen Renditen, wenn ihre Portfoli...
#
#                                                reference  \
# 0      The audience is almost evenly split between bl...
# 1       You can feel their energy through the screen. ""
# 2      As the address is unknown, the help of the pop...
# 3      Arsenal manager Arsene Wenger, whose club is o...
# 4      Agriculture Minister in the interview - How do...
# ...                                                  ...
# 28399  Total, however, there were approximately 30 ye...
# 28400  We can be glad we have overcome these time alr...
# 28401  The condition of unheilbare, which affects the...
# 28402  "Check-in amenities," the rail operator descri...
# 28403  Investors reach valuations if their Portfolio-...
#
#                                              translation    metric
# 0      The audience is almost evenly split between bl...  0.911390
# 1           You can feel her energy through the screen."  0.902081
# 2      As the address is unknown, the assistance of t... -0.274379
# 3      Arsenal manager Arsene Wenger, whose club is o...  0.906433
# 4      Minister of Agriculture in interview – How do ... -0.528896
# ...                                                  ...       ...
# 28399  Nevertheless, altogether, there have been a se... -0.102730
# 28400  We can be glad that we have long overcome this...  0.339870
# 28401  The incurable condition, which affects around ...  0.057377
# 28402  The railway is calling this conductorless tick... -0.362051
# 28403  Investors achieve returns when their portfolio...  0.428049
#
# [28404 rows x 4 columns]
