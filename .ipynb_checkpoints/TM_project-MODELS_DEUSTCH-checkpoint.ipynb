# %%
#libraries 
import numpy as np
import pandas as pd
import re
import os


#preprocessing
import string
from time import time  
from nltk.corpus import stopwords #remove stop words
chachedWords = stopwords.words('english')

#translation 
from nltk.translate.bleu_score import sentence_bleu
from gensim import models

#ignore warnings
import warnings
warnings.filterwarnings("ignore")

#cosine similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
import math
from collections import Counter

#Word Movin Distance
from gensim import models
import gensim.downloader as api
from pyemd import emd

#visualization 
import seaborn as sns

# %% [markdown]
# Base: https://medium.com/@adriensieg/text-similarities-da019229c894

# %% [markdown]
# REF:
#
# https://arxiv.org/pdf/1301.3781.pdf
#
# https://www.aclweb.org/anthology/N19-1181.pdf
#
# http://proceedings.mlr.press/v37/kusnerb15.pdf
#
# https://static.googleusercontent.com/media/research.google.com/en//pubs/archive/37842.pdf
#
# https://arxiv.org/pdf/1609.08144.pdf

# %%
df = pd.read_csv(r"C:\Users\hirom\OneDrive - NOVAIMS\NOVA IMS\OneDrive_1_25-02-2021\Text Mining\Project\corpus\de-en\scores.csv")
df.head(4)
# Out:
#                                               source  \
# 0  Ihr Zeitlupentempo maßen sie, als sie vor Spit...
# 1  Er sagte, dass die Bereiche ruhige Treffpunkte...
# 2  Für die Geschäftsleute an der B 27 ist es nur ...
# 3  Diese Fähigkeit sei möglicherweise angeboren o...
#
#                                            reference  \
# 0  Her timeless pace measures them when they equi...
# 1  He said the areas offer quiet meeting points b...
# 2  For businessmen at the B 27, it's only a small...
# 3  This ability may be born or developed with gen...
#
#                                          translation   z-score  avg-score  \
# 0  Their slow speed was measured by researchers o... -0.345024       76.0
# 1  He said the spaces provided calm meeting point...  0.903800       97.5
# 2  This is only a small consolation for businesse...  0.700503       94.0
# 3  This ability may be innate, or may develop as ... -1.256572       51.5
#
#    annotators
# 0           1
# 1           2
# 2           1
# 3           2

# %%
df.shape
# Out:
# (21704, 6)

# %%
df.describe()
# Out:
#             z-score     avg-score    annotators
# count  21704.000000  21704.000000  21704.000000
# mean       0.000898     71.852890      1.502995
# std        0.855140     26.348469      0.810923
# min       -5.806322      0.000000      1.000000
# 25%       -0.499574     56.000000      1.000000
# 50%        0.216756     79.000000      1.000000
# 75%        0.640273     94.000000      2.000000
# max        2.535434    100.000000      9.000000

# %%
pd.pivot_table(df, values = 'annotators', index =['translation'], aggfunc = 'count')
# Out:
#                                                     annotators
# translation
# "A Generation Is Protesting" in Ethiopia, Long ...           7
# "A Square Meal" is a feast of historical tidbits.            4
# "A cultural change, a mental change, a physical...           4
# "A lot of former customers got priced out of Wi...           5
# "A lot of the stuff I get is late 60s, early 70...          10
# ...                                                        ...
# You're not singing by yourself - and in a group...           9
# YouTube Gaming is owned by Google's parent comp...           9
# Young people are particularly vulnerable to this.            5
# Your doctor will examine you to see if the prob...           6
# Zeiss Meditec produces devices and equipment fo...           5
#
# [3001 rows x 1 columns]

# %%
reference =df['reference']
translation = df['translation']

# %% [markdown]
# ## Preprocessing

# %%
df.isnull().sum()
# Out:
# source         0
# reference      0
# translation    0
# z-score        0
# avg-score      0
# annotators     0
# dtype: int64

# %%
def preprocessing(column):
    pp_column = []
    for sentence in column:
        #exclude punctuation 
        sentence = re.sub(r'[^A-Za-z0-9]',' ',sentence)
        #transform everything in lowercase
        sentence = sentence.lower()
        pp_column.append(sentence)
        
    processed = pd.Series(pp_column)
    return processed

# %%
def preprocessing2(sentence):
    return " ".join(re.sub(r'[^a-zA-Z]',' ',w).lower() for w in sentence.split() if re.sub(r'[^a-zA-Z]',' ',w).lower() not in chachedWords)

# %%
# Out:
# 'small consolation businesses located along b    road reopened customers rottenburg '

# %%
df['p_reference'] = df.apply(lambda x:preprocessing2(x['reference']),axis=1)

# %%
df['p_translation'] = df.apply(lambda x:preprocessing2(x['translation']),axis=1)

# %%
df_cp = df.copy()

# %%
df_cp.head(4)
# Out:
#                                               source  \
# 0  Ihr Zeitlupentempo maßen sie, als sie vor Spit...
# 1  Er sagte, dass die Bereiche ruhige Treffpunkte...
# 2  Für die Geschäftsleute an der B 27 ist es nur ...
# 3  Diese Fähigkeit sei möglicherweise angeboren o...
#
#                                            reference  \
# 0  Her timeless pace measures them when they equi...
# 1  He said the areas offer quiet meeting points b...
# 2  For businessmen at the B 27, it's only a small...
# 3  This ability may be born or developed with gen...
#
#                                          translation   z-score  avg-score  \
# 0  Their slow speed was measured by researchers o... -0.345024       76.0
# 1  He said the spaces provided calm meeting point...  0.903800       97.5
# 2  This is only a small consolation for businesse...  0.700503       94.0
# 3  This ability may be innate, or may develop as ... -1.256572       51.5
#
#    annotators                                        p_reference  \
# 0           1  timeless pace measures equipped six animals br...
# 1           2  said areas offer quiet meeting points refugees...
# 2           1  businessmen b     it s small consolation custo...
# 3           2        ability may born developed gender maturity
#
#                                        p_translation
# 0  slow speed measured researchers svalbard  fitt...
# 1  said spaces provided calm meeting points refug...
# 2  small consolation businesses located along b  ...
# 3  ability may innate  may develop animal reaches...

# %%
def delete_sw(sentence):
    stop_words = stopwords.words('english')
    processed = sentence.split()
    clean = [w for w in processed if w not in chachedWords]
    return clean

# %%
df_cp['w_reference'] = df_cp.apply(lambda x:delete_sw(x['p_reference']),axis=1)

# %%
df_cp['w_translation'] = df_cp.apply(lambda x:delete_sw(x['p_translation']),axis=1)

# %%
df_cp.head(3)
# Out:
#                                               source  \
# 0  Ihr Zeitlupentempo maßen sie, als sie vor Spit...
# 1  Er sagte, dass die Bereiche ruhige Treffpunkte...
# 2  Für die Geschäftsleute an der B 27 ist es nur ...
#
#                                            reference  \
# 0  Her timeless pace measures them when they equi...
# 1  He said the areas offer quiet meeting points b...
# 2  For businessmen at the B 27, it's only a small...
#
#                                          translation   z-score  avg-score  \
# 0  Their slow speed was measured by researchers o... -0.345024       76.0
# 1  He said the spaces provided calm meeting point...  0.903800       97.5
# 2  This is only a small consolation for businesse...  0.700503       94.0
#
#    annotators                                        p_reference  \
# 0           1  timeless pace measures equipped six animals br...
# 1           2  said areas offer quiet meeting points refugees...
# 2           1  businessmen b     it s small consolation custo...
#
#                                        p_translation  \
# 0  slow speed measured researchers svalbard  fitt...
# 1  said spaces provided calm meeting points refug...
# 2  small consolation businesses located along b  ...
#
#                                          w_reference  \
# 0  [timeless, pace, measures, equipped, six, anim...
# 1  [said, areas, offer, quiet, meeting, points, r...
# 2  [businessmen, b, small, consolation, customers...
#
#                                        w_translation
# 0  [slow, speed, measured, researchers, svalbard,...
# 1  [said, spaces, provided, calm, meeting, points...
# 2  [small, consolation, businesses, located, alon...

# %% [markdown]
# # 'TESTE

# %%
teste = df_cp[df_cp['translation'] == 'Young people are particularly vulnerable to this.']
teste
# Out:
#                                                   source  \
# 2842   Junge Leute sind da in besonderer Weise anfällig.
# 5374   Junge Leute sind da in besonderer Weise anfällig.
# 7253   Junge Leute sind da in besonderer Weise anfällig.
# 9352   Junge Leute sind da in besonderer Weise anfällig.
# 18227  Junge Leute sind da in besonderer Weise anfällig.
#
#                                                reference  \
# 2842   Young people are there in special way suscepti...
# 5374           Young people are particularly vulnerable.
# 7253      Young people are particularly vulnerable here.
# 9352   Young people are particularly susceptible to t...
# 18227         Young people are in particular vulnerable.
#
#                                              translation   z-score  avg-score  \
# 2842   Young people are particularly vulnerable to this. -0.105717       61.0
# 5374   Young people are particularly vulnerable to this.  1.242500      100.0
# 7253   Young people are particularly vulnerable to this.  0.762377       91.0
# 9352   Young people are particularly vulnerable to this.  1.184759      100.0
# 18227  Young people are particularly vulnerable to this.  0.363601       75.0
#
#        annotators                                  p_reference  \
# 2842            2        young people special way susceptible
# 5374            1        young people particularly vulnerable
# 7253            1   young people particularly vulnerable here
# 9352            1  young people particularly susceptible this
# 18227           1          young people particular vulnerable
#
#                                     p_translation  \
# 2842   young people particularly vulnerable this
# 5374   young people particularly vulnerable this
# 7253   young people particularly vulnerable this
# 9352   young people particularly vulnerable this
# 18227  young people particularly vulnerable this
#
#                                       w_reference  \
# 2842   [young, people, special, way, susceptible]
# 5374    [young, people, particularly, vulnerable]
# 7253    [young, people, particularly, vulnerable]
# 9352   [young, people, particularly, susceptible]
# 18227     [young, people, particular, vulnerable]
#
#                                    w_translation
# 2842   [young, people, particularly, vulnerable]
# 5374   [young, people, particularly, vulnerable]
# 7253   [young, people, particularly, vulnerable]
# 9352   [young, people, particularly, vulnerable]
# 18227  [young, people, particularly, vulnerable]

# %%
ref = teste['p_reference'].to_list()

# %%
cand = 'young people particularly vulnerable this'

# %% [markdown]
# ## Embedding
#
# https://www.analyticsvidhya.com/blog/2020/08/top-4-sentence-embedding-techniques-using-python/
#
# Doc2Vec

# %%
# import
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(df_cp['w_translation'])]
tagged_data
# Out:
# [TaggedDocument(words=['slow', 'speed', 'measured', 'researchers', 'svalbard', 'fitted', 'six', 'animals', 'tracker'], tags=[0]),
#  TaggedDocument(words=['said', 'spaces', 'provided', 'calm', 'meeting', 'points', 'refugees', 'volunteers'], tags=[1]),
#  TaggedDocument(words=['small', 'consolation', 'businesses', 'located', 'along', 'b', 'road', 'reopened', 'customers', 'rottenburg'], tags=[2]),
#  TaggedDocument(words=['ability', 'may', 'innate', 'may', 'develop', 'animal', 'reaches', 'sexual', 'maturity'], tags=[3]),
#  TaggedDocument(words=['generally', 'come', 'surface', 'winter', 'prefer', 'water', 'temperatures', 'around', 'six', 'degrees', 'celsius'], tags=[4]),
#  TaggedDocument(words=['bn', 'project', 'due', 'complete', 'may'], tags=[5]),
#  TaggedDocument(words=['time', 'look', 'needs', 'community', 'legal', 'centres', 'client', 'communities', 'palaszczuk', 'government', 'invest', 'important', 'work'], tags=[6]),
#  TaggedDocument(words=['appreciate', 'work', 'put', 'team', 'devon', 'cornwall', 'police', 'members', 'community', 'bravely', 'came', 'forward', 'give', 'us', 'information'], tags=[7]),
#  TaggedDocument(words=['even', 'supply', 'new', 'spring', 'sometimes', 'maintained', 'elevated', 'tank', 'pettstadt', 'filled', 'hosepipe'], tags=[8]),
#  TaggedDocument(words=['advertising', 'industry', 'already', 'pricked', 'ears'], tags=[9]),
#  TaggedDocument(words=['changing', 'well'], tags=[10]),
#  TaggedDocument(words=['well', 'known', 'platforms', 'include', 'twitch', 'youtube', 'gaming'], tags=[11]),
#  TaggedDocument(words=['north', 'sea', 'said', 'vital', 'regional', 'economy'], tags=[12]),
#  TaggedDocument(words=['organisers', 'pay', 'illness', 'strikes'], tags=[13]),
#  TaggedDocument(words=['sultana', 'years', 'old', 'according', 'family', 'died', 'making', 'plans', 'flee', 'war', 'torn', 'country', 'return', 'britain'], tags=[14]),
#  TaggedDocument(words=['appreciate', 'done', 'organization', 'wish', 'best', 'luck', 'future'], tags=[15]),
#  TaggedDocument(words=['propaganda', 'designed', 'provoke', 'emotional', 'response', 'people'], tags=[16]),
#  TaggedDocument(words=['problem', 'could', 'solved', 'one', 'fell', 'swoop'], tags=[17]),
#  TaggedDocument(words=['however', 'strict', 'rejection', 'military', 'coups', 'brings', 'turks', 'together', 'light', 'dramatic', 'historical', 'events'], tags=[18]),
#  TaggedDocument(words=['fact', 'archer', 'became', 'aware', 'social', 'media', 'frenzy', 'admitted', 'hearing', 'looks', 'like', 'leo', 'since', 'kid'], tags=[19]),
#  TaggedDocument(words=['couples', 'tourists', 'taking', 'photos', 'teenage', 'boys', 'middle', 'aged', 'women'], tags=[20]),
#  TaggedDocument(words=['olympics', 'brazen', 'cheating', 'doping', 'tests'], tags=[21]),
#  TaggedDocument(words=['police', 'say', 'triple', 'killing', 'appear', 'result', 'robbery', 'attacker', 'take', 'purses', 'possession', 'one', 'adult', 'victims'], tags=[22]),
#  TaggedDocument(words=['depressing', 'food', 'depression', 'square', 'meal'], tags=[23]),
#  TaggedDocument(words=['sisters', 'selling', 'pictures', 'respective', 'paywalled', 'apps'], tags=[24]),
#  TaggedDocument(words=['case', 'bordini', 'v', 'donald', 'j', 'trump', 'president', 'inc', 'cs', 'general', 'court', 'justice', 'superior', 'court', 'division', 'county', 'mecklenburg', 'charlotte'], tags=[25]),
#  TaggedDocument(words=['beaten', 'rivals', 'within', 'republican', 'camp', 'doubt', 'growing', 'whether', 'successful', 'race', 'white', 'house'], tags=[26]),
#  TaggedDocument(words=['various', 'pilgrimage', 'sites', 'discussed', 'decision', 'finally', 'made', 'go', 'bishop', 'city', 'freiburg', 'mark', 'holy', 'year', 'mercy', 'year', 'gates', 'mercy', 'opened', 'freiburg', 'cathedral', 'particular', 'pilgrimage', 'site'], tags=[27]),
#  TaggedDocument(words=['appears', 'multiple', 'armed', 'combatants', 'actively', 'engaged', 'philadelphia', 'police', 'captain', 'anthony', 'ginaldi', 'told', 'station'], tags=[28]),
#  TaggedDocument(words=['example', 'called', 'us', 'president', 'barack', 'obama', 'democratic', 'candidate', 'hillary', 'clinton', 'founders', 'terrorist', 'militia', 'islamic', 'state'], tags=[29]),
#  TaggedDocument(words=['know', 'get', 'better'], tags=[30]),
#  TaggedDocument(words=['final', 'five', 'next', 'olympic', 'gymnastics', 'team', 'four', 'gymnasts', 'team', 'marta', 'karolyi', 'last', 'year', 'coaching'], tags=[31]),
#  TaggedDocument(words=['picciuto', 'hopeful', 'advice', 'mothers', 'babies', 'birth', 'defects', 'zika'], tags=[32]),
#  TaggedDocument(words=['one', 'brands', 'stand', 'something', 'quite', 'different', 'communities', 'staff', 'work', 'customers', 'brands'], tags=[33]),
#  TaggedDocument(words=['one', 'knows', 'yet'], tags=[34]),
#  TaggedDocument(words=['rudolph', 'w', 'giuliani', 'former', 'new', 'york', 'city', 'mayor', 'one', 'mr', 'trump', 'prominent', 'surrogates', 'went', 'great', 'lengths', 'defend', 'candidate', 'interview', 'cnn', 'thursday'], tags=[35]),
#  TaggedDocument(words=['thuringia', 'volks', 'und', 'raffeisen', 'bank', 'altenburger', 'land', 'hit', 'headlines', 'skatbank', 'branch', 'imposed', 'penalty', 'interest', 'investments', 'three', 'million', 'euros'], tags=[36]),
#  TaggedDocument(words=['may', 'case', 'hunt', 'sleeping', 'animals', 'patrol', 'ocean', 'floor', 'look', 'corpses', 'sunk', 'downwards', 'higher', 'levels', 'water'], tags=[37]),
#  TaggedDocument(words=['neighbours', 'say', 'seen', 'fighting', 'street', 'police', 'regularly', 'called'], tags=[38]),
#  TaggedDocument(words=['tourists', 'beach', 'aveiro', 'terrified', 'plane', 'appeared', 'murk', 'flew', 'incredibly', 'low', 'altitude'], tags=[39]),
#  TaggedDocument(words=['steele', 'said', 'tangipahoa', 'parish', 'alone', 'requested', 'tens', 'thousands', 'sandbags'], tags=[40]),
#  TaggedDocument(words=['ticagrelor', 'made', 'uk', 'firm', 'astrazeneca', 'sold', 'trade', 'name', 'brilique', 'reduces', 'risk', 'making', 'clots', 'less', 'likely'], tags=[41]),
#  TaggedDocument(words=['particular', 'russian', 'exports', 'iran', 'jumped', 'percent', 'amounted', 'million'], tags=[42]),
#  TaggedDocument(words=['two', 'victims', 'car', 'police', 'investigating', 'whether', 'wounded', 'men', 'could', 'shooter'], tags=[43]),
#  TaggedDocument(words=['k', 'r', 'accused', 'follower', 'imam', 'fethullah', 'g', 'len', 'president', 'recep', 'tayyip', 'erdogan', 'holds', 'responsible', 'attempted', 'coup'], tags=[44]),
#  TaggedDocument(words=['concerns', 'state', 'institutions', 'turned', 'blind', 'eye', 'behaviour', 'politically', 'correct', 'sensitivities', 'ethnicity', 'religion'], tags=[45]),
#  TaggedDocument(words=['seriously', 'though', 'frankie', 'riding', 'winners', 'uk', 'best', 'part', 'years', 'great', 'see'], tags=[46]),
#  TaggedDocument(words=['two', 'time', 'us', 'master', 'champion', 'inaugurated', 'hall', 'fame', 'german', 'sport', 'saturday', 'along', 'outstanding', 'sportspeople'], tags=[47]),
#  TaggedDocument(words=['managing', 'director', 'bank', 'josef', 'paul', 'said', 'thursday', 'applies', 'customers', 'million', 'euros', 'current', 'accounts', 'day', 'day', 'accounts'], tags=[48]),
#  TaggedDocument(words=['commune', 'council', 'focused', 'construction', 'related', 'topics', 'recent', 'session'], tags=[49]),
#  TaggedDocument(words=['shutout', 'first', 'tournament', 'united', 'states', 'goalie', 'jackie', 'briggs', 'allowed', 'one', 'goal', 'first', 'three', 'victories'], tags=[50]),
#  TaggedDocument(words=['bordini', 'complaint', 'seeks', 'compensation', 'campaign', 'negligent', 'supervision', 'phillip', 'assault', 'battery', 'infliction', 'emotional', 'distress'], tags=[51]),
#  TaggedDocument(words=['already', 'banned', 'twice', 'doping'], tags=[52]),
#  TaggedDocument(words=['result', 'low', 'distribution', 'expenses', 'critical', 'repairs', 'amounting', 'several', 'thousand', 'euros', 'example', 'seem', 'major'], tags=[53]),
#  TaggedDocument(words=['everyone', 'gets', 'frustrated', 'including', 'police', 'residents'], tags=[54]),
#  TaggedDocument(words=['hr', 'v', 'honda', 'offering', 'diverse', 'car', 'perfect', 'everyday', 'driving'], tags=[55]),
#  TaggedDocument(words=['get', 'win', 'mates'], tags=[56]),
#  TaggedDocument(words=['although', 'hr', 'v', 'tall', 'seems', 'small', 'passengers', 'front', 'back', 'got', 'plenty', 'room', 'squeeze'], tags=[57]),
#  TaggedDocument(words=['yes', 'elections', 'looming'], tags=[58]),
#  TaggedDocument(words=['rare', 'sight'], tags=[59]),
#  TaggedDocument(words=['regardless', 'fiji', 'form', 'would', 'beaten', 'fit', 'fiddle', 'man', 'team'], tags=[60]),
#  TaggedDocument(words=['one', 'hand', 'import', 'taxes', 'started', 'impact', 'imported', 'steel', 'economic', 'prospects', 'china', 'brightened'], tags=[61]),
#  TaggedDocument(words=['played', 'country'], tags=[62]),
#  TaggedDocument(words=['taking', 'twitter', 'warned', 'mrs', 'clinton', 'proposals', 'would', 'come', 'higher', 'taxes', 'said', 'found', 'speech', 'boring'], tags=[63]),
#  TaggedDocument(words=['gone', 'retirement', 'age'], tags=[64]),
#  TaggedDocument(words=['squatters', 'houses', 'residential', 'projects', 'spawn', 'nothing', 'new', 'district', 'numerous', 'houses', 'gdr', 'full', 'squatters', 'including', 'almost', 'mainzer', 'stra', 'er', 'near', 'rigauer'], tags=[65]),
#  TaggedDocument(words=['comparing', 'clinton', 'trump', 'economic', 'policies', 'money'], tags=[66]),
#  TaggedDocument(words=['bronze', 'medal', 'olympics', 'also', 'taken', 'away', 'returned', 'following', 'decision', 'international', 'court', 'arbitration', 'sport', 'cas'], tags=[67]),
#  TaggedDocument(words=['essay', 'medium', 'telephone', 'interview', 'said', 'believed', 'race', 'related', 'controversies', 'reflected', 'lack', 'diversity', 'hiring', 'practices', 'snapchat'], tags=[68]),
#  TaggedDocument(words=['apparently', 'thinks', 'calendar'], tags=[69]),
#  TaggedDocument(words=['recent', 'attacks', 'minister', 'interior', 'de', 'maizi', 'putting', 'forward', 'host', 'security', 'measures'], tags=[70]),
#  TaggedDocument(words=['evening', 'mind', 'stop', 'whirring', 'lie', 'awake', 'hours', 'night', 'time', 'morning', 'comes', 'sleep', 'far', 'mind', 'even', 'well', 'alarm', 'goes'], tags=[71]),
#  TaggedDocument(words=['returned', 'stands', 'leaving', 'charges', 'alone', 'fight', 'fair', 'battle'], tags=[72]),
#  TaggedDocument(words=['government', 'response', 'according', 'human', 'rights', 'groups', 'ruthless'], tags=[73]),
#  TaggedDocument(words=['soprano', 'anna', 'netrebko', 'open', 'son', 'tiago', 'autism', 'addresses', 'parents', 'affected', 'disease', 'must', 'brave', 'enough', 'talk'], tags=[74]),
#  TaggedDocument(words=['anzrah', 'went', 'doping', 'check', 'alleged', 'ferguson', 'rotich', 'handed', 'sample', 'signed', 'explained', 'stephan', 'arap', 'soi', 'kenya', 'chef', 'de', 'mission'], tags=[75]),
#  TaggedDocument(words=['customers', 'hechingen', 'balingen', 'rottweil', 'stayed', 'away'], tags=[76]),
#  TaggedDocument(words=['losing', 'many', 'world', 'titles', 'win', 'olympics', 'amazing'], tags=[77]),
#  TaggedDocument(words=['british', 'traveller', 'put', 'immune', 'system', 'gag', 'reflex', 'serious', 'test', 'licking', 'dirtiest', 'disgusting', 'places', 'europe'], tags=[78]),
#  TaggedDocument(words=['new', 'nbc', 'wall', 'street', 'journal', 'marist', 'poll', 'released', 'friday', 'showed', 'mr', 'trump', 'trailing', 'mrs', 'clinton', 'large', 'margins', 'north', 'carolina', 'virginia', 'colorado', 'locked', 'tight', 'race', 'florida'], tags=[79]),
#  TaggedDocument(words=['nagold', 'fun', 'games', 'summer', 'fete'], tags=[80]),
#  TaggedDocument(words=['much', 'moment'], tags=[81]),
#  TaggedDocument(words=['year', 'old', 'olympian', 'far', 'athlete', 'fighting', 'gold', 'summer', 'boasts', 'celebrity', 'doppelganger', 'least', 'according', 'social', 'media'], tags=[82]),
#  TaggedDocument(words=['donna', 'mcevoy', 'housing', 'manager', 'cornwall', 'housing', 'said', 'feared', 'might', 'beyond', 'saving'], tags=[83]),
#  TaggedDocument(words=['thursday', 'year', 'old', 'beat', 'fellow', 'countryman', 'defending', 'champion', 'zhang', 'jike', 'rio', 'de', 'janeiro', 'one', 'sided', 'final'], tags=[84]),
#  TaggedDocument(words=['suffering', 'losses', 'previous', 'quarters', 'company', 'unable', 'stop', 'losing', 'money', 'second', 'quarter'], tags=[85]),
#  TaggedDocument(words=['hakan', 'k', 'r', 'football', 'legend', 'turkey'], tags=[86]),
#  TaggedDocument(words=['happy', 'audience', 'great', 'praise'], tags=[87]),
#  TaggedDocument(words=['couple', 'said', 'writing', 'book', 'gained', 'greater', 'understanding', 'eating', 'habits', 'ms', 'ziegelman', 'mother', 'throw', 'food', 'away', 'instance'], tags=[88]),
#  TaggedDocument(words=['new', 'collaborative', 'work', 'square', 'meal', 'published', 'tuesday', 'harper', 'history', 'american', 'food', 'great', 'depression'], tags=[89]),
#  TaggedDocument(words=['trampoline', 'offers', 'respite'], tags=[90]),
#  TaggedDocument(words=['third', 'trip', 'took', 'group', 'pforzheim'], tags=[91]),
#  TaggedDocument(words=['service', 'pilgrims', 'able', 'visit', 'sacristry', 'high', 'altar'], tags=[92]),
#  TaggedDocument(words=['one', 'track', 'similar', 'event'], tags=[93]),
#  TaggedDocument(words=['major', 'advantage', 'traffic', 'split', 'earlier', 'improving', 'overall', 'circulation', 'busy', 'section', 'main', 'road'], tags=[94]),
#  TaggedDocument(words=['time', 'respect', 'drug', 'cheats', 'said'], tags=[95]),
#  TaggedDocument(words=['years', 'old', 'also', 'stripped', 'olympic', 'silver', 'medal', 'doping', 'steroids', 'european', 'champion', 'title', 'testosterone', 'misuse'], tags=[96]),
#  TaggedDocument(words=['information', 'efficacy', 'safety', 'ticagrelor', 'particularly', 'risk', 'bleeding', 'beyond', 'three', 'years', 'limited', 'draft', 'guidance', 'recommend', 'treatment', 'beyond', 'period'], tags=[97]),
#  TaggedDocument(words=['got', 'quiet', 'used'], tags=[98]),
#  TaggedDocument(words=['edmund', 'sit', 'crawl', 'three', 'still', 'talk'], tags=[99]),
#  TaggedDocument(words=['advance', 'tickets', 'required', 'sah', 'scc', 'members', 'non', 'members'], tags=[100]),
#  TaggedDocument(words=['unable', 'provide', 'explanation', 'poor', 'finish', 'th', 'place', 'sugar', 'loaf', 'mountain'], tags=[101]),
#  TaggedDocument(words=['often', 'know', 'get', 'help', 'needs', 'accommodation', 'says', 'bahr'], tags=[102]),
#  TaggedDocument(words=['allowed', 'return', 'home', 'water', 'starts', 'recede', 'said'], tags=[103]),
#  TaggedDocument(words=['taken', 'board', 'inshore', 'lifeboat', 'brought', 'back', 'lifeboat', 'station'], tags=[104]),
#  TaggedDocument(words=['product', 'question', 'removed', 'sale'], tags=[105]),
#  TaggedDocument(words=['however', 'slow', 'pace', 'life', 'seems', 'key', 'long', 'life'], tags=[106]),
#  TaggedDocument(words=['cornwall', 'housing', 'evicted', 'partner', 'forcefully', 'property', 'week', 'giving', 'extended', 'period', 'weeks', 'move', 'voluntarily'], tags=[107]),
#  TaggedDocument(words=['threatened', 'existence'], tags=[108]),
#  TaggedDocument(words=['winner', 'australian', 'open', 'faced', 'brit', 'johanna', 'konta'], tags=[109]),
#  TaggedDocument(words=['additional', 'motor', 'l', 'petrol', 'engine', 'kw', 'horsepower'], tags=[110]),
#  TaggedDocument(words=['scientists', 'say', 'greenland', 'shark', 'longest', 'lifespan', 'vertebrate', 'planet'], tags=[111]),
#  TaggedDocument(words=['hoy', 'watched', 'position', 'bbc', 'pundit', 'caught', 'eye', 'skinner', 'kenny', 'hindes', 'stepped', 'podium'], tags=[112]),
#  TaggedDocument(words=['last', 'resort', 'launcher', 'shoots', 'roman', 'candle', 'firework', 'air', 'producing', 'loud', 'bright', 'explosion'], tags=[113]),
#  TaggedDocument(words=['witnessing', 'top', 'sport', 'look', 'like', 'gymnastics', 'classes', 'across', 'country'], tags=[114]),
#  TaggedDocument(words=['always', 'obstacles', 'overcome', 'heathrow', 'answering', 'every', 'question', 'asked'], tags=[115]),
#  TaggedDocument(words=['vein', 'passed', 'prize', 'money', 'euros', 'straight', 'away'], tags=[116]),
#  TaggedDocument(words=['singing', 'often', 'really', 'special', 'effect', 'older', 'people', 'says', 'ursula', 'lenz', 'german', 'association', 'senior', 'citizens', 'associations'], tags=[117]),
#  TaggedDocument(words=['follows', 'sir', 'gordon', 'richards', 'doug', 'smith', 'lester', 'piggott', 'pat', 'eddery', 'willie', 'carson'], tags=[118]),
#  TaggedDocument(words=['biles', 'became', 'fourth', 'straight', 'american', 'woman', 'win', 'around', 'title', 'fifth', 'overall', 'cementing', 'reputation', 'best', 'generation', 'perhaps', 'ever'], tags=[119]),
#  TaggedDocument(words=['last', 'non', 'chinese', 'athlete', 'top', 'step', 'olympic', 'podium', 'former', 'svs', 'lower', 'austria', 'legionary', 'ryu', 'seung', 'min', 'south', 'korea'], tags=[120]),
#  TaggedDocument(words=['junior', 'doctors', 'strike', 'calls', 'fresh', 'industrial', 'action'], tags=[121]),
#  TaggedDocument(words=['children', 'certainly', 'conceived', 'woman', 'consent'], tags=[122]),
#  TaggedDocument(words=['medium', 'term', 'could', 'even', 'grow', 'hundred', 'thousand', 'believes', 'ali', 'toprak', 'president', 'association'], tags=[123]),
#  TaggedDocument(words=['olympic', 'athletes', 'world', 'records', 'always', 'things', 'hit', 'headlines', 'olympic', 'games'], tags=[124]),
#  TaggedDocument(words=['date', 'organiser', 'assume', 'seawater', 'acceptable'], tags=[125]),
#  TaggedDocument(words=['winds', 'travel', 'across', 'stars', 'magnetic', 'fields', 'enact', 'braking', 'effect', 'stars'], tags=[126]),
#  TaggedDocument(words=['first', 'foremost', 'erdogan', 'needs', 'friends', 'get', 'nearly', 'ousted', 'power', 'last', 'month', 'failed', 'coup'], tags=[127]),
#  TaggedDocument(words=['add', 'long', 'standing', 'grudge', 'snail', 'pace', 'talks', 'join', 'eu', 'step', 'mr', 'putin', 'keen', 'capitalise', 'chill', 'chip', 'away', 'turkey', 'ties', 'west'], tags=[128]),
#  TaggedDocument(words=['victim', 'apparently', 'born', 'perpetrator'], tags=[129]),
#  TaggedDocument(words=['cup', 'winners', 'gala', 'depend', 'lukas', 'podolski'], tags=[130]),
#  TaggedDocument(words=['giving', 'illusion', 'perusing', 'denim', 'hot', 'pants', 'observe', 'group', 'teenage', 'girls', 'cluster', 'around', 'polaroid', 'cameras', 'momentarily', 'dad', 'daughter', 'deliberate', 'purchasing', 'crosley', 'record', 'player'], tags=[131]),
#  TaggedDocument(words=['covered', 'four', 'stages', 'together'], tags=[132]),
#  TaggedDocument(words=['looking', 'manager', 'people', 'skills', 'communication', 'skills', 'combined', 'years', 'experience', 'social', 'work', 'real', 'jack', 'trades'], tags=[133]),
#  TaggedDocument(words=['demonstrators', 'demanding', 'political', 'change', 'ethiopia', 'met', 'violent', 'resistance', 'government'], tags=[134]),
#  TaggedDocument(words=['unsuccessful', 'coup', 'secular', 'oppositional', 'ethnic', 'turks', 'added', 'list'], tags=[135]),
#  TaggedDocument(words=['stage', 'alexandra', 'burkhardt', 'heidi', 'faller', 'responsible', 'creating', 'delicious', 'nourishing', 'dinner', 'breakfast'], tags=[136]),
#  TaggedDocument(words=['last', 'big', 'minority', 'turkey', 'christian', 'armenians', 'greeks', 'already', 'exterminated', 'driven', 'past', 'hundred', 'years', 'said', 'toprak', 'also', 'member', 'cdu'], tags=[137]),
#  TaggedDocument(words=['witch', 'hunt', 'also', 'underway', 'germany', 'critical', 'erdogan'], tags=[138]),
#  TaggedDocument(words=['time', 'us', 'channel', 'olympic', 'spirit', 'expand', 'heathrow', 'securing', 'trading', 'future', 'creating', 'legacy', 'skills', 'employment', 'britain', 'proud'], tags=[139]),
#  TaggedDocument(words=['enough', 'good', 'reasons', 'start', 'singing'], tags=[140]),
#  TaggedDocument(words=['next', 'day', 'set', 'section', 'towards', 'st', 'peter', 'demanding', 'section', 'seeing', 'climb', 'around', 'metres', 'altitude', 'sweltering', 'heat', 'descend'], tags=[141]),
#  TaggedDocument(words=['justin', 'gatlin', 'aged', 'already', 'banned', 'twice', 'doping'], tags=[142]),
#  TaggedDocument(words=['director', 'community', 'legal', 'centres', 'queensland', 'james', 'farrell', 'said', 'latest', 'national', 'association', 'community', 'legal', 'centres', 'census', 'report', 'found', 'thousands', 'people', 'already', 'turned', 'away', 'year'], tags=[143]),
#  TaggedDocument(words=['nutshell', 'players', 'smartphones', 'go', 'looking', 'pok', 'mons', 'tracked', 'gps', 'found', 'photographed', 'via', 'screenshot', 'phone', 'captured'], tags=[144]),
#  TaggedDocument(words=['ban', 'everything', 'opposed', 'opposed', 'wearing', 'burka'], tags=[145]),
#  TaggedDocument(words=['never', 'direct', 'order', 'include', 'israel', 'fast', 'dial', 'list', 'suddeutsche', 'zeitung', 'quoted', 'kempinski', 'representative', 'saying'], tags=[146]),
#  TaggedDocument(words=['hindes', 'narrowly', 'behind', 'lap', 'kenny', 'pushed', 'team', 'front', 'skinner', 'held'], tags=[147]),
#  TaggedDocument(words=['mother', 'two', 'jenny', 'davidson', 'shop', 'time', 'said', 'trying', 'underwear', 'mystery', 'woman', 'got', 'dressed', 'walked', 'store', 'without', 'buying', 'anything'], tags=[148]),
#  TaggedDocument(words=['great', 'shame'], tags=[149]),
#  TaggedDocument(words=['best', 'make', 'name'], tags=[150]),
#  TaggedDocument(words=['leroy', 'hansford', 'wife', 'stepson', 'among', 'rescued', 'earlier', 'friday', 'near', 'gloster'], tags=[151]),
#  TaggedDocument(words=['would', 'like', 'say', 'thank', 'writers', 'producers', 'actors', 'amazing', 'crew', 'importantly', 'best', 'fans', 'show', 'could', 'ever', 'hope'], tags=[152]),
#  TaggedDocument(words=['safe', 'say', 'last', 'year', 'record', 'number', 'iranian', 'tourists', 'visiting', 'russia', 'broken', 'said'], tags=[153]),
#  TaggedDocument(words=['court', 'hearing', 'week', 'calais', 'authorities', 'argued', 'state', 'able', 'knock', 'total', 'makeshift', 'shops', 'people', 'inside', 'camp', 'sell', 'goods', 'cigarettes', 'energy', 'drinks', 'offer', 'haircuts', 'sell', 'tea', 'cents', 'p', 'basic', 'meals', 'euros', 'makeshift', 'restaurants'], tags=[154]),
#  TaggedDocument(words=['move', 'clinton', 'campaign', 'aide', 'ian', 'sams', 'said', 'twitter', 'linking', 'democratic', 'nominee', 'returns'], tags=[155]),
#  TaggedDocument(words=['michael', 'kemmer', 'managing', 'director', 'banking', 'association', 'said', 'expecting', 'private', 'customers', 'pay', 'fees', 'investments', 'competition', 'banks', 'germany', 'much', 'strong'], tags=[156]),
#  TaggedDocument(words=['built', 'storage', 'originally', 'held', 'eight', 'megabytes', 'enough', 'today', 'around', 'two', 'high', 'resolution', 'selfies'], tags=[157]),
#  TaggedDocument(words=['pleased', 'happened', 'newmarket', 'landed', 'years', 'ago'], tags=[158]),
#  TaggedDocument(words=['means', 'risk', 'potential', 'much', 'higher', 'depending', 'type', 'file'], tags=[159]),
#  TaggedDocument(words=['told', 'bma', 'members', 'deal', 'good', 'one', 'accepted', 'meetings', 'ahead', 'poll', 'junior', 'doctors', 'medical', 'students'], tags=[160]),
#  TaggedDocument(words=['cdu', 'wants', 'put', 'rules', 'investors', 'possible'], tags=[161]),
#  TaggedDocument(words=['singing', 'also', 'demands', 'particular', 'mental', 'exertion', 'explains', 'lenz'], tags=[162]),
#  TaggedDocument(words=['earn', 'lot', 'says', 'collecting', 'records', 'really', 'option'], tags=[163]),
#  TaggedDocument(words=['two', 'charities', 'help', 'refugees', 'l', 'auberge', 'des', 'migrants', 'friday', 'estimated', 'numbers', 'jungle', 'camp', 'risen', 'people', 'highest', 'ever', 'steep', 'increase', 'arrivals', 'summer'], tags=[164]),
#  TaggedDocument(words=['city', 'fully', 'control', 'undertaking', 'sweeping', 'operations', 'told', 'reuters'], tags=[165]),
#  TaggedDocument(words=['community', 'legal', 'services', 'already', 'stretched', 'beyond', 'limits', 'bracing', 'cuts'], tags=[166]),
#  TaggedDocument(words=['researchers', 'able', 'map', 'length', 'onto', 'age'], tags=[167]),
#  TaggedDocument(words=['north', 'sea', 'oil', 'workers', 'resume', 'talks', 'suspend', 'strike'], tags=[168]),
#  TaggedDocument(words=['creative', 'differences', 'set', 'disagreement'], tags=[169]),
#  TaggedDocument(words=['may', 'case', 'unknown', 'assailants', 'recognised', 'near', 'apartment', 'escape'], tags=[170]),
#  TaggedDocument(words=['many', 'people', 'work', 'builder', 'yards', 'help', 'caretakers', 'voluntary', 'work', 'provides', 'motivation', 'orderly', 'way', 'annika', 'deuschle', 'reports'], tags=[171]),
#  TaggedDocument(words=['germany', 'need', 'cap'], tags=[172]),
#  TaggedDocument(words=['trump', 'new', 'york', 'businessman', 'lawyers', 'cited', 'audit', 'internal', 'revenue', 'service', 'reason', 'refusal', 'release', 'returns'], tags=[173]),
#  TaggedDocument(words=['amount', 'times', 'seen', 'police', 'unbelievable'], tags=[174]),
#  TaggedDocument(words=['personally', 'recommend', 'visit', 'cities', 'isfahan', 'shiraz', 'yazd', 'preserved', 'monuments', 'ancient', 'persian', 'civilization', 'good', 'condition', 'said'], tags=[175]),
#  TaggedDocument(words=['provisionally', 'recommending', 'ticagrelor', 'pleased', 'able', 'increase', 'treatment', 'options', 'available', 'many', 'thousands', 'people', 'stand', 'benefit'], tags=[176]),
#  TaggedDocument(words=['addition', 'thought', 'must', 'given', 'putting', 'homes', 'back', 'price', 'maintenance', 'scenario'], tags=[177]),
#  TaggedDocument(words=['haigerloch', 'pilgrims', 'gates', 'mercy'], tags=[178]),
#  TaggedDocument(words=['stark', 'contrast', 'donald', 'trump', 'hiding', 'behind', 'fake', 'excuses', 'backtracking', 'previous', 'promises', 'release', 'tax', 'returns'], tags=[179]),
#  TaggedDocument(words=['number', 'slumped', 'almost'], tags=[180]),
#  TaggedDocument(words=['efforts', 'bma', 'resolve', 'dispute', 'talks', 'met', 'unwillingness', 'engage', 'times', 'deafening', 'silence', 'government'], tags=[181]),
#  TaggedDocument(words=['police', 'use', 'tear', 'gas', 'rubber', 'bullets', 'protesting', 'brazilian', 'students'], tags=[182]),
#  TaggedDocument(words=['last', 'year', 'police', 'officer', 'acquitted', 'causing', 'death', 'negligence', 'hit', 'killed', 'man', 'lying', 'near', 'paynerne', 'one', 'night', 'august'], tags=[183]),
#  TaggedDocument(words=['instead', 'republican', 'congressional', 'candidates', 'would', 'offered', 'support'], tags=[184]),
#  TaggedDocument(words=['instead', 'drunk', 'attacker', 'sliced', 'ex', 'girlfriend', 'clothes'], tags=[185]),
#  TaggedDocument(words=['people', 'signed', 'petition', 'protect', 'kids', 'cafe'], tags=[186]),
#  TaggedDocument(words=['according', 'microsoft', 'beam', 'integrated', 'video', 'games', 'department', 'linked', 'xbox', 'console'], tags=[187]),
#  TaggedDocument(words=['taking', 'part', 'protest', 'could', 'seen', 'writing', 'graffiti', 'walls', 'interim', 'president', 'michel', 'temer'], tags=[188]),
#  TaggedDocument(words=['britain', 'must', 'channel', 'olympic', 'spirit', 'expand', 'heathrow'], tags=[189]),
#  TaggedDocument(words=['big', 'meeting', 'royal', 'ascot', 'mundane', 'friday', 'night', 'people'], tags=[190]),
#  TaggedDocument(words=['ban', 'political', 'campaigners', 'activists', 'handling', 'completed', 'postal', 'votes', 'postal', 'vote', 'envelopes'], tags=[191]),
#  TaggedDocument(words=['risked', 'everything', 'save', 'people', 'lives'], tags=[192]),
#  TaggedDocument(words=['exactly', 'countries'], tags=[193]),
#  TaggedDocument(words=['honoured', 'work'], tags=[194]),
#  TaggedDocument(words=['nuno', 'arroja', 'added', 'surfing', 'swear', 'felt', 'like', 'plane', 'going', 'fall', 'top'], tags=[195]),
#  TaggedDocument(words=['midst', 'olympic', 'mania', 'promise', 'quiet', 'lovely', 'moment', 'one', 'likely', 'overlooked', 'general', 'melee'], tags=[196]),
#  TaggedDocument(words=['mr', 'meles', 'former', 'rebel', 'leader', 'ethiopia', 'prime', 'minister', 'years', 'death', 'undisclosed', 'illness'], tags=[197]),
#  TaggedDocument(words=['spd', 'head', 'sigmar', 'gabriel', 'showed', 'party', 'happy', 'discuss', 'issue', 'albeit', 'sensitively', 'first', 'saying', 'spd', 'prepared', 'discuss', 'anything', 'increase', 'security'], tags=[198]),
#  TaggedDocument(words=['freed', 'civilian', 'hostages', 'held', 'militants', 'sharfan', 'darwish', 'sdf', 'allied', 'manbij', 'military', 'council', 'told', 'reuters'], tags=[199]),
#  TaggedDocument(words=['according', 'kokert', 'play', 'minor', 'role'], tags=[200]),
#  TaggedDocument(words=['russian', 'public', 'opinion', 'also', 'turned', 'since', 'november'], tags=[201]),
#  TaggedDocument(words=['homes', 'alone', 'trick'], tags=[202]),
#  TaggedDocument(words=['would', 'hoy'], tags=[203]),
#  TaggedDocument(words=['cbs', 'affiliate', 'wwl', 'reports', 'alderwoman', 'tangipahoa', 'said', 'homes', 'flooded'], tags=[204]),
#  TaggedDocument(words=['said', 'trump', 'unfit', 'office'], tags=[205]),
#  TaggedDocument(words=['end', 'contract', 'december', 'work', 'consultant', 'youth', 'coach', 'full', 'pay'], tags=[206]),
#  TaggedDocument(words=['previous', 'record', 'holder', 'year', 'old', 'greenland', 'whale', 'whose', 'neck', 'year', 'old', 'harpoon', 'tip', 'lodged', 'caught', 'alaska'], tags=[207]),
#  TaggedDocument(words=['company', 'know', 'playing', 'pok', 'mon', 'go', 'sees', 'raw', 'data', 'exercise', 'levels'], tags=[208]),
#  TaggedDocument(words=['senate', 'majority', 'leader', 'mitch', 'mcconnell', 'says', 'next', 'president', 'choose', 'person', 'replace', 'late', 'supreme', 'court', 'justice', 'antonin', 'scalia'], tags=[209]),
#  TaggedDocument(words=['th', 'ringen', 'zeiss', 'meditec', 'comes', 'closer', 'reaching', 'billion', 'turnover'], tags=[210]),
#  TaggedDocument(words=['want', 'try', 'new', 'hobby', 'delay', 'even', 'think', 'got', 'much', 'talent', 'lenz', 'suggests'], tags=[211]),
#  TaggedDocument(words=['new', 'location', 'perks'], tags=[212]),
#  TaggedDocument(words=['kenny', 'next', 'competes', 'sprint', 'begins', 'today', 'plays', 'three', 'days'], tags=[213]),
#  TaggedDocument(words=['blog', 'post', 'adblock', 'spokesperson', 'ben', 'williams', 'wrote', 'sort', 'back', 'forth', 'battle', 'open', 'source', 'ad', 'blocking', 'community', 'circumventers', 'going', 'since', 'ad', 'blocking', 'invented', 'possible', 'facebook', 'would', 'come', 'fix', 'soon'], tags=[214]),
#  TaggedDocument(words=['sewage', 'fee', 'sewage', 'works', 'azendorf', 'raised', 'necessary', 'carry', 'improvement', 'works'], tags=[215]),
#  TaggedDocument(words=['inflation', 'bulgaria', 'monthly', 'basis', 'july', 'national', 'statistics', 'show'], tags=[216]),
#  TaggedDocument(words=['afd', 'would', 'represented', 'house', 'first', 'time', 'percent'], tags=[217]),
#  TaggedDocument(words=['jennifer', 'aniston', 'always', 'pigeonholed'], tags=[218]),
#  TaggedDocument(words=['issues', 'already', 'discussed', 'refugees'], tags=[219]),
#  TaggedDocument(words=['benefits', 'restructuring', 'programme', 'become', 'visible', 'years', 'said'], tags=[220]),
#  TaggedDocument(words=['germany', 'around', 'percent', 'companies', 'already', 'targeted', 'ransomware', 'attack'], tags=[221]),
#  TaggedDocument(words=['peanut', 'loaf', 'liver', 'loaf', 'bean', 'loaf'], tags=[222]),
#  TaggedDocument(words=['dispute', 'commissaires', 'yesterday', 'ahead', 'qualification', 'ride', 'officials', 'summoned', 'measure', 'height'], tags=[223]),
#  TaggedDocument(words=['conversion', 'made', 'break'], tags=[224]),
#  TaggedDocument(words=['tangipahoa', 'parish', 'city', 'hammond', 'close', 'two', 'dozen', 'streets', 'closed', 'high', 'water', 'sandbags', 'made', 'available', 'pickup', 'residents', 'hoping', 'keep', 'water', 'homes', 'businesses'], tags=[225]),
#  TaggedDocument(words=['senate', 'democratic', 'leader', 'harry', 'reid', 'says', 'convinced', 'democratic', 'presidential', 'candidate', 'hillary', 'clinton', 'nominate', 'judge', 'merrick', 'garland', 'supreme', 'court', 'elected', 'president'], tags=[226]),
#  TaggedDocument(words=['military', 'officials', 'distorted', 'isis', 'intelligence', 'congressional', 'panel', 'says'], tags=[227]),
#  TaggedDocument(words=['greenland', 'sharks', 'swim', 'leisurely', 'along', 'sea', 'floor', 'north', 'atlantic', 'covering', 'average', 'metres', 'hour'], tags=[228]),
#  TaggedDocument(words=['giss', 'model', 'simulation', 'venus', 'slow', 'spin', 'exposes', 'dayside', 'sun', 'almost', 'two', 'months', 'time', 'giss', 'scientist', 'anthony', 'del', 'genio', 'explained', 'news', 'release'], tags=[229]),
#  TaggedDocument(words=['despite', 'complains', 'g', 'hner', 'convinced', 'restaurant', 'survive'], tags=[230]),
#  TaggedDocument(words=['donald', 'trump', 'really', 'mind', 'lost', 'us', 'presidential', 'election', 'november', 'either', 'work', 'go', 'long', 'long', 'holiday', 'republican', 'candidate', 'said', 'telephone', 'interview', 'us', 'television', 'channel', 'cnbc'], tags=[231]),
#  TaggedDocument(words=['interested', 'singing', 'absolutely', 'join', 'choir', 'hackler', 'thinks'], tags=[232]),
#  TaggedDocument(words=['g', 'hner', 'knows', 'districts', 'people', 'acted', 'generously'], tags=[233]),
#  TaggedDocument(words=['according', 'wez', 'older', 'customers', 'taken', 'umbrage', 'contactless', 'payment', 'system', 'particular'], tags=[234]),
#  TaggedDocument(words=['de', 'maizi', 'planning', 'employ', 'undercover', 'agents', 'hunt', 'criminals', 'particular', 'areas', 'internet', 'dark', 'web'], tags=[235]),
#  TaggedDocument(words=['previously', 'many', 'used', 'spears', 'defend'], tags=[236]),
#  TaggedDocument(words=['belarussian', 'injured', 'rib', 'quarter', 'final', 'german', 'european', 'champion', 'dimitrij', 'ovtcharov', 'given', 'medical', 'treatment', 'ultimately', 'content', 'fourth', 'place'], tags=[237]),
#  TaggedDocument(words=['family', 'lived', 'house', 'years', 'police', 'regularly', 'called', 'property'], tags=[238]),
#  TaggedDocument(words=['would', 'easy', 'open', 'second', 'house'], tags=[239]),
#  TaggedDocument(words=['traffic', 'diverted', 'past', 'construction', 'site', 'single', 'lane', 'tuesday', 'wednesday'], tags=[240]),
#  TaggedDocument(words=['matter', 'successful', 'rodriguez', 'nicknamed', 'rod', 'pitch', 'behaviour', 'pitch', 'controversial'], tags=[241]),
#  TaggedDocument(words=['kerstin', 'neugebauer', 'little', 'sympathy', 'people', 'moved', 'irritated', 'paint', 'bombs', 'housing', 'project', 'left', 'wing', 'scene', 'part', 'district'], tags=[242]),
#  TaggedDocument(words=['iphone', 'holds', 'least', 'gigabytes'], tags=[243]),
#  TaggedDocument(words=['teenagers', 'children', 'get', 'outside', 'play', 'preferring', 'spend', 'free', 'time', 'looking', 'screens', 'lament', 'many', 'past', 'decade'], tags=[244]),
#  TaggedDocument(words=['someone', 'watching', 'guys', 'today'], tags=[245]),
#  TaggedDocument(words=['large', 'amount', 'uncertainty'], tags=[246]),
#  TaggedDocument(words=['realized', 'coffee', 'culture', 'verb', 'liked', 'said'], tags=[247]),
#  TaggedDocument(words=['heavy', 'rain', 'widespread', 'flooding', 'louisiana', 'lead', 'governor', 'declare', 'state', 'emergency', 'friday', 'rain', 'expected', 'state', 'saturday'], tags=[248]),
#  TaggedDocument(words=['took', 'train', 'horb', 'starting', 'point', 'villingen', 'cathedral', 'lady', 'found', 'started', 'pilgrimage', 'cathedral'], tags=[249]),
#  TaggedDocument(words=['post', 'taken', 'another', 'close', 'putin', 'ally', 'dmitry', 'medvedev'], tags=[250]),
#  TaggedDocument(words=['want', 'say', 'last', 'race'], tags=[251]),
#  TaggedDocument(words=['field', 'manager', 'condrobs', 'provider', 'social', 'assistance', 'within', 'bavaria', 'one', 'issues', 'deals', 'refugee', 'women'], tags=[252]),
#  TaggedDocument(words=['people', 'probably', 'working', 'hard', 'school', 'offices'], tags=[253]),
#  TaggedDocument(words=['also', 'loves', 'playing', 'two', 'brothers', 'singing'], tags=[254]),
#  TaggedDocument(words=['crime', 'passionelle', 'bargteheide', 'man', 'shoots', 'partner'], tags=[255]),
#  TaggedDocument(words=['actually', 'asked', 'prognosis', 'forever', 'expect', 'anyone', 'really', 'able', 'tell'], tags=[256]),
#  TaggedDocument(words=['latest', 'protest', 'comes', 'days', 'protesters', 'took', 'streets', 'en', 'masse', 'support', 'suspended', 'president', 'dilma', 'rousseff', 'country', 'senate', 'voted', 'impeachment'], tags=[257]),
#  TaggedDocument(words=['zhang', 'alone', 'table', 'coaches', 'sets', 'time', 'outs'], tags=[258]),
#  TaggedDocument(words=['going', 'happen'], tags=[259]),
#  TaggedDocument(words=['nima', 'association', 'young', 'theatre', 'planning', 'musical', 'project'], tags=[260]),
#  TaggedDocument(words=['general', 'austin', 'retired', 'april', 'replaced', 'central', 'command', 'gen', 'joseph', 'l', 'votel'], tags=[261]),
#  TaggedDocument(words=['mata', 'viliame', 'iced', 'fijian', 'cake', 'need', 'icing', 'another', 'try', 'dying', 'moments'], tags=[262]),
#  TaggedDocument(words=['republican', 'strongholds', 'wavering'], tags=[263]),
#  TaggedDocument(words=['many', 'choirs', 'elderly', 'also', 'found', 'online'], tags=[264]),
#  TaggedDocument(words=['also', 'solidified', 'black', 'latina', 'female', 'presence', 'top', 'sport'], tags=[265]),
#  TaggedDocument(words=['junior', 'doctors', 'medical', 'students', 'voted', 'july', 'reject', 'contract', 'deal', 'agreed', 'bma'], tags=[266]),
#  TaggedDocument(words=['ulster', 'bank', 'brand', 'already', 'used', 'customers', 'republic', 'ireland', 'northern', 'ireland'], tags=[267]),
#  TaggedDocument(words=['feels', 'much', 'better', 'said'], tags=[268]),
#  TaggedDocument(words=['lost', 'one'], tags=[269]),
#  TaggedDocument(words=['suit', 'comes', 'two', 'days', 'republican', 'presidential', 'nominee', 'caused', 'furore', 'telling', 'crowd', 'north', 'carolina', 'second', 'amendment', 'people', 'understood', 'gun', 'owners', 'gun', 'enthusiasts', 'could', 'take', 'action', 'rival', 'hillary', 'clinton', 'elected', 'gets', 'pick', 'judges'], tags=[270]),
#  TaggedDocument(words=['country', 'track', 'field', 'athletes', 'medals', 'world', 'championships', 'beijing'], tags=[271]),
#  TaggedDocument(words=['us', 'company', 'said', 'entered', 'year', 'contract', 'loy', 'yang', 'due', 'commence', 'november', 'year', 'although', 'yet', 'explain', 'pulled', 'contract'], tags=[272]),
#  TaggedDocument(words=['mr', 'coe', 'last', 'book', 'chop', 'suey', 'chinese', 'cuisine', 'america', 'ms', 'ziegelman', 'told', 'story', 'life', 'lower', 'east', 'side', 'tenement', 'food', 'book', 'orchard'], tags=[273]),
#  TaggedDocument(words=['creating', 'opportunities', 'local', 'people', 'firms', 'close', 'heathrow'], tags=[274]),
#  TaggedDocument(words=['last', 'month', 'protesters', 'gondar', 'amhara', 'town', 'attacked', 'businesses', 'owned', 'tigrayans', 'anti', 'tigrayan', 'hatred', 'becoming', 'common', 'social', 'media'], tags=[275]),
#  TaggedDocument(words=['tiago', 'eight', 'years', 'old', 'made', 'great', 'strides', 'schooled', 'privately', 'new', 'york', 'best', 'therapists', 'located'], tags=[276]),
#  TaggedDocument(words=['family', 'business', 'moved', 'back', 'said', 'referring', 'long', 'history'], tags=[277]),
#  TaggedDocument(words=['time', 'right', 'us', 'move', 'bank', 'brands', 'underneath', 'asking', 'focus', 'making', 'better', 'bank', 'customers', 'said', 'chief', 'executive'], tags=[278]),
#  TaggedDocument(words=['last', 'time', 'two', 'german', 'tennis', 'players', 'quarter', 'finals', 'summer', 'games'], tags=[279]),
#  TaggedDocument(words=['seriously', 'injured', 'man', 'stabs', 'ex', 'girlfriend'], tags=[280]),
#  TaggedDocument(words=['busted', 'sample', 'tested', 'positive', 'doping', 'weightlifter', 'adrian', 'zielinksi', 'poland', 'allowed', 'compete', 'rio'], tags=[281]),
#  TaggedDocument(words=['issue', 'doping', 'continues', 'hit', 'headlines', 'olympic', 'games', 'rio'], tags=[282]),
#  TaggedDocument(words=['women', 'qualifiers', 'finals', 'take', 'place', 'friday', 'afternoon', 'streaming', 'p', 'eastern', 'time', 'men', 'saturday', 'also'], tags=[283]),
#  TaggedDocument(words=['three', 'time', 'champion', 'jockey', 'dettori', 'earlier', 'ghayyar', 'said', 'special'], tags=[284]),
#  TaggedDocument(words=['therefore', 'decisive', 'factor', 'whether', 'people', 'exert', 'controlling', 'influence', 'party'], tags=[285]),
#  TaggedDocument(words=['victim', 'brother', 'says', 'think', 'anyone', 'would', 'want', 'hurt', 'saying', 'things', 'finally', 'going', 'well'], tags=[286]),
#  TaggedDocument(words=['salon', 'set', 'p', 'p', 'aug', 'salle', 'moderne', 'art', 'deco', 'southwestern', 'school', 'law', 'formerly', 'bullocks', 'wilshire', 'wilshire', 'blvd'], tags=[287]),
#  TaggedDocument(words=['mr', 'wright', 'became', 'known', 'testing', 'durability', 'gut', 'travelling', 'around', 'world', 'eating', 'weird', 'wonderful', 'things'], tags=[288]),
#  TaggedDocument(words=['child', 'found', 'shot', 'front', 'seat', 'car', 'along', 'year', 'old', 'critical', 'condition', 'station', 'reports'], tags=[289]),
#  TaggedDocument(words=['remuneration', 'system', 'swimming', 'poor', 'doping', 'tests', 'hand', 'good', 'says'], tags=[290]),
#  TaggedDocument(words=['company', 'reduced', 'value', 'difficult', 'economic', 'climate', 'impacted', 'second', 'quarter', 'profits', 'particular'], tags=[291]),
#  TaggedDocument(words=['finnish', 'mobile', 'phone', 'manufacturer', 'presented', 'product', 'couple', 'months', 'previously', 'cebit', 'computer', 'trade', 'fair', 'hanover', 'billing', 'office', 'fit', 'pocket'], tags=[292]),
#  TaggedDocument(words=['scene', 'looks', 'normal'], tags=[293]),
#  TaggedDocument(words=['year', 'old', 'taking', 'part', 'olympic', 'games'], tags=[294]),
#  TaggedDocument(words=['last', 'year', 'officials', 'said', 'mr', 'hooker', 'team', 'concluded', 'despite', 'public', 'statements', 'contrary', 'airstrikes', 'islamic', 'state', 'held', 'refineries', 'significantly', 'weakened', 'terrorist', 'group', 'finances', 'built', 'makeshift', 'refineries', 'sell', 'oil', 'black', 'market'], tags=[295]),
#  TaggedDocument(words=['incident', 'described', 'lawsuit', 'filed', 'wednesday', 'state', 'court', 'charlotte', 'vincent', 'bordini', 'former', 'software', 'trainer', 'state', 'campaign'], tags=[296]),
#  TaggedDocument(words=['personally', 'desire', 'perfect', 'successful', 'time'], tags=[297]),
#  TaggedDocument(words=['midst', 'winter', 'many', 'victims', 'would', 'pay', 'ransom', 'blocked', 'heating', 'turned', 'back'], tags=[298]),
#  TaggedDocument(words=['committee', 'pleased', 'hear', 'mayor', 'robert', 'putz', 'announcement', 'finally', 'begin', 'market', 'residential', 'construction', 'sites', 'recently', 'marked'], tags=[299]),
#  TaggedDocument(words=['team', 'gb', 'come', 'rely', 'mighty', 'track', 'cycling', 'squad', 'take', 'ownership', 'middle', 'period', 'olympic', 'games', 'deliver', 'host', 'medals'], tags=[300]),
#  TaggedDocument(words=['result', 'way', 'bus', 'positioned', 'people', 'able', 'leave', 'bus', 'said'], tags=[301]),
#  TaggedDocument(words=['deny', 'taking', 'neither', 'allowed', 'compete', 'weight', 'category', 'kg'], tags=[302]),
#  TaggedDocument(words=['two', 'women', 'entered', 'apartment', 'year', 'old', 'pushed', 'sister', 'one', 'side', 'attacked', 'ex', 'girlfriend'], tags=[303]),
#  TaggedDocument(words=['book', 'tells', 'mrs', 'roosevelt', 'hiring', 'housekeeper', 'interest', 'flavor', 'resulted', 'white', 'house', 'put', 'dreariest', 'food', 'washington', 'also', 'dismally', 'prepared'], tags=[304]),
#  TaggedDocument(words=['supercup', 'barca', 'worried', 'facing', 'sevilla'], tags=[305]),
#  TaggedDocument(words=['guided', 'club', 'points', 'first', 'place', 'finish', 'central', 'division', 'colorado', 'upset', 'minnesota', 'first', 'round', 'playoffs', 'missed', 'postseason', 'last', 'two', 'years'], tags=[306]),
#  TaggedDocument(words=['rebounds', 'seeming', 'weightless', 'astronaut', 'going', 'effortlessly'], tags=[307]),
#  TaggedDocument(words=['must', 'also', 'say', 'decisions', 'impact', 'team', 'performance'], tags=[308]),
#  TaggedDocument(words=['almost', 'weightlifters', 'nation', 'plagued', 'doping', 'allowed', 'participate', 'rio'], tags=[309]),
#  TaggedDocument(words=['hero', 'aleppo', 'khaled', 'omar', 'dedicated', 'life', 'syrian', 'people'], tags=[310]),
#  TaggedDocument(words=['tickfaw', 'river', 'south', 'mississippi', 'state', 'line', 'liverpool', 'louisiana', 'already', 'highest', 'level', 'ever', 'recorded', 'friday'], tags=[311]),
#  TaggedDocument(words=['several', 'day', 'trips', 'agenda'], tags=[312]),
#  TaggedDocument(words=['thickness', 'closely', 'resembling', 'coffee', 'table', 'book', 'fashion', 'magazine', 'issue', 'attracts', 'huge', 'number', 'advertisers', 'fashionista', 'counted', 'last', 'year', 'page', 'tome', 'advertising', 'content'], tags=[313]),
#  TaggedDocument(words=['million', 'tons', 'produced', 'good', 'six', 'percent', 'less', 'raw', 'steel', 'corresponding', 'month', 'previous', 'year', 'steel', 'association', 'reported', 'friday'], tags=[314]),
#  TaggedDocument(words=['motors', 'comply', 'euro', 'emissions', 'standards'], tags=[315]),
#  TaggedDocument(words=['said', 'innocent', 'explanation', 'could', 'food', 'supplements', 'athlete', 'explained'], tags=[316]),
#  TaggedDocument(words=['want', 'start', 'selling', 'third', 'parties', 'postal', 'service', 'spokesman', 'said', 'friday'], tags=[317]),
#  TaggedDocument(words=['even', 'reused', 'lights', 'old', 'verb'], tags=[318]),
#  TaggedDocument(words=['mr', 'schiff', 'democrats', 'said', 'found', 'evidence', 'white', 'house', 'tried', 'pressure', 'centcom', 'analysts', 'fit', 'conclusions', 'preset', 'political', 'narrative'], tags=[319]),
#  TaggedDocument(words=['bernhard', 'langer', 'kept', 'distance', 'large', 'animals'], tags=[320]),
#  TaggedDocument(words=['schmidt', 'justifies', 'major', 'fee', 'increases', 'saying', 'three', 'sewage', 'plants', 'relatively', 'small', 'deal', 'small', 'amount', 'waste', 'namely', 'cubic', 'metres', 'pear'], tags=[321]),
#  TaggedDocument(words=['gb', 'made', 'wholesale', 'changes', 'half', 'time', 'plugged', 'fijian', 'dam', 'four', 'minutes', 'first', 'half', 'standards', 'good', 'josua', 'tuisova', 'went', 'brilliant', 'fijian', 'interplay'], tags=[322]),
#  TaggedDocument(words=['india', 'come', 'game', 'without', 'victory', 'tournament', 'team', 'proved', 'surprisingly', 'tough', 'kept', 'score', 'late', 'third', 'period', 'bam', 'took', 'charge'], tags=[323]),
#  TaggedDocument(words=['mr', 'ivanov', 'deputy', 'since', 'anton', 'vaino', 'appointed', 'successor'], tags=[324]),
#  TaggedDocument(words=['drive', 'past', 'places', 'also', 'nice'], tags=[325]),
#  TaggedDocument(words=['older', 'generations', 'singing', 'together', 'seen', 'important', 'part', 'daily', 'life', 'school', 'leisure', 'time', 'explains'], tags=[326]),
#  TaggedDocument(words=['annika', 'deutschle', 'contact', 'person', 'integration', 'organisation'], tags=[327]),
#  TaggedDocument(words=['collector', 'think', 'lot', 'people'], tags=[328]),
#  TaggedDocument(words=['filing', 'thursday', 'u', 'district', 'judge', 'beth', 'labson', 'freeman', 'said', 'gilead', 'entitled', 'relief', 'fees', 'incurred', 'defending', 'case'], tags=[329]),
#  TaggedDocument(words=['repeated', 'trick', 'finishing', 'lowly', 'sixth', 'march', 'track', 'world', 'championships', 'london', 'despite', 'hoy', 'since', 'retired'], tags=[330]),
#  TaggedDocument(words=['incident', 'triggered', 'quite', 'response', 'online', 'people', 'calling', 'scandal'], tags=[331]),
#  TaggedDocument(words=['donald', 'trump', 'explains', 'obama', 'founded', 'isis', 'claim', 'sarcasm'], tags=[332]),
#  TaggedDocument(words=['chinese', 'swimmer', 'chen', 'xinyi', 'meter', 'hurdler', 'silwia', 'danekowa', 'bulgaria', 'polish', 'weightlifter', 'adrian', 'zielinski', 'tested', 'positive', 'brazil', 'excluded', 'start', 'athletics', 'competition', 'escaped', 'criticism', 'news', 'comes', 'bad', 'time'], tags=[333]),
#  TaggedDocument(words=['lenses', 'blunt', 'feature', 'warping', 'tools', 'generate', 'million', 'enhanced', 'selfies', 'day'], tags=[334]),
#  TaggedDocument(words=['though', 'mustafina', 'took', 'small', 'lead', 'two', 'rotations', 'mirage'], tags=[335]),
#  TaggedDocument(words=['may', 'changing'], tags=[336]),
#  TaggedDocument(words=['ross', 'mcewan', 'told', 'bbc', 'scotland', 'rbs', 'brand', 'associated', 'bank', 'global', 'ambitions'], tags=[337]),
# ...
#  TaggedDocument(words=['investment', 'infrastructure', 'trump', 'clinton', 'say', 'almost', 'verbatim'], tags=[893]),
#  TaggedDocument(words=['cafe', 'longer', 'serves', 'beer', 'makes', 'fresh', 'juices'], tags=[894]),
#  TaggedDocument(words=['waking', 'early', 'common', 'depression', 'particular', 'says', 'wee'], tags=[895]),
#  TaggedDocument(words=['sincerely', 'regret', 'statements', 'made', 'allowed', 'go', 'air'], tags=[896]),
#  TaggedDocument(words=['screen', 'time', 'initially', 'limited', 'television', 'video', 'games', 'recently', 'smartphones'], tags=[897]),
#  TaggedDocument(words=['spokesperson', 'sons', 'daughters', 'said', 'shocked', 'devastated', 'death'], tags=[898]),
#  TaggedDocument(words=['steinh', 'user', 'perspective', 'plants', 'mentioned', 'remain', 'precarious', 'situation', 'long', 'run', 'especially', 'area', 'covered', 'friesenbachtal', 'wastewater', 'association', 'cannot', 'expanded', 'include', 'plants', 'running', 'deficit'], tags=[899]),
#  TaggedDocument(words=['verb', 'closed', 'said', 'gave', 'drinking', 'coffee'], tags=[900]),
#  TaggedDocument(words=['well', 'turns', 'presidential', 'chief', 'staff', 'four', 'years', 'eight', 'months'], tags=[901]),
#  TaggedDocument(words=['edmund', 'walks', 'help', 'walker'], tags=[902]),
#  TaggedDocument(words=['committee', 'upper', 'ministrants', 'st', 'anna', 'decided', 'prepare', 'go', 'pilgrimage', 'lasting', 'several', 'days', 'bridge', 'gap', 'next', 'pilgrimage', 'rome', 'ministrants', 'likely', 'take', 'place', 'two', 'years', 'time'], tags=[903]),
#  TaggedDocument(words=['time', 'managing', 'million', 'euros', 'could', 'withdrawn', 'day', 'unable', 'make', 'use'], tags=[904]),
#  TaggedDocument(words=['hotel', 'clerk', 'said', 'measure', 'deliberate', 'decision', 'management', 'kempinski', 'hotels'], tags=[905]),
#  TaggedDocument(words=['de', 'maizi', 'also', 'presented', 'new', 'ideas'], tags=[906]),
#  TaggedDocument(words=['olympic', 'games', 'sydney', 'eric', 'moussambani', 'race', 'also', 'drew', 'media', 'attention'], tags=[907]),
#  TaggedDocument(words=['lord', 'paul', 'deighton', 'chairman', 'heathrow', 'board', 'former', 'commercial', 'secretary', 'treasury'], tags=[908]),
#  TaggedDocument(words=['clearing', 'away', 'toxic', 'remains', 'bomb', 'children', 'play', 'quoted', 'bild', 'last', 'words', 'died'], tags=[909]),
#  TaggedDocument(words=['one', 'said', 'care', 'anybody'], tags=[910]),
#  TaggedDocument(words=['trio', 'fortunate', 'able', 'begin', 'treatment', 'start', 'season', 'keeping', 'disruption', 'minimum', 'ever', 'right', 'expression', 'circumstances'], tags=[911]),
#  TaggedDocument(words=['russia', 'putin', 'sacks', 'chief', 'staff', 'sergei', 'ivanov'], tags=[912]),
#  TaggedDocument(words=['scottish', 'member', 'parliament', 'dave', 'anderson', 'met', 'labor', 'leaders', 'earlier', 'week', 'discuss', 'one', 'biggest', 'labor', 'disputes', 'strike', 'north', 'sea', 'generation'], tags=[913]),
#  TaggedDocument(words=['interested', 'keeping', 'sound', 'voice', 'age', 'singing', 'perfect', 'hobby'], tags=[914]),
#  TaggedDocument(words=['body', 'found', 'westfield', 'mall', 'wednesday', 'morning', 'identified', 'year', 'old', 'san', 'francisco', 'resident', 'frank', 'galicia', 'san', 'francisco', 'medical', 'examiner', 'office', 'said'], tags=[915]),
#  TaggedDocument(words=['collision', 'warning', 'system', 'irritating', 'occasionally', 'parking', 'sees', 'lots', 'obstacles', 'approaching', 'objects'], tags=[916]),
#  TaggedDocument(words=['helen', 'glover', 'heather', 'stanning', 'lost', 'race', 'five', 'years'], tags=[917]),
#  TaggedDocument(words=['victim', 'lying', 'motorway', 'middle', 'night'], tags=[918]),
#  TaggedDocument(words=['forecaster', 'alek', 'krautmann', 'said', 'rivers', 'could', 'flood', 'many', 'houses', 'suburban', 'areas', 'near', 'baton', 'rouge'], tags=[919]),
#  TaggedDocument(words=['said', 'needed', 'reflect', 'analyse', 'reasons', 'behind', 'debacle'], tags=[920]),
#  TaggedDocument(words=['global', 'sales', 'devices', 'amount', 'around', 'billion', 'euros'], tags=[921]),
#  TaggedDocument(words=['case', 'dates', 'back', 'gilead', 'merck', 'sued', 'claiming', 'ownership', 'laboratory', 'work', 'underlying', 'sofosbuvir', 'active', 'ingredient', 'gilead', 'drugs'], tags=[922]),
#  TaggedDocument(words=['paris', 'easy', 'find', 'vacant', 'high', 'quality', 'offices', 'said', 'voigtl', 'nder'], tags=[923]),
#  TaggedDocument(words=['probably', 'ask', 'camera', 'stop', 'rolling', 'next', 'bit', 'stand', 'close', 'various', 'men', 'stores', 'attempt', 'gauge', 'age', 'emotional', 'disposition', 'via', 'observation'], tags=[924]),
#  TaggedDocument(words=['part', 'ms', 'zhu', 'said', 'would', 'keep', 'snapchat', 'account', 'closed', 'adding', 'wonder', 'actually', 'need', 'users', 'like', 'us', 'able', 'say', 'k'], tags=[925]),
#  TaggedDocument(words=['however', 'years', 'ago', 'communicator', 'sparked', 'sensation'], tags=[926]),
#  TaggedDocument(words=['oscar', 'winner', 'dior', 'ambassador', 'jennifer', 'lawrence', 'featured', 'year', 'lady', 'gaga', 'honour'], tags=[927]),
#  TaggedDocument(words=['burst', 'tears', 'final', 'total', 'posted', 'long', 'journey', 'moment', 'ended'], tags=[928]),
#  TaggedDocument(words=['thicker', 'larger', 'harder', 'hold'], tags=[929]),
#  TaggedDocument(words=['rather', 'less', 'magical', 'sounds', 'seats', 'back', 'flipped', 'like', 'cinema', 'seats', 'reveal', 'additional', 'loading', 'space', 'measuring', 'floor', 'ceiling'], tags=[930]),
#  TaggedDocument(words=['anyone', 'information', 'asked', 'call', 'sfpd', 'tip', 'line'], tags=[931]),
#  TaggedDocument(words=['brother', 'went', 'flow'], tags=[932]),
#  TaggedDocument(words=['bomb', 'terror', 'thailand', 'one', 'austrian', 'woman', 'injured', 'several', 'dead'], tags=[933]),
#  TaggedDocument(words=['judge', 'jean', 'fran', 'ois', 'molla', 'said', 'groceries', 'cafes', 'restaurants', 'played', 'much', 'bigger', 'role', 'simply', 'feeding', 'people', 'live', 'extremely', 'precarious', 'conditions'], tags=[934]),
#  TaggedDocument(words=['analysts', 'wary', 'possible', 'closure', 'portland', 'smelter', 'victoria', 'also', 'tomago', 'plant', 'near', 'newcastle', 'due', 'poor', 'economics', 'industry'], tags=[935]),
#  TaggedDocument(words=['today', 'dealing', 'refugees', 'back', 'puerto', 'ricans', 'gone', 'new', 'york', 'residents', 'new', 'york', 'want'], tags=[936]),
#  TaggedDocument(words=['also', 'dangerous', 'expensive', 'keep', 'assembling', 'unassembling', 'speed', 'camera', 'points'], tags=[937]),
#  TaggedDocument(words=['exciting', 'see', 'neuling', 'afd', 'carves', 'things', 'whether', 'coalition', 'formed', 'left', 'end'], tags=[938]),
#  TaggedDocument(words=['hoy', 'retirement', 'also', 'created', 'void', 'kian', 'emadi', 'matt', 'crampton', 'tried', 'fill'], tags=[939]),
#  TaggedDocument(words=['way', 'things', 'going', 'simply', 'ridiculous', 'summer', 'holidays', 'heat', 'state', 'parliament', 'elections', 'clash', 'one', 'another'], tags=[940]),
#  TaggedDocument(words=['expansion', 'opportunity', 'create', 'new', 'jobs', 'bn', 'economic', 'growth', 'leaving', 'legacy', 'skills', 'employment', 'around', 'airport', 'across', 'uk'], tags=[941]),
#  TaggedDocument(words=['attacks', 'thursday', 'friday', 'came', 'days', 'controversial', 'referendum', 'constitution', 'drawn', 'military', 'junta'], tags=[942]),
#  TaggedDocument(words=['addition', 'many', 'people', 'worried', 'security', 'large', 'numbers', 'refugees'], tags=[943]),
#  TaggedDocument(words=['infrastructure', 'improved', 'drastically', 'even', 'new', 'commuter', 'train', 'capital', 'addis', 'ababa'], tags=[944]),
#  TaggedDocument(words=['trump', 'wants', 'build', 'coal', 'fired', 'power', 'stations', 'bring', 'coal', 'production', 'usa', 'back'], tags=[945]),
#  TaggedDocument(words=['another', 'long', 'running', 'comparison', 'tennis', 'star', 'rafael', 'nadal', 'actor', 'josh', 'hartnett', 'boast', 'similar', 'heavy', 'brow', 'lips'], tags=[946]),
#  TaggedDocument(words=['attempt', 'deceive', 'doping', 'check', 'olympic', 'village', 'kenya', 'sent', 'one', 'coach', 'home'], tags=[947]),
#  TaggedDocument(words=['interim', 'report', 'task', 'force', 'established', 'republican', 'chairmen', 'house', 'armed', 'services', 'committee', 'intelligence', 'committee', 'defense', 'appropriations', 'subcommittee', 'found', 'widespread', 'dissatisfaction', 'among', 'central', 'command', 'intelligence', 'analysts', 'said', 'superiors', 'doctoring', 'assessments', 'american', 'efforts', 'defeat', 'islamic', 'state'], tags=[948]),
#  TaggedDocument(words=['competition', 'fierce', 'risk', 'investors', 'move', 'competitors'], tags=[949]),
#  TaggedDocument(words=['widely', 'criticized', 'election', 'last', 'year', 'governing', 'party', 'allies', 'got', 'last', 'seat', 'opposition', 'held', 'control', 'percent', 'parliament'], tags=[950]),
#  TaggedDocument(words=['access', 'internet', 'ask', 'family', 'friends', 'neighbours', 'help', 'look', 'things', 'online'], tags=[951]),
#  TaggedDocument(words=['praised', 'garland', 'said', 'clinton', 'team', 'would', 'want', 'rock', 'boat', 'new', 'pick'], tags=[952]),
#  TaggedDocument(words=['politico', 'reported', 'trump', 'paid', 'zero', 'little', 'taxes', 'two', 'years', 'new', 'york', 'times', 'business', 'columnist', 'friday', 'quoted', 'number', 'tax', 'lawyers', 'accountants', 'saying', 'could', 'still', 'case'], tags=[953]),
#  TaggedDocument(words=['despite', 'sending', 'athletes', 'compete', 'united', 'states', 'never', 'medal', 'trampoline', 'athlete', 'advance', 'finals'], tags=[954]),
#  TaggedDocument(words=['data', 'theft', 'perfidiously', 'hackers', 'extort', 'ransom', 'money'], tags=[955]),
#  TaggedDocument(words=['reid', 'says', 'clinton', 'stick', 'garland', 'supreme', 'court', 'nominee', 'elected'], tags=[956]),
#  TaggedDocument(words=['suffering', 'like', 'left', 'spd', 'greens', 'hardly', 'present', 'across', 'large', 'swathes', 'region'], tags=[957]),
#  TaggedDocument(words=['ex', 'cabinet', 'minister', 'sir', 'eric', 'pickles', 'lambasts', 'police', 'election', 'watchdogs', 'town', 'halls', 'ignoring', 'evidence', 'electoral', 'abuse', 'sensitivities', 'ethnicity', 'religion'], tags=[958]),
#  TaggedDocument(words=['critics', 'state', 'increase', 'budgetary', 'deficit'], tags=[959]),
#  TaggedDocument(words=['letter', 'sent', 'guardian', 'said', 'closure', 'would', 'catastrophe', 'children', 'young', 'eight'], tags=[960]),
#  TaggedDocument(words=['later', 'managed', 'presidential', 'protocol', 'government', 'staff', 'kremlin', 'website', 'says', 'russian'], tags=[961]),
#  TaggedDocument(words=['wheel', 'drive', 'available'], tags=[962]),
#  TaggedDocument(words=['mr', 'coe', 'went', 'back', 'seconds', 'thirds'], tags=[963]),
#  TaggedDocument(words=['delicate', 'tolerances', 'team', 'working', 'tiny', 'millimetres', 'either', 'way'], tags=[964]),
#  TaggedDocument(words=['top', 'united', 'nations', 'human', 'rights', 'official', 'calling', 'thorough', 'investigation'], tags=[965]),
#  TaggedDocument(words=['wide', 'reaching', 'issues', 'first', 'discussed', 'within', 'parties'], tags=[966]),
#  TaggedDocument(words=['year', 'old', 'skinner', 'glasgow', 'said', 'flattering', 'comparison'], tags=[967]),
#  TaggedDocument(words=['london', 'took', 'six', 'months', 'realise', 'olympic', 'champion'], tags=[968]),
#  TaggedDocument(words=['clear', 'long', 'prices', 'remain', 'perked'], tags=[969]),
#  TaggedDocument(words=['danekowa', 'suspended', 'precaution', 'according', 'bnt', 'b', 'sample', 'also', 'tested', 'postive'], tags=[970]),
#  TaggedDocument(words=['focus', 'reported', 'volkswagen', 'would', 'provide', 'german', 'customers', 'guarantee', 'modified', 'diesel', 'cars', 'nonetheless'], tags=[971]),
#  TaggedDocument(words=['female', 'cats', 'tell', 'agitated', 'kittens', 'miaowing'], tags=[972]),
#  TaggedDocument(words=['fantastic', 'ambassador', 'racing', 'enthusiasm', 'charisma', 'drawing', 'fans', 'sport', 'years'], tags=[973]),
#  TaggedDocument(words=['floor', 'boards', 'pulled', 'property', 'drugs', 'dealt', 'past'], tags=[974]),
#  TaggedDocument(words=['happened', 'centcom', 'unacceptable', 'war', 'fighters', 'suffer', 'bad', 'analysis', 'presented', 'senior', 'policy', 'makers', 'said', 'representative', 'ken', 'calvert', 'republican', 'california'], tags=[975]),
#  TaggedDocument(words=['leading', 'new', 'verb', 'cisco', 'rodriguez', 'longtime', 'employee', 'old', 'cafe', 'owner', 'general', 'manager', 'new', 'place'], tags=[976]),
#  TaggedDocument(words=['bomb', 'attacks', 'bear', 'signature', 'said', 'army', 'general', 'danai', 'kritmethavee', 'journalists', 'early', 'friday', 'morning'], tags=[977]),
#  TaggedDocument(words=['two', 'women', 'year', 'old', 'girl', 'died', 'deadliest', 'attack', 'phoenix', 'first', 'serial', 'killer', 'case', 'decade', 'sitting', 'car', 'talking', 'listening', 'music', 'shot', 'according', 'police', 'reports', 'released', 'thursday'], tags=[978]),
#  TaggedDocument(words=['vw', 'using', 'term', 'guarantee'], tags=[979]),
#  TaggedDocument(words=['investigators', 'declined', 'reveal', 'evidence', 'led', 'conclude', 'attacks', 'related', 'committed', 'killer'], tags=[980]),
#  TaggedDocument(words=['said', 'jet', 'flown', 'slightly', 'lower', 'normal', 'poor', 'visibility', 'caused', 'smoke', 'nearby', 'wildfires', 'air', 'force', 'insisted', 'one', 'safety', 'compromised'], tags=[981]),
#  TaggedDocument(words=['association', 'described', 'segment', 'bavarian', 'radio'], tags=[982]),
#  TaggedDocument(words=['child', 'grandparents', 'identified', 'cbs', 'philadelphia', 'mahaj', 'brown'], tags=[983]),
#  TaggedDocument(words=['however', 'pokmeon', 'success', 'games', 'combine', 'apps', 'virtual', 'reality', 'active', 'real', 'world', 'helping', 'many', 'people', 'hunt', 'active', 'fitter', 'healthier'], tags=[984]),
#  TaggedDocument(words=['added', 'hard', 'argue', 'side', 'side', 'comparison', 'gross', 'asian', 'caricature', 'filter', 'effects'], tags=[985]),
#  TaggedDocument(words=['recent', 'sunday', 'rebecca', 'oliveira', 'one', 'customer'], tags=[986]),
#  TaggedDocument(words=['according', 'german', 'association', 'sector', 'steel', 'industry', 'threatened', 'additional', 'costs', 'ranging', 'million', 'euros', 'year'], tags=[987]),
#  TaggedDocument(words=['treats', 'president', 'steve', 'shaw', 'told', 'us', 'earlier', 'year', 'nude', 'heavy', 'magazine', 'differs', 'old', 'school', 'playboys', 'playboy', 'men'], tags=[988]),
#  TaggedDocument(words=['four', 'minutes', 'clock', 'jerry', 'tuwai', 'added', 'another', 'right', 'wing', 'converted'], tags=[989]),
#  TaggedDocument(words=['criticism', 'twitter', 'came', 'thick', 'fast', 'byron', 'macdonald', 'many', 'calling'], tags=[990]),
#  TaggedDocument(words=['thing', 'turned', 'filthy', 'russian', 'public', 'toilet'], tags=[991]),
#  TaggedDocument(words=['happiest', 'person', 'earth'], tags=[992]),
#  TaggedDocument(words=['lost', 'count'], tags=[993]),
#  TaggedDocument(words=['teaching', 'sign', 'language', 'picciuto', 'told', 'cbs', 'news'], tags=[994]),
#  TaggedDocument(words=['moves', 'follows', 'speculation', 'future', 'plant', 'several', 'years', 'initially', 'wake', 'strong', 'australian', 'dollar', 'recently', 'due', 'price', 'output', 'plant'], tags=[995]),
#  TaggedDocument(words=['important', 'football', 'match', 'taking', 'place', 'turkey', 'first', 'time', 'following', 'attempted', 'coup'], tags=[996]),
#  TaggedDocument(words=['volkswagen', 'delivered', 'percent', 'vehicles', 'time', 'period', 'coming', 'global', 'total', 'million'], tags=[997]),
#  TaggedDocument(words=['new', 'york', 'donald', 'trump', 'campaign', 'sued', 'allegedly', 'nothing', 'told', 'director', 'north', 'carolina', 'operations', 'pulled', 'gun', 'staffer', 'drove', 'jeep', 'february'], tags=[998]),
#  TaggedDocument(words=['steinh', 'user', 'pointed', 'even', 'low', 'amount', 'sewage', 'coming', 'three', 'plants', 'expenses', 'running', 'maintaining', 'significantly', 'impacted'], tags=[999]),
#  ...]

# %%
## Train doc2vec model
model_Doc2Vec = Doc2Vec(tagged_data, vector_size = 5, window = 2, min_count = 1, epochs = 100)

# %%
model_Doc2Vec.wv.index_to_key
# Out:
# ['said',
#  'people',
#  'year',
#  'one',
#  'time',
#  'new',
#  'years',
#  'also',
#  'would',
#  'first',
#  'old',
#  'mr',
#  'two',
#  'police',
#  'like',
#  'around',
#  'percent',
#  'even',
#  'last',
#  'world',
#  'according',
#  'could',
#  'many',
#  'three',
#  'olympic',
#  'says',
#  'trump',
#  'state',
#  'women',
#  'back',
#  'day',
#  'team',
#  'long',
#  'company',
#  'thursday',
#  'made',
#  'friday',
#  'already',
#  'put',
#  'group',
#  'germany',
#  'euros',
#  'since',
#  'president',
#  'take',
#  'work',
#  'months',
#  'get',
#  'men',
#  'make',
#  'million',
#  'clinton',
#  'water',
#  'association',
#  'good',
#  'games',
#  'final',
#  'another',
#  'country',
#  'however',
#  'security',
#  'still',
#  'way',
#  'left',
#  'go',
#  'able',
#  'right',
#  'going',
#  'saying',
#  'much',
#  'place',
#  'rio',
#  'told',
#  'customers',
#  'used',
#  'well',
#  'house',
#  'things',
#  'say',
#  'doping',
#  'second',
#  'four',
#  'come',
#  'start',
#  'bank',
#  'several',
#  'record',
#  'found',
#  'end',
#  'young',
#  'result',
#  'line',
#  'see',
#  'set',
#  'government',
#  'german',
#  'us',
#  'ago',
#  'north',
#  'attacks',
#  'market',
#  'home',
#  'want',
#  'champion',
#  'wants',
#  'number',
#  'director',
#  'gold',
#  'head',
#  'court',
#  'olympics',
#  'within',
#  'part',
#  'report',
#  'took',
#  'next',
#  'social',
#  'may',
#  'clear',
#  'past',
#  'got',
#  'almost',
#  'family',
#  'federal',
#  'along',
#  'refugees',
#  'across',
#  'sleep',
#  'came',
#  'london',
#  'night',
#  'city',
#  'de',
#  'russian',
#  'july',
#  'called',
#  'taken',
#  'run',
#  'every',
#  'days',
#  'district',
#  'life',
#  'sport',
#  'game',
#  'small',
#  'coach',
#  'putin',
#  'central',
#  'woman',
#  'system',
#  'use',
#  'help',
#  'american',
#  'important',
#  'election',
#  'star',
#  'video',
#  'away',
#  'announced',
#  'doctors',
#  'campaign',
#  'today',
#  'little',
#  'went',
#  'case',
#  'always',
#  'spd',
#  'far',
#  'man',
#  'g',
#  'great',
#  'reported',
#  'e',
#  'five',
#  'without',
#  'homes',
#  'near',
#  'despite',
#  'statement',
#  'street',
#  'positive',
#  'children',
#  'think',
#  'attack',
#  'turkey',
#  'contract',
#  'pay',
#  'month',
#  'risk',
#  'need',
#  'addition',
#  'large',
#  'middle',
#  'recently',
#  'given',
#  'media',
#  'early',
#  'six',
#  'week',
#  'cdu',
#  'previous',
#  'intelligence',
#  'money',
#  'news',
#  'air',
#  'ahead',
#  'vehicles',
#  'staff',
#  'russia',
#  'previously',
#  'summer',
#  'period',
#  'top',
#  'companies',
#  'stars',
#  'states',
#  'september',
#  'change',
#  'person',
#  'better',
#  'residents',
#  'issue',
#  'housing',
#  'low',
#  'republican',
#  'authorities',
#  'really',
#  'situation',
#  'former',
#  'per',
#  'minister',
#  'community',
#  'less',
#  'business',
#  'berlin',
#  'speed',
#  'gymnastics',
#  'project',
#  'wanted',
#  'often',
#  'side',
#  'looking',
#  'bridge',
#  'high',
#  'private',
#  'steel',
#  'nothing',
#  'close',
#  'greenland',
#  'vote',
#  'athletes',
#  'including',
#  'local',
#  'particular',
#  'never',
#  'whether',
#  'additional',
#  'road',
#  'ethiopia',
#  'singing',
#  'times',
#  'saw',
#  'ms',
#  'medal',
#  'biles',
#  'hard',
#  'presidential',
#  'reports',
#  'full',
#  'least',
#  'committee',
#  'military',
#  'lot',
#  'floor',
#  'jobs',
#  'led',
#  'west',
#  'international',
#  'traffic',
#  'problems',
#  'banned',
#  'age',
#  'might',
#  'british',
#  'tax',
#  'show',
#  'taking',
#  'bad',
#  'service',
#  'south',
#  'particularly',
#  'car',
#  'move',
#  'example',
#  'look',
#  'became',
#  'facebook',
#  'recent',
#  'bit',
#  'among',
#  'areas',
#  'making',
#  'know',
#  'members',
#  'health',
#  'general',
#  'records',
#  'soon',
#  'live',
#  'heart',
#  'give',
#  'involved',
#  'call',
#  'increase',
#  'york',
#  'seen',
#  'model',
#  'party',
#  'legal',
#  'eight',
#  'best',
#  'release',
#  'course',
#  'find',
#  'half',
#  'earlier',
#  'twitter',
#  'something',
#  'return',
#  'u',
#  'anyone',
#  'violence',
#  'likely',
#  'public',
#  'gun',
#  'added',
#  'rodriguez',
#  'swimmer',
#  'must',
#  'sewage',
#  'construction',
#  'erdogan',
#  'anything',
#  'television',
#  'chinese',
#  'candidate',
#  'junior',
#  'site',
#  'b',
#  'terms',
#  'council',
#  'economic',
#  'season',
#  'needs',
#  'islamic',
#  'fans',
#  'plant',
#  'support',
#  'europe',
#  'force',
#  'race',
#  'gb',
#  'track',
#  'online',
#  'industry',
#  'analysts',
#  'school',
#  'feel',
#  'managing',
#  'performance',
#  'older',
#  'fact',
#  'lower',
#  'ad',
#  'software',
#  'hand',
#  'banks',
#  'released',
#  'vinyl',
#  'britain',
#  'player',
#  'currently',
#  'investigation',
#  'political',
#  'killed',
#  'lost',
#  'later',
#  'works',
#  'competition',
#  'operations',
#  'hit',
#  'simone',
#  'action',
#  'quarter',
#  'east',
#  'hotel',
#  'china',
#  'leave',
#  'spin',
#  'morning',
#  'behind',
#  'donald',
#  'point',
#  'together',
#  'weeks',
#  'food',
#  'post',
#  'keep',
#  'national',
#  'snapchat',
#  'aged',
#  'ever',
#  'lives',
#  'trade',
#  'anti',
#  'power',
#  'june',
#  'users',
#  'silver',
#  'member',
#  'allowed',
#  'tourists',
#  'town',
#  'shop',
#  'decision',
#  'following',
#  'play',
#  'plants',
#  'protection',
#  'sharks',
#  'data',
#  'moved',
#  'thousands',
#  'syria',
#  'partner',
#  'parliament',
#  'enough',
#  'camp',
#  'someone',
#  'accommodation',
#  'office',
#  'late',
#  'similar',
#  'training',
#  'area',
#  'official',
#  'shark',
#  'alone',
#  'officials',
#  'shot',
#  'music',
#  'property',
#  'front',
#  'become',
#  'bring',
#  'working',
#  'holiday',
#  'everything',
#  'financial',
#  'possible',
#  'regional',
#  'victory',
#  'win',
#  'medical',
#  'treatment',
#  'coup',
#  'open',
#  'future',
#  'venus',
#  'war',
#  'due',
#  'shooting',
#  'services',
#  'ban',
#  'european',
#  'centcom',
#  'tested',
#  'comes',
#  'slow',
#  'wrote',
#  'thanks',
#  'problem',
#  'means',
#  'board',
#  'research',
#  'played',
#  'responsible',
#  'using',
#  'moment',
#  'cover',
#  'returns',
#  'via',
#  'poll',
#  'died',
#  'probably',
#  'brand',
#  'serious',
#  'reached',
#  'field',
#  'free',
#  'asked',
#  'explained',
#  'refugee',
#  'communities',
#  'global',
#  'instead',
#  'electricity',
#  'perpetrators',
#  'verb',
#  'rates',
#  'sea',
#  'coming',
#  'explains',
#  'newspaper',
#  'costs',
#  'brought',
#  'others',
#  'try',
#  'cannot',
#  'available',
#  'term',
#  'let',
#  'started',
#  'generation',
#  'third',
#  'female',
#  'maizi',
#  'compared',
#  'user',
#  'gets',
#  'countries',
#  'current',
#  'iran',
#  'rate',
#  'turned',
#  'hope',
#  'tried',
#  'groups',
#  'wing',
#  'brands',
#  'l',
#  'coffee',
#  'infrastructure',
#  'interest',
#  'reality',
#  'building',
#  'choir',
#  'workers',
#  'big',
#  'build',
#  'higher',
#  'reason',
#  'supply',
#  'prepared',
#  'history',
#  'st',
#  'fees',
#  'station',
#  'hunt',
#  'p',
#  'couple',
#  'united',
#  'though',
#  'success',
#  'event',
#  'running',
#  'centres',
#  'latest',
#  'entire',
#  'league',
#  'democratic',
#  'attempted',
#  'saturday',
#  'elderly',
#  'seven',
#  'management',
#  'showed',
#  'wednesday',
#  'kenya',
#  'billion',
#  'book',
#  'chance',
#  'thought',
#  'provide',
#  'either',
#  'effect',
#  'major',
#  'mecklenburg',
#  'cent',
#  'department',
#  'heathrow',
#  'elections',
#  'list',
#  'happened',
#  'vehicle',
#  'internet',
#  'interior',
#  'cbc',
#  'ziegelman',
#  'various',
#  'ivanov',
#  'carry',
#  'nearly',
#  'tuesday',
#  'special',
#  'kunde',
#  'magazine',
#  'issues',
#  'administration',
#  'paid',
#  'spokesperson',
#  'smelter',
#  'evidence',
#  'chief',
#  'victim',
#  'cost',
#  'th',
#  'medals',
#  'drug',
#  'region',
#  'information',
#  'towards',
#  'drugs',
#  'coalition',
#  'hoy',
#  'focus',
#  'sir',
#  'mother',
#  'opened',
#  'nine',
#  'quite',
#  'male',
#  'shops',
#  'investment',
#  'postal',
#  'cornwall',
#  'true',
#  'continue',
#  'obama',
#  'control',
#  'key',
#  'bma',
#  'huge',
#  'fiji',
#  'cats',
#  'lived',
#  'account',
#  'strong',
#  'files',
#  'question',
#  'winning',
#  'fourth',
#  'ransomware',
#  'emergency',
#  'quickly',
#  'finally',
#  'greens',
#  'champions',
#  'command',
#  'press',
#  'actually',
#  'lens',
#  'lane',
#  'taxes',
#  'figures',
#  'august',
#  'lead',
#  'turnover',
#  'pressure',
#  'vw',
#  'death',
#  'victims',
#  'law',
#  'scene',
#  'role',
#  'metres',
#  'leader',
#  'deuschle',
#  'provided',
#  'mass',
#  'sun',
#  'based',
#  'hands',
#  'cafe',
#  'expected',
#  'restaurants',
#  'face',
#  'generally',
#  'caused',
#  'known',
#  'located',
#  'real',
#  'tournament',
#  'especially',
#  'terrorism',
#  'manager',
#  'room',
#  'beam',
#  'incident',
#  'thing',
#  'trampoline',
#  'strength',
#  'efforts',
#  'co',
#  'clearly',
#  'rain',
#  'economy',
#  'athlete',
#  'animal',
#  'average',
#  'proved',
#  'doubt',
#  'dispute',
#  'bomb',
#  'affected',
#  'space',
#  'relay',
#  'ground',
#  'motorway',
#  'stra',
#  'energy',
#  'date',
#  'longer',
#  'issued',
#  'include',
#  'neighbours',
#  'amount',
#  'explain',
#  'j',
#  'title',
#  'climate',
#  'sector',
#  'suffered',
#  'threat',
#  'stay',
#  'perfect',
#  'thinks',
#  'hour',
#  'asylum',
#  'researchers',
#  'fight',
#  'cluster',
#  'spokesman',
#  'behaviour',
#  'animals',
#  'michael',
#  'emotional',
#  'exercise',
#  'meeting',
#  'points',
#  'protect',
#  'majority',
#  'closure',
#  'train',
#  'seconds',
#  'simply',
#  'remain',
#  'pulled',
#  'matter',
#  'living',
#  'spent',
#  'happy',
#  'programme',
#  'apartment',
#  'difficult',
#  'janeiro',
#  'scandal',
#  'level',
#  'prime',
#  'task',
#  'passed',
#  'concerns',
#  'places',
#  'different',
#  'described',
#  'vorpommern',
#  'injured',
#  'contact',
#  'stop',
#  'gave',
#  'coe',
#  'surprise',
#  'metre',
#  'white',
#  'contracts',
#  'terrorist',
#  'yet',
#  'usa',
#  'cash',
#  'muslim',
#  'main',
#  'step',
#  'discuss',
#  'surface',
#  'eric',
#  'removed',
#  'response',
#  'table',
#  'potential',
#  'gfk',
#  'businesses',
#  'macdonald',
#  'largest',
#  'talk',
#  'individual',
#  'land',
#  'ambassador',
#  'fire',
#  'calling',
#  'mrs',
#  'afternoon',
#  'believes',
#  'revealed',
#  'bacteria',
#  'planning',
#  'language',
#  'film',
#  'name',
#  'volunteers',
#  'crime',
#  'heavy',
#  'act',
#  'poor',
#  'section',
#  'leaders',
#  'october',
#  'forward',
#  'pleiades',
#  'offered',
#  'damage',
#  'effective',
#  'count',
#  'winner',
#  'impact',
#  'series',
#  'closed',
#  'kenny',
#  'twice',
#  'minutes',
#  'jenner',
#  'blocking',
#  'spring',
#  'boat',
#  'hillary',
#  'done',
#  'certainly',
#  'mobile',
#  'sometimes',
#  'keeping',
#  'meaning',
#  'continued',
#  'outside',
#  'massive',
#  'significant',
#  'bavaria',
#  'agreement',
#  'order',
#  'blockers',
#  'isis',
#  'deck',
#  'w',
#  'sold',
#  'youth',
#  'love',
#  'wide',
#  'hindes',
#  'swimming',
#  'rather',
#  'talking',
#  'tour',
#  'fit',
#  'executive',
#  'rhine',
#  'pilgrimage',
#  'improved',
#  'atmosphere',
#  'tennis',
#  'getting',
#  'ex',
#  'garland',
#  'sound',
#  'republicans',
#  'related',
#  'process',
#  'met',
#  'regine',
#  'judge',
#  'centre',
#  'redevelopment',
#  'served',
#  'brown',
#  'events',
#  'hardly',
#  'complete',
#  'camera',
#  'gilead',
#  'san',
#  'officers',
#  'fall',
#  'foundation',
#  'francisco',
#  'agl',
#  'changes',
#  'ensure',
#  'frankfurt',
#  'plans',
#  'parish',
#  'firm',
#  'wall',
#  'bus',
#  'built',
#  'battle',
#  'sexual',
#  'evening',
#  'scientists',
#  'body',
#  'crimes',
#  'successful',
#  'houses',
#  'seems',
#  'heat',
#  'sales',
#  'interview',
#  'visit',
#  'hall',
#  'ioc',
#  'rejected',
#  'gymnast',
#  'spokeswoman',
#  'sense',
#  'produced',
#  'light',
#  'criminal',
#  'raised',
#  'girls',
#  'carbon',
#  'total',
#  'analysis',
#  'semi',
#  'immediately',
#  'demand',
#  'sign',
#  'follow',
#  'ller',
#  'plane',
#  'dangerous',
#  'lack',
#  'putting',
#  'afd',
#  'looks',
#  'sample',
#  'actress',
#  'price',
#  'becoming',
#  'oil',
#  'directly',
#  'disorders',
#  'en',
#  'girl',
#  'results',
#  'younger',
#  'nice',
#  'daily',
#  'prevent',
#  'senior',
#  'travel',
#  'weight',
#  'mind',
#  'investors',
#  'beyond',
#  'moscow',
#  'march',
#  'fresh',
#  'hr',
#  'study',
#  'portland',
#  'eating',
#  'playing',
#  'africa',
#  'journey',
#  'multiple',
#  'forces',
#  'comment',
#  'residential',
#  'skinner',
#  'whose',
#  'knickers',
#  'gabby',
#  'position',
#  'stand',
#  'eye',
#  'mean',
#  'react',
#  'posted',
#  'fraud',
#  'suffering',
#  'sister',
#  'depression',
#  'swim',
#  'published',
#  ...]

# %%
x = model_Doc2Vec.infer_vector(df_cp['w_reference'][4])

# %%
model_Doc2Vec.docvecs.most_similar([x])
# Out:
# [(8613, 0.9949114918708801),
#  (8242, 0.994421660900116),
#  (10956, 0.9931619763374329),
#  (811, 0.992548942565918),
#  (16707, 0.9924169182777405),
#  (1106, 0.992290198802948),
#  (6425, 0.9918161034584045),
#  (177, 0.9916792511940002),
#  (16479, 0.9914894104003906),
#  (2194, 0.9901847839355469)]

# %%
t = model_Doc2Vec.infer_vector(df_cp['w_translation'][4])

# %%
r = model_Doc2Vec.infer_vector(df_cp['w_reference'][4])

# %%
t
# Out:
# array([ 0.7540549 , -0.23823501,  0.45477074, -2.0242496 , -1.1178677 ],
#       dtype=float32)

# %%
r
# Out:
# array([ 0.55538803, -0.62329966,  0.40882438, -1.6991106 , -0.24646209],
#       dtype=float32)

# %% [markdown]
# ## Similarity

# %% [markdown]
# ## Doc2Vec + Cosine Similarity

# %%
from scipy import spatial
def cosinesimilarity(ref,trans):
    t = model_Doc2Vec.infer_vector(trans)
    r = model_Doc2Vec.infer_vector(ref)
    result = 1 - spatial.distance.cosine(t,r)
    return result

# %% [markdown]
# REF: https://www.machinelearningplus.com/nlp/cosine-similarity/
#
# The cosine similarity is advantageous because even if the two similar documents are far apart by the Euclidean distance (due to the size of the document), chances are they may still be oriented closer together. The smaller the angle, higher the cosine similarity.

# %%
cosinesimilarity(df_cp['w_reference'][4],df_cp['w_translation'][4])
# Out:
# 0.918903648853302

# %% [markdown]
# **Interpretation** : A cosine value of 0 means that the two vectors are at 90 degrees to each other (orthogonal) and have no match. The closer the cosine value to 1, the smaller the angle and the greater the match between vectors.

# %% [markdown]
# ## W2V(google) + Word Mover Distance

# %% [markdown]
# REF: https://towardsdatascience.com/word-movers-distance-for-text-similarity-7492aeca71b0

# %%
cand_f = 'olympics  brazen cheating in doping tests'.split()

# %%
#libraries 
from time import time 
#remove stop words 
from nltk.corpus import stopwords
import os
from gensim import models
import gensim.downloader as api
from pyemd import emd

# %%
#tokenized data 
def delete_sw(lista):
    stop_words = stopwords.words('english')
    finalresult = []
    for sentence in lista:
        processed = sentence.split()
        clean = []
        for word in processed:
            if word not in stop_words:
                clean.append(word)
        finalresult.append(clean)
    return finalresult

# %%
modelGOOGLEWMD = api.load('word2vec-google-news-300')

# %%
distance = modelGOOGLEWMD.wmdistance(clean_ref[0],clean_cand)

# %% [markdown]
# https://towardsdatascience.com/word-distance-between-word-embeddings-cc3e9cf1d632
# https://radimrehurek.com/gensim/auto_examples/tutorials/run_wmd.html
#
# The sentence can have no similar words, but by the relevand words in each sentence, it's possible to identify the "semantical distance" between them.
# With this method we can evaluate how the reference of translation is close to the real translation.

# %% [markdown]
# ## BLEU

# %%
df_cp
# Out:
#                                                   source  \
# 0      Ihr Zeitlupentempo maßen sie, als sie vor Spit...
# 1      Er sagte, dass die Bereiche ruhige Treffpunkte...
# 2      Für die Geschäftsleute an der B 27 ist es nur ...
# 3      Diese Fähigkeit sei möglicherweise angeboren o...
# 4      Weil sie Wassertemperaturen um die sechs Grad ...
# ...                                                  ...
# 21699  Lt. Cmdr. Patrick Evans, ein Pressesprecher de...
# 21700  "Um ein Beispiel zu geben: Wenn ich ihn etwas ...
# 21701  Ein Grund dafür, dass nicht alle Nachbarn das ...
# 21702  Der Gewinn vor Zinsen und Steuern erhöhte sich...
# 21703  Großbritannien und die Vereinigten Staaten wer...
#
#                                                reference  \
# 0      Her timeless pace measures them when they equi...
# 1      He said the areas offer quiet meeting points b...
# 2      For businessmen at the B 27, it's only a small...
# 3      This ability may be born or developed with gen...
# 4      Because they prefer water temperatures around ...
# ...                                                  ...
# 21699  Lt. Cmdr. Patrick Evans, a press officer at th...
# 21700  "To give an example: If I ask him something th...
# 21701  One reason that not all neighbours view this a...
# 21702  Profit before interest and tax increased from ...
# 21703  Britain and the United States will clash on Sa...
#
#                                              translation   z-score  avg-score  \
# 0      Their slow speed was measured by researchers o... -0.345024       76.0
# 1      He said the spaces provided calm meeting point...  0.903800       97.5
# 2      This is only a small consolation for businesse...  0.700503       94.0
# 3      This ability may be innate, or may develop as ... -1.256572       51.5
# 4      They generally only come to the surface in win...  0.293909       87.0
# ...                                                  ...       ...        ...
# 21699  Lt. Cmdr. Patrick Evans, a Pentagon spokesman,...  1.246459      100.0
# 21700  "To give an example: If I ask him what happene...  0.792878       98.0
# 21701  One reason for not all neighbours seeing this ...  0.597068       76.0
# 21702  Profits before interest and taxes increased fr... -0.305719       61.0
# 21703  Britain and the United States will meet on Sat...  0.995212       97.0
#
#        annotators                                        p_reference  \
# 0               1  timeless pace measures equipped six animals br...
# 1               2  said areas offer quiet meeting points refugees...
# 2               1  businessmen b     it s small consolation custo...
# 3               2        ability may born developed gender maturity
# 4               2  prefer water temperatures around six degrees c...
# ...           ...                                                ...
# 21699           1  lt  cmdr  patrick evans  press officer pentago...
# 21700           1   to give example  ask something two years back...
# 21701           1  one reason neighbours view problem may necessa...
# 21702           1  profit interest tax increased       million   ...
# 21703           1  britain united states clash saturday last game...
#
#                                            p_translation  \
# 0      slow speed measured researchers svalbard  fitt...
# 1      said spaces provided calm meeting points refug...
# 2      small consolation businesses located along b  ...
# 3      ability may innate  may develop animal reaches...
# 4      generally come surface winter prefer water tem...
# ...                                                  ...
# 21699  lt  cmdr  patrick evans  pentagon spokesman  s...
# 21700   to give example  ask happened two years ago s...
# 21701  one reason neighbours seeing problem could dir...
# 21702  profits interest taxes increased      million ...
# 21703  britain united states meet saturday last game ...
#
#                                              w_reference  \
# 0      [timeless, pace, measures, equipped, six, anim...
# 1      [said, areas, offer, quiet, meeting, points, r...
# 2      [businessmen, b, small, consolation, customers...
# 3      [ability, may, born, developed, gender, maturity]
# 4      [prefer, water, temperatures, around, six, deg...
# ...                                                  ...
# 21699  [lt, cmdr, patrick, evans, press, officer, pen...
# 21700  [give, example, ask, something, two, years, ba...
# 21701  [one, reason, neighbours, view, problem, may, ...
# 21702  [profit, interest, tax, increased, million, mi...
# 21703  [britain, united, states, clash, saturday, las...
#
#                                            w_translation  D2V_CosSim  \
# 0      [slow, speed, measured, researchers, svalbard,...    0.425661
# 1      [said, spaces, provided, calm, meeting, points...    0.829815
# 2      [small, consolation, businesses, located, alon...    0.917814
# 3      [ability, may, innate, may, develop, animal, r...    0.325962
# 4      [generally, come, surface, winter, prefer, wat...    0.931308
# ...                                                  ...         ...
# 21699  [lt, cmdr, patrick, evans, pentagon, spokesman...    0.916019
# 21700  [give, example, ask, happened, two, years, ago...    0.921230
# 21701  [one, reason, neighbours, seeing, problem, cou...    0.937846
# 21702  [profits, interest, taxes, increased, million,...    0.765729
# 21703  [britain, united, states, meet, saturday, last...    0.819329
#
#         D2V_WMD  W2VGoogle_WMD           BLEU
# 0      0.626473       0.887293  6.089710e-155
# 1      0.376303       0.376988   3.655552e-01
# 2      0.452215       0.649186  6.848991e-155
# 3      0.459583       0.714501  6.739372e-155
# 4      0.174523       0.204553   6.315552e-01
# ...         ...            ...            ...
# 21699  0.305339       0.394128   3.682362e-01
# 21700  0.235791       0.374207   4.493016e-78
# 21701  0.240191       0.439362   4.949020e-78
# 21702  0.317006       0.439875  8.572734e-155
# 21703  0.128742       0.136276   5.969492e-01
#
# [21704 rows x 14 columns]

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
df_cp.iloc[800,:]
# Out:
# source           CHIO: "Goldene Sportpyramide" für Bernhard Langer
# reference          CHIO: golden Sports Pyramid for Bernhard Langer
# translation       CHIO: "Golden Sport Pyramid" for Bernhard Langer
# z-score                                                   0.903944
# avg-score                                                     98.5
# annotators                                                       2
# p_reference            chio  golden sports pyramid bernhard langer
# p_translation         chio   golden sport pyramid  bernhard langer
# w_reference      [chio, golden, sports, pyramid, bernhard, langer]
# w_translation     [chio, golden, sport, pyramid, bernhard, langer]
# D2V_CosSim                                                0.951899
# D2V_WMD                                                   0.152974
# W2VGoogle_WMD                                             0.196382
# BLEU                                                   7.26212e-78
# Name: 800, dtype: object

# %%
score_bleu = sentence_bleu([df_cp['w_reference'][800]], df_cp['w_translation'][800])
score_bleu
# Out:
# 7.262123179505913e-78

# %% [markdown]
# ## ADD the embedding comparation in the table

# %%
df_cp['D2V_CosSim'] = df_cp.apply(lambda x:cosinesimilarity(x['w_reference'],x['w_translation']), axis=1)

# %%
df_cp['D2V_WMD'] = df_cp.apply(lambda x:model_Doc2Vec.wv.wmdistance(x['w_reference'],x['w_translation']), axis=1)

# %%
df_cp['W2VGoogle_WMD'] = df_cp.apply(lambda x:modelGOOGLEWMD.wmdistance(x['w_reference'],x['w_translation']), axis=1)

# %%
df_cp['BLEU'] = df_cp.apply(lambda x:sentence_bleu([x['w_reference']],x['w_translation']), axis=1)

# %%
df_cp.describe()
# Out:
#             z-score     avg-score    annotators    D2V_CosSim       D2V_WMD  \
# count  21704.000000  21704.000000  21704.000000  21704.000000  2.170400e+04
# mean       0.000898     71.852890      1.502995      0.681002           inf
# std        0.855140     26.348469      0.810923      0.306784           NaN
# min       -5.806322      0.000000      1.000000     -0.901142  0.000000e+00
# 25%       -0.499574     56.000000      1.000000      0.562007  2.575791e-01
# 50%        0.216756     79.000000      1.000000      0.778589  3.612081e-01
# 75%        0.640273     94.000000      2.000000      0.904721  4.863277e-01
# max        2.535434    100.000000      9.000000      0.999912           inf
#
#        W2VGoogle_WMD           BLEU
# count   2.170400e+04   2.170400e+04
# mean             inf   1.321164e-01
# std              NaN   2.196728e-01
# min     0.000000e+00   0.000000e+00
# 25%     3.566816e-01  6.836366e-155
# 50%     5.076215e-01   3.603235e-78
# 75%     6.671028e-01   2.624078e-01
# max              inf   1.000000e+00

# %%
df_cp2 = df_cp.copy()

# %%
len(df_cp2[df_cp2['D2V_WMD']==np.inf])/len(df_cp2)
# Out:
# 0.002165499447106524

# %%
df_filter = df_cp2[df_cp2['D2V_WMD']!=np.inf]

# %%
df_filter.sort_values(by='BLEU', ascending = False)
# Out:
#                                                   source  \
# 7317   Ich würde sagen, dass wir Bernsteins Musik wir...
# 19864  Medienberichten zufolge soll er bei seiner Rüc...
# 5783   "Ich habe Wasser an Orten gesehen, an denen ic...
# 11963  Aber es ist keine typische Zeichensprache -- s...
# 5740   "Singen bewegt mich - emotional und körperlich...
# ...                                                  ...
# 8280   Die fallen dafür nun aber umso umfangreicher aus.
# 10739                  Das ist wirklich sehr beschämend.
# 6140   Es war dicker und größer, es lag deshalb auch ...
# 13460          "Es handelt sich um einen Tötungsdelikt."
# 11957         Doch nur mit Wohnungen ist es nicht getan.
#
#                                                reference  \
# 7317   I would say we really have Bernstein's music i...
# 19864  According to media reports, he should have bee...
# 5783   "I've seen water in places I've never seen bef...
# 11963  But it is not a typical sign language -- it sa...
# 5740   "Singing moves me - emotionally and physically...
# ...                                                  ...
# 8280               But these are all the more extensive.
# 10739                      That is really very shameful.
# 6140   It was thick and bigger, so it was not good en...
# 13460                                  "It's a kill-up."
# 11957              But only with housing is it not done.
#
#                                              translation   z-score  avg-score  \
# 7317   I would say that we really have Bernstein's mu... -0.705823      85.50
# 19864  According to media reports, he was arrested on... -0.950026      63.00
# 5783   "I've seen water in some places I have never s...  0.660102     100.00
# 11963  But it's not just typical sign language -- she... -0.354548      52.00
# 5740   "Singing moves me - emotionally and physically...  1.241415     100.00
# ...                                                  ...       ...        ...
# 8280   However, they are more comprehensive as a result.  0.465052      94.50
# 10739                     It is in itself a great shame. -0.432157      74.75
# 6140      It was thicker and larger, and harder to hold. -1.586257      12.00
# 13460                                "It is a homicide." -1.939518       8.00
# 11957             But homes alone will not do the trick. -0.712967      50.00
#
#        annotators                                        p_reference  \
# 7317            2          would say really bernstein s music blood
# 19864           1  according media reports  arrested return nairo...
# 5783            1   i ve seen water places i ve never seen before...
# 11963           1  typical sign language    says  edmund invented...
# 5740            1   singing moves   emotionally physically   desc...
# ...           ...                                                ...
# 8280            2                                         extensive
# 10739           4                                   really shameful
# 6140            1                         thick bigger  good enough
# 13460           1                                     it s kill up
# 11957           1                                      housing done
#
#                                            p_translation  \
# 7317           would say really bernstein s music blood
# 19864  according media reports  arrested return nairo...
# 5783    i ve seen water places never seen before   to...
# 11963  it s typical sign language    says edmund inve...
# 5740    singing moves   emotionally physically   desc...
# ...                                                  ...
# 8280                      however  comprehensive result
# 10739                                       great shame
# 6140                        thicker larger  harder hold
# 13460                                      it homicide
# 11957                                 homes alone trick
#
#                                              w_reference  \
# 7317       [would, say, really, bernstein, music, blood]
# 19864  [according, media, reports, arrested, return, ...
# 5783   [seen, water, places, never, seen, townson, sa...
# 11963  [typical, sign, language, says, edmund, invent...
# 5740   [singing, moves, emotionally, physically, desc...
# ...                                                  ...
# 8280                                         [extensive]
# 10739                                 [really, shameful]
# 6140                       [thick, bigger, good, enough]
# 13460                                             [kill]
# 11957                                    [housing, done]
#
#                                            w_translation  D2V_CosSim  \
# 7317       [would, say, really, bernstein, music, blood]    0.998049
# 19864  [according, media, reports, arrested, return, ...    0.998481
# 5783   [seen, water, places, never, seen, townson, sa...    0.998734
# 11963  [typical, sign, language, says, edmund, invent...    0.998412
# 5740   [singing, moves, emotionally, physically, desc...    0.995982
# ...                                                  ...         ...
# 8280                    [however, comprehensive, result]    0.406999
# 10739                                     [great, shame]    0.282574
# 6140                     [thicker, larger, harder, hold]    0.733151
# 13460                                         [homicide]    0.643608
# 11957                              [homes, alone, trick]    0.768359
#
#         D2V_WMD  W2VGoogle_WMD  BLEU
# 7317   0.000000       0.000000   1.0
# 19864  0.000000       0.000000   1.0
# 5783   0.000000       0.000000   1.0
# 11963  0.000000       0.000000   1.0
# 5740   0.000000       0.000000   1.0
# ...         ...            ...   ...
# 8280   1.585227       1.225471   0.0
# 10739  1.059937       0.914778   0.0
# 6140   0.801476       0.995060   0.0
# 13460  0.971655       1.275968   0.0
# 11957  0.960720       1.216915   0.0
#
# [21657 rows x 14 columns]

# %% [markdown]
# ## Preprocessing Predictive model

# %%
df_predict = df_filter[['z-score','avg-score','D2V_CosSim','D2V_WMD','W2VGoogle_WMD','BLEU']]

# %%
sns.heatmap(df_predict.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.displot(df_predict, x='z-score')

# %%
df_predict[df_predict['z-score']>0].describe()
# Out:
#             z-score     avg-score    D2V_CosSim       D2V_WMD  W2VGoogle_WMD  \
# count  12671.000000  12671.000000  12671.000000  12671.000000   12671.000000
# mean       0.587915     88.946305      0.704635      0.353126       0.464023
# std        0.324137     10.256151      0.297713      0.191697       0.224630
# min        0.000564     43.000000     -0.860643      0.000000       0.000000
# 25%        0.338521     82.000000      0.593410      0.231273       0.310433
# 50%        0.581665     92.000000      0.801828      0.332107       0.454908
# 75%        0.810439     98.000000      0.918500      0.447327       0.607858
# max        2.535434    100.000000      0.999912      1.808193       1.375857
#
#                 BLEU
# count   1.267100e+04
# mean    1.636080e-01
# std     2.430007e-01
# min     0.000000e+00
# 25%    7.711524e-155
# 50%     4.493016e-78
# 75%     3.253289e-01
# max     1.000000e+00

# %%
colunas = df_predict.columns

# %%
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()

# %%
df_ncp = pd.DataFrame(scale.fit_transform(df_predict))

# %%
df_ncp.columns = colunas

# %%
df_ncp
# Out:
#         z-score  avg-score  D2V_CosSim   D2V_WMD  W2VGoogle_WMD      BLEU
# 0     -0.406514   0.156367   -0.842997  1.205879       1.570060 -0.602326
# 1      1.056184   0.973107    0.483581 -0.051906      -0.595015  1.060652
# 2      0.818070   0.840150    0.772427  0.329760       0.559842 -0.602326
# 3     -1.474174  -0.774336   -1.170243  0.366801       0.836956 -0.602326
# 4      0.341843   0.574234    0.816719 -1.066395      -1.326610  2.270735
# ...         ...        ...         ...       ...            ...       ...
# 21652  1.457526   1.068077    0.766532 -0.408690      -0.522299  1.072848
# 21653  0.926265   0.992101    0.783638 -0.758356      -0.606815 -0.602326
# 21654  0.696921   0.156367    0.838177 -0.736234      -0.330381 -0.602326
# 21655 -0.360478  -0.413451    0.273228 -0.350032      -0.328204 -0.602326
# 21656  1.163250   0.954113    0.449163 -1.296571      -1.616291  2.113306
#
# [21657 rows x 6 columns]

# %% [markdown]
# ## Predictive Model

# %%
X = df_ncp[['D2V_CosSim','D2V_WMD','W2VGoogle_WMD','BLEU']]
y = df_ncp['z-score']

# %%
#Libraries
    
#https://medium.com/codex/step-by-step-guide-to-simple-and-multiple-linear-regression-in-python-867ac9a30298    
    
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.neural_network import MLPRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
# Note the difference in argument order
modelLR = LinearRegression().fit(X_train,y_train)
predictions = modelLR.predict(X_test)

# %%
slr_slope = modelLR.coef_
slr_intercept = modelLR.intercept_

# %%
modelLR.score(X_train, y_train)
# Out:
# 0.08827903837695783

# %%
modelLR.score(X_test, y_test)
# Out:
# 0.08471200532752099

# %%
modelNN = MLPRegressor(random_state=1, max_iter=500).fit(X_train,y_train)

# %%
predictions = modelNN.predict(X_test)

# %%
modelNN.score(X_train, y_train)
# Out:
# 0.09421920714162235

# %%
modelNN.score(X_test, y_test)
# Out:
# 0.08546236398816387
